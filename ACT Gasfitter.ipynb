# %% [markdown]
# # Importing essential libraries

# %%
import selenium
import time
from selenium import webdriver

from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# # Loading the `Webdriver`

# %%
driver = webdriver.Chrome()

# %% [markdown]
# # Getting the access of `ACT Gasfitter's` official website

# %%
driver.get('https://www.accesscanberra.act.gov.au/s/public-registers/construction-licences?registerid=m0I4a00000000CLEAY')
time.sleep(2)

# %% [markdown]
# # Finding number of pages of the data

# %%
pages=driver.find_element_by_xpath('/html/body/div[4]/div[3]/div/div/div/div/div/div/div[3]/div/div/div[2]/c-cxs-public-registers-construction/div/div[6]/p').text
pages
# Out:
# 'Page: 1 / 167'

# %%
numbers = []
for word in pages.split():
    if word.isdigit():
        numbers.append(int(word))
print(numbers[1])
# Out:
# 167

# %% [markdown]
# # Main program to get `Headers` & `all the data rows` of just the `first page`

# %%
page_source = driver.page_source
soup =  BeautifulSoup(page_source, 'lxml')
            
data = [j.text for j in soup.findAll('td')]
#print(data)
all_names= []
all_names= data[::5]
print(all_names)
# Out:
# ['A & A HOTWATER & GAS SOLUTIONS PTY LTD', 'A & A HOTWATER & GAS SOLUTIONS PTY LTD', 'A & K (ACT) PTY LTD', 'A PLUS PLUMBING (ACT) PTY LTD', 'ABBEY, DAMIEN LETTON', 'ABBEY, DAMIEN LETTON', 'ABDEL RAHMAN, MUDATHIR NOURIN ALI', 'ABSOLOM, ALEX', 'ACKLAND, CHRISTOPHER LEE', 'ADAMS, JAMES']

# %%
len(all_names)
# Out:
# 10

# %%
data= data[3:]
#data
all_class_desc= []
all_class_desc= data[::5]
all_class_desc
# Out:
# ['LPG Gasfitter (Vapour Phase)',
#  'General',
#  'General',
#  'Advanced',
#  'General',
#  'LPG Gasfitter (Vapour Phase)',
#  'Journeyperson Gasfitter',
#  'Journeyperson Gasfitter',
#  'General',
#  'Journeyperson Gasfitter']

# %% [markdown]
# # Generating xpaths for all the records in any page

# %%
xpaths=[]
for j in range(1,11): #creating xpaths: just change span[i] to click different links
    xpaths.append('/html/body/div[4]/div[3]/div/div/div/div/div/div/div[3]/div/div/div[2]/c-cxs-public-registers-construction/div/div[5]/div/div/table/tbody/tr['+str(j) + ']/td[5]/lightning-button/button')
print(xpaths)
# Out:
# ['/html/body/div[4]/div[3]/div/div/div/div/div/div/div[3]/div/div/div[2]/c-cxs-public-registers-construction/div/div[5]/div/div/table/tbody/tr[1]/td[5]/lightning-button/button', '/html/body/div[4]/div[3]/div/div/div/div/div/div/div[3]/div/div/div[2]/c-cxs-public-registers-construction/div/div[5]/div/div/table/tbody/tr[2]/td[5]/lightning-button/button', '/html/body/div[4]/div[3]/div/div/div/div/div/div/div[3]/div/div/div[2]/c-cxs-public-registers-construction/div/div[5]/div/div/table/tbody/tr[3]/td[5]/lightning-button/button', '/html/body/div[4]/div[3]/div/div/div/div/div/div/div[3]/div/div/div[2]/c-cxs-public-registers-construction/div/div[5]/div/div/table/tbody/tr[4]/td[5]/lightning-button/button', '/html/body/div[4]/div[3]/div/div/div/div/div/div/div[3]/div/div/div[2]/c-cxs-public-registers-construction/div/div[5]/div/div/table/tbody/tr[5]/td[5]/lightning-button/button', '/html/body/div[4]/div[3]/div/div/div/div/div/div/div[3]/div/div/div[2]/c-cxs-public-registers-construction/div/div[5]/div/div/table/tbody/tr[6]/td[5]/lightning-button/button', '/html/body/div[4]/div[3]/div/div/div/div/div/div/div[3]/div/div/div[2]/c-cxs-public-registers-construction/div/div[5]/div/div/table/tbody/tr[7]/td[5]/lightning-button/button', '/html/body/div[4]/div[3]/div/div/div/div/div/div/div[3]/div/div/div[2]/c-cxs-public-registers-construction/div/div[5]/div/div/table/tbody/tr[8]/td[5]/lightning-button/button', '/html/body/div[4]/div[3]/div/div/div/div/div/div/div[3]/div/div/div[2]/c-cxs-public-registers-construction/div/div[5]/div/div/table/tbody/tr[9]/td[5]/lightning-button/button', '/html/body/div[4]/div[3]/div/div/div/div/div/div/div[3]/div/div/div[2]/c-cxs-public-registers-construction/div/div[5]/div/div/table/tbody/tr[10]/td[5]/lightning-button/button']

# %%
licensee_detail=[]
for k in range(1,11): #getting the details of every license in a combination
    driver.find_element_by_xpath(xpaths[k-1]).click()
    #time.sleep(1)
    
    page_source = driver.page_source
    soup = BeautifulSoup(page_source, 'lxml')
            
    det= [j.text for j in soup.findAll('td')]
    det=det[1:]
    #det

    ab=[]
    ab=det[::2]

    ab.insert(0,all_names[k-1])
    ab.insert(3,all_class_desc[k-1])
    ab

    licensee_detail.append(ab)
    
    
    
    
    
    driver.find_element_by_xpath('/html/body/div[4]/div[3]/div/div/div/div/div/div/div[3]/div/div/div[2]/c-cxs-public-registers-construction/div/div/lightning-button/button').click()

# %%
licensee_detail[0]
# Out:
# ['A & A HOTWATER & GAS SOLUTIONS PTY LTD',
#  '20191321',
#  '2/2/2024',
#  'LPG Gasfitter (Vapour Phase)',
#  'Gasfitter',
#  '',
#  '']

# %%
len(licensee_detail)
# Out:
# 10

# %% [markdown]
# # Main program to get `Headers` & `all the data rows` of all the pages till 167

# %%
for i in range(1, numbers[1]):
    
    driver.find_element_by_xpath('/html/body/div[4]/div[3]/div/div/div/div/div/div/div[3]/div/div/div[2]/c-cxs-public-registers-construction/div/div[6]/div[4]/button').click()
    time.sleep(1)
    
    page_source = driver.page_source
    soup =  BeautifulSoup(page_source, 'lxml')       
    data = [j.text for j in soup.findAll('td')]
    #data
    all_names= []
    all_names= data[::5]
    #all_names
    data= data[3:]
    #data
    all_class_desc= []
    all_class_desc= data[::5]
    #all_class_desc
    
    
    for k in range(1,11): 
        
        driver.find_element_by_xpath(xpaths[k-1]).click()
        #time.sleep(1)
    
        page_source = driver.page_source
        soup = BeautifulSoup(page_source, 'lxml')
            
        det= [l.text for l in soup.findAll('td')]
        det=det[1:]
        #det

        ab=[]
        ab=det[::2]

        ab.insert(3,all_class_desc[k-1])
        ab.insert(0,all_names[k-1])
        #ab

        licensee_detail.append(ab)
    
        driver.find_element_by_xpath('/html/body/div[4]/div[3]/div/div/div/div/div/div/div[3]/div/div/div[2]/c-cxs-public-registers-construction/div/div/lightning-button/button').click()
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-58-deb29d5511f4> in <module>
#      20     for k in range(1,11):
#      21
# ---> 22         driver.find_element_by_xpath(xpaths[k-1]).click()
#      23         #time.sleep(1)
#      24
#
# ~/anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in find_element_by_xpath(self, xpath)
#     392             element = driver.find_element_by_xpath('//div/td[1]')
#     393         """
# --> 394         return self.find_element(by=By.XPATH, value=xpath)
#     395
#     396     def find_elements_by_xpath(self, xpath):
#
# ~/anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in find_element(self, by, value)
#     976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
# --> 978             'value': value})['value']
#     979
#     980     def find_elements(self, by=By.ID, value=None):
#
# ~/anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~/anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/div[4]/div[3]/div/div/div/div/div/div/div[3]/div/div/div[2]/c-cxs-public-registers-construction/div/div[5]/div/div/table/tbody/tr[10]/td[5]/lightning-button/button"}
#   (Session info: chrome=94.0.4606.71)

# %%
det
# Out:
# ['201583',
#  'Expiry date',
#  '1/6/2024',
#  'Occupation',
#  'Gasfitter',
#  'General',
#  '',
#  'LPG Gasfitter (Vapour Phase)',
#  '']

# %%
ab
# Out:
# ['ZOUCH, GEORGE ANDREW',
#  '201583',
#  '1/6/2024',
#  'Gasfitter',
#  'LPG Gasfitter (Vapour Phase)',
#  '',
#  '']

# %%
licensee_detail
# Out:
# [['A & A HOTWATER & GAS SOLUTIONS PTY LTD',
#   '20191321',
#   '2/2/2024',
#   'LPG Gasfitter (Vapour Phase)',
#   'Gasfitter',
#   '',
#   ''],
#  ['A & A HOTWATER & GAS SOLUTIONS PTY LTD',
#   '20191321',
#   '2/2/2024',
#   'General',
#   'Gasfitter',
#   '',
#   ''],
#  ['A & K (ACT) PTY LTD', '2016855', '13/9/2022', 'General', 'Gasfitter', ''],
#  ['A PLUS PLUMBING (ACT) PTY LTD',
#   '2016683',
#   '17/8/2022',
#   'Advanced',
#   'Gasfitter',
#   ''],
#  ['ABBEY, DAMIEN LETTON',
#   '200216119',
#   '17/2/2024',
#   'General',
#   'Gasfitter',
#   '',
#   ''],
#  ['ABBEY, DAMIEN LETTON',
#   '200216119',
#   '17/2/2024',
#   'LPG Gasfitter (Vapour Phase)',
#   'Gasfitter',
#   '',
#   ''],
#  ['ABDEL RAHMAN, MUDATHIR NOURIN ALI',
#   '20201405',
#   '31/10/2023',
#   'Journeyperson Gasfitter',
#   'Gasfitter',
#   ''],
#  ['ABSOLOM, ALEX',
#   '2021915',
#   '27/7/2024',
#   'Journeyperson Gasfitter',
#   'Gasfitter',
#   ''],
#  ['ACKLAND, CHRISTOPHER LEE',
#   '2014830',
#   '5/4/2023',
#   'General',
#   'Gasfitter',
#   ''],
#  ['ADAMS, JAMES',
#   '2021668',
#   '8/8/2024',
#   'Journeyperson Gasfitter',
#   'Gasfitter',
#   ''],
#  ['ADVANCED PLUMBING & DRAINS (CANBERRA) PTY LTD',
#   '2017904',
#   '6/11/2023',
#   'Gasfitter',
#   'Advanced',
#   ''],
#  ['AGGARWAL, SURESH', '20151', '20/7/2023', 'Gasfitter', 'General', ''],
#  ['AGOSTINO, ALEX DOMINIC',
#   '20121662',
#   '16/1/2022',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['AL-KULABI, SAIF', '2020367', '16/4/2022', 'Gasfitter', 'General', '', ''],
#  ['AL-KULABI, SAIF',
#   '2020367',
#   '16/4/2022',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['AL-ZAHROUT, BRAKH',
#   '20211300',
#   '13/9/2024',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['ALL GAS PLUMBING REPAIRS PTY LTD',
#   '20208',
#   '6/2/2023',
#   'Gasfitter',
#   'General',
#   '',
#   ''],
#  ['ALL GAS PLUMBING REPAIRS PTY LTD',
#   '20208',
#   '6/2/2023',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['ALLEN, GAVAN CHARLES',
#   '20151235',
#   '16/5/2023',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['ALLEN, GERARD THOMAS',
#   '20101061',
#   '11/10/2021',
#   'Gasfitter',
#   'General',
#   ''],
#  ['ALLEN, MATHEW CHARLES',
#   '200428226',
#   '9/5/2022',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['AMEY, BRETT RICHARD',
#   '199915913',
#   '1/10/2023',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['AMEY, SAMUEL LESLIE THOMAS',
#   '200216054',
#   '3/2/2023',
#   'Gasfitter',
#   'General',
#   ''],
#  ['ANDERSON, DEAN JOHN',
#   '199214659',
#   '19/8/2024',
#   'Gasfitter',
#   'Advanced',
#   ''],
#  ['ANDREW, SCOTT MATTHEW',
#   '2010188',
#   '12/10/2021',
#   'Gasfitter',
#   'General',
#   '',
#   ''],
#  ['ANDREW, SCOTT MATTHEW',
#   '2010188',
#   '12/10/2021',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['ANDREWS, JUSTIN PAUL',
#   '200416233',
#   '28/5/2023',
#   'Gasfitter',
#   'General',
#   '',
#   ''],
#  ['ANDREWS, JUSTIN PAUL',
#   '200416233',
#   '28/5/2023',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['ANTONAKOS, CHRIS', '199714524', '1/5/2022', 'Gasfitter', 'General', ''],
#  ['APAP, DANIEL', '2021843', '23/7/2024', 'Gasfitter', 'Advanced', '', ''],
#  ['APAP, DANIEL',
#   '2021843',
#   '23/7/2024',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['APATHY, JAMIE',
#   '20201612',
#   '1/12/2021',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['AQUA BROTHERS PLUMBING PTY LTD',
#   '20171009',
#   '27/6/2022',
#   'Gasfitter',
#   'General',
#   '',
#   ''],
#  ['AQUA BROTHERS PLUMBING PTY LTD',
#   '20171009',
#   '27/6/2022',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['ARCIDIACONO, MICHAEL', '2008895', '20/5/2023', 'Gasfitter', 'General', ''],
#  ['ARGENTI, JOSHUA JOSEPH',
#   '2017895',
#   '4/4/2023',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['ARGENTI, JOSHUA JOSEPH',
#   '2017895',
#   '4/4/2023',
#   'Gasfitter',
#   'General',
#   '',
#   ''],
#  ['ARGYLE, JAMES', '20091222', '16/10/2021', 'Gasfitter', 'Advanced', ''],
#  ['ARNOTT, MATTHEW SHANE',
#   '20141072',
#   '10/12/2021',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['ARNOTT, MATTHEW SHANE',
#   '20141072',
#   '10/12/2021',
#   'Gasfitter',
#   'General',
#   '',
#   ''],
#  ['AROUND THE BEND PLUMBING & GAS FITTING PTY LIMITED',
#   '2009837',
#   '13/9/2024',
#   'Gasfitter',
#   'General',
#   ''],
#  ['ASHBY, SAMUEL',
#   '2021396',
#   '25/3/2022',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['ASHLIN, DYLAN',
#   '201942',
#   '17/1/2022',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['ASHLIN, DYLAN', '201942', '17/1/2022', 'Gasfitter', 'General', '', ''],
#  ['ASKEW, SAMUEL',
#   '20201115',
#   '5/11/2021',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['ASTILL, TYSON',
#   '20211394',
#   '25/9/2024',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['ATKIN, SHANE', '2009215', '15/11/2022', 'Gasfitter', 'General', '', ''],
#  ['ATKIN, SHANE',
#   '2009215',
#   '15/11/2022',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['AUALIITIA, JUAN PAUL',
#   '2016433',
#   '26/5/2022',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['AUALIITIA, JUAN PAUL',
#   '2016433',
#   '26/5/2022',
#   'Gasfitter',
#   'General',
#   '',
#   ''],
#  ['AURORA & CO PLUMBING PTY LTD',
#   '2019360',
#   '23/4/2022',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['AURORA & CO PLUMBING PTY LTD',
#   '2019360',
#   '23/4/2022',
#   'Gasfitter',
#   'General',
#   '',
#   ''],
#  ['AUZMENDI, ADAM', '2008711', '9/4/2022', 'Gasfitter', 'Advanced', ''],
#  ['AVAGE, IAN DAVID',
#   '20111474',
#   '11/8/2023',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['AVAGE, IAN DAVID', '20111474', '11/8/2023', 'Gasfitter', 'General', '', ''],
#  ['AXIS PLUMBING ACT PTY LTD',
#   '2005368',
#   '23/5/2023',
#   'Gasfitter',
#   'Advanced',
#   ''],
#  ['AZZILLA, AARON DEAN',
#   '201523',
#   '8/9/2023',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['BACKHOUSE, BRETT MICHAEL',
#   '2008856',
#   '20/8/2024',
#   'Gasfitter',
#   'General',
#   ''],
#  ['BACON, ALEXANDER',
#   '20151034',
#   '21/2/2022',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['BACON, ALEXANDER', '20151034', '21/2/2022', 'Gasfitter', 'General', '', ''],
#  ['BACON, LIAM',
#   '201968',
#   '27/1/2022',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['BADDOCK, DANNY GREGORY', '201754', '1/6/2022', 'Gasfitter', 'General', ''],
#  ['BAILEY, IAN WILLIAM',
#   '199613974',
#   '20/1/2023',
#   'Gasfitter',
#   'Advanced',
#   ''],
#  ['BAKER, STEPHEN JOSEPH',
#   '199314399',
#   '30/3/2022',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['BAKER, ZACHARY JOHN', '2016741', '20/2/2022', 'Gasfitter', 'General', ''],
#  ['BALMER, ROBERT', '2021228', '1/4/2024', 'Gasfitter', 'Advanced', '', ''],
#  ['BALMER, ROBERT',
#   '2021228',
#   '1/4/2024',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['BALTAJI, AYMAN',
#   '20201616',
#   '8/12/2021',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['BANKS, THOMAS',
#   '20201674',
#   '22/12/2023',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['BARAC, DENIS',
#   '20131202',
#   '9/8/2022',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['BARKER, JOSHUA ARNOLD',
#   '2021506',
#   '3/5/2022',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['BARLOW, MARK ANDREW',
#   '2006466',
#   '18/5/2022',
#   'Gasfitter',
#   'Advanced',
#   'Restricted to work performed as an employee only. Not able to contract.'],
#  ['BAROUDI, ADAM',
#   '2021468',
#   '16/4/2022',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['BARRON, THOMAS RAYMOND',
#   '199714113',
#   '21/6/2024',
#   'Gasfitter',
#   'General',
#   '',
#   ''],
#  ['BARRON, THOMAS RAYMOND',
#   '199714113',
#   '21/6/2024',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['BARTHOLOMEUSZ, MATTHEW THOMAS',
#   '2015300',
#   '19/11/2023',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['BARTHOLOMEUSZ, MATTHEW THOMAS',
#   '2015300',
#   '19/11/2023',
#   'Gasfitter',
#   'General',
#   '',
#   ''],
#  ['BARTLEET, CHRISTOPHER MICHAEL',
#   '2016277',
#   '2/5/2022',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['BARTLEET, CHRISTOPHER MICHAEL',
#   '2016277',
#   '2/5/2022',
#   'Gasfitter',
#   'General',
#   '',
#   ''],
#  ['BATEMAN, LUKE', '2012632', '22/5/2022', 'Gasfitter', 'General', ''],
#  ['BATTISSON, DAVID JOHN',
#   '199613970',
#   '3/12/2022',
#   'Gasfitter',
#   'Restricted Automotive LPG',
#   ''],
#  ['BATTISSON, GRAHAM PETER',
#   '199414136',
#   '13/7/2022',
#   'Gasfitter',
#   'Restricted Automotive LPG',
#   ''],
#  ['BAXTER, ROBERT JOHN',
#   '199714418',
#   '24/3/2024',
#   'Gasfitter',
#   'General',
#   '',
#   ''],
#  ['BAXTER, ROBERT JOHN',
#   '199714418',
#   '24/3/2024',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['BAY & COAST PLUMBING PTY LTD',
#   '2015965',
#   '22/10/2021',
#   'Gasfitter',
#   'Advanced',
#   ''],
#  ['BAYLEY, LUKE MICHAEL',
#   '2008271',
#   '30/9/2023',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['BAYLISS, ANDREW',
#   '2014885',
#   '19/8/2024',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['BAYLISS, ANDREW', '2014885', '19/8/2024', 'Gasfitter', 'General', '', ''],
#  ['BAYOT, BEN WILLIAM', '2017504', '28/6/2023', 'Gasfitter', 'Advanced', ''],
#  ['BEARD, PETER',
#   '2021707',
#   '22/6/2024',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['BEARD, PETER', '2021707', '22/6/2024', 'Gasfitter', 'Advanced', '', ''],
#  ['BEATH, ROBERT JOHN', '2015667', '26/7/2023', 'Gasfitter', 'Advanced', ''],
#  ['BELL, JAMIE ALLEN',
#   '20101127',
#   '19/11/2023',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['BELL, JOSHUA JOHN', '20181092', '22/10/2022', 'Gasfitter', 'Advanced', ''],
#  ['BENGSTON, CRAIG',
#   '202048',
#   '20/1/2023',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   ''],
#  ['BENNETT, JASON BRADLEY THOMAS',
#   '2012212',
#   '29/9/2023',
#   'Gasfitter',
#   'General',
#   ''],
#  ['BERENBAK, JUSTIN',
#   '2011764',
#   '25/6/2023',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['BERRY, TIAGO', '2018655', '14/10/2021', 'Gasfitter', 'Advanced', ''],
#  ['BERTOSA, WILLIAM ANTON',
#   '199714679',
#   '12/5/2023',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   'Journeyperson gasfitter can only provide this construction service as an employee under supervision'],
#  ['BEVAN, DYLAN JAY',
#   '2017464',
#   '8/6/2023',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['BIANCHINI, ANTHONY MARK',
#   '2005101',
#   '14/1/2023',
#   'Gasfitter',
#   'Restricted Automotive LPG',
#   ''],
#  ['BINETTI, ANTHONY',
#   '200416190',
#   '26/4/2024',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['BIONDA, KELVIN', '2010627', '24/4/2023', 'Gasfitter', 'General', ''],
#  ['BIRD, CODIE WALTER', '2016160', '23/9/2022', 'Gasfitter', 'General', ''],
#  ['BLACK, HARRY',
#   '199415448',
#   '25/6/2022',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['BLACKER, MICHAEL DOUGLAS',
#   '2014660',
#   '1/7/2023',
#   'Gasfitter',
#   'Advanced',
#   ''],
#  ['BLACKMORE, JASON',
#   '20201422',
#   '23/10/2023',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['BLADEN, MICHAEL FRANCIS',
#   '199414703',
#   '9/6/2022',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['BLADEN, MICHAEL FRANCIS',
#   '199414703',
#   '9/6/2022',
#   'Gasfitter',
#   'General',
#   '',
#   ''],
#  ['BLAIR, JAMES JOHN', '2009986', '16/7/2024', 'Gasfitter', 'General', ''],
#  ['BLAKE, RYAN', '2014353', '13/1/2024', 'Gasfitter', 'General', ''],
#  ['BLANCHARD, PATRICK JAMES',
#   '200216108',
#   '4/2/2023',
#   'Gasfitter',
#   'General',
#   '',
#   ''],
#  ['BLANCHARD, PATRICK JAMES',
#   '200216108',
#   '4/2/2023',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['BLANKENSTEIN, JOHN',
#   '2009158',
#   '2/11/2021',
#   'Gasfitter',
#   'Advanced',
#   'includes LPG vapour'],
#  ['BLAYDEN, SAM ANDREW', '2012793', '24/11/2022', 'Gasfitter', 'General', ''],
#  ['BLEWETT, JAMES',
#   '2020171',
#   '12/2/2023',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['BLEWITT, GARRY',
#   '199715812',
#   '8/3/2023',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['BLEWITT, GARRY', '199715812', '18/2/2023', 'Gasfitter', 'General', '', ''],
#  ['BLOODWORTH, BRIAN JAMES',
#   '199714802',
#   '16/3/2023',
#   'Gasfitter',
#   'General',
#   ''],
#  ['BLOODWORTH, JAMES MORGAN',
#   '2014348',
#   '23/1/2022',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['BLOODWORTH, NICHOLAS JOHN',
#   '2016709',
#   '27/1/2022',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['BLOYE, STEVEN MARK',
#   '199414846',
#   '13/12/2022',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['BLOYE, STEVEN MARK',
#   '199414846',
#   '13/12/2022',
#   'Gasfitter',
#   'General',
#   '',
#   ''],
#  ['BLUNDELL, KYLE JORDAN',
#   '20121181',
#   '6/5/2022',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['BLUNDELL, WADE',
#   '20151076',
#   '21/3/2022',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['BLUNDELL, WADE',
#   '20151076',
#   '21/3/2022',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   '',
#   ''],
#  ['BM PLUMBING & DRAINAGE PTY LIMITED',
#   '2019187',
#   '1/4/2023',
#   'Gasfitter',
#   'General',
#   ''],
#  ['BOLAND, TODD ASHLEY',
#   '2012857',
#   '28/7/2023',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['BOLAND, TODD ASHLEY',
#   '2012857',
#   '28/7/2023',
#   'Gasfitter',
#   'General',
#   '',
#   ''],
#  ['BOLJKOVAC, BAILEY',
#   '2021272',
#   '4/3/2024',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['BOOTH, TIMOTHY PAUL', '2015385', '2/10/2021', 'Gasfitter', 'Advanced', ''],
#  ['BOPPING, DAVID JOHN',
#   '2012642',
#   '23/10/2021',
#   'Gasfitter',
#   'Restricted Automotive NGV',
#   'Restricted to work as an employee. Not able to contract.'],
#  ['BORRMAN, BARDO', '20131306', '11/3/2024', 'Gasfitter', 'General', ''],
#  ['BOSOTAS, TIMOTHY JOHN',
#   '20181061',
#   '26/2/2022',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['BOSWELL, DANIEL JOHN',
#   '2017486',
#   '28/7/2023',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['BOTHAMLEY, DANIEL WAYNE',
#   '2020161',
#   '25/2/2023',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['BOTHAMLEY, DANIEL WAYNE',
#   '2020161',
#   '25/2/2023',
#   'Gasfitter',
#   'Advanced',
#   '',
#   ''],
#  ['BOUNDY, NOAHTA',
#   '20201423',
#   '21/10/2021',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['BOWDEN, ZACHERY',
#   '2016519',
#   '11/8/2022',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['BOWDEN, ZACHERY', '2016519', '11/8/2022', 'Gasfitter', 'General', '', ''],
#  ['BOWIE, PETER IGNATIUS',
#   '198714858',
#   '12/7/2024',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['BOWIE, PETER IGNATIUS',
#   '198714858',
#   '12/7/2024',
#   'Gasfitter',
#   'General',
#   '',
#   ''],
#  ['BOYTON, BENJAMIN JAMES',
#   '20111151',
#   '16/2/2022',
#   'Gasfitter',
#   'General',
#   '',
#   ''],
#  ['BOYTON, BENJAMIN JAMES',
#   '20111151',
#   '16/2/2022',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['BOYTON, CHARLIE JOSEPH',
#   '2016351',
#   '3/3/2024',
#   'Gasfitter',
#   'General',
#   '',
#   ''],
#  ['BOYTON, CHARLIE JOSEPH',
#   '2016351',
#   '4/3/2024',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['BR PLUMBING & EXCAVATIONS PTY LTD',
#   '200987',
#   '8/8/2024',
#   'Gasfitter',
#   'Advanced',
#   ''],
#  ['BRADLEY, DAVID HAROLD',
#   '2005463',
#   '14/7/2023',
#   'Gasfitter',
#   'Restricted Automotive NGV',
#   ''],
#  ['BRAIDO, PHILLIP JOHN',
#   '199714667',
#   '15/5/2023',
#   'Gasfitter',
#   'General',
#   'Please contact Access Canberra for condition details'],
#  ['BRAIN, MITCHELL ALEXANDER',
#   '20141361',
#   '18/12/2023',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['BRANDON, REECE', '2014695', '27/5/2024', 'Gasfitter', 'General', ''],
#  ['BREINER, PAUL',
#   '200961',
#   '21/4/2024',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['BREITKOPF, JASON GRANT',
#   '199614149',
#   '13/3/2024',
#   'Gasfitter',
#   'General',
#   ''],
#  ['BRERETON, CRAIG ANTHONY',
#   '2006849',
#   '27/2/2024',
#   'Gasfitter',
#   'General',
#   ''],
#  ['BRETT, RICHARD JOHN',
#   '199714538',
#   '22/7/2022',
#   'Gasfitter',
#   'General',
#   '',
#   ''],
#  ['BRETT, RICHARD JOHN',
#   '199714538',
#   '22/7/2022',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['BRICE-WILLIAMS, CALLUM',
#   '201955',
#   '16/7/2022',
#   'Gasfitter',
#   'General',
#   '',
#   ''],
#  ['BRICE-WILLIAMS, CALLUM',
#   '201955',
#   '16/7/2022',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['BRIGGS, TIMOTHY DARRIN',
#   '20101149',
#   '20/12/2023',
#   'Gasfitter',
#   'Advanced',
#   ''],
#  ['BRIMAGE, CHRISTOPHER',
#   '2021463',
#   '25/4/2024',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['BROMWICH, BRADLEY CHARLES',
#   '201360',
#   '28/6/2025',
#   'Gasfitter',
#   'General',
#   ''],
#  ['BROWN, BRENDAN',
#   '2021440',
#   '12/4/2022',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['BROWN, CAMERON', '20171097', '8/6/2022', 'Gasfitter', 'General', '', ''],
#  ['BROWN, CAMERON',
#   '20171097',
#   '8/6/2022',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['BROWN, STEWART THOMAS',
#   '199714448',
#   '31/3/2022',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['BROWNBILL, GEORGE METCALF',
#   '20121129',
#   '30/9/2022',
#   'Gasfitter',
#   'General',
#   ''],
#  ['BRUCIC, NICHOLAS', '2014393', '5/11/2023', 'Gasfitter', 'General', ''],
#  ['BRYANT, COOPER SEC',
#   '200216113',
#   '18/8/2024',
#   'Gasfitter',
#   'Advanced',
#   'Gasfitting pressure below 21KPA. LPG Gasfitting pressure below 21KPA.',
#   ''],
#  ['BRYANT, COOPER SEC',
#   '200216113',
#   '18/8/2024',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   'Gasfitting pressure below 21KPA. LPG Gasfitting pressure below 21KPA.',
#   ''],
#  ['BUCHANAN, HAMISH DUNCAN',
#   '2011229',
#   '21/10/2024',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['BUCHANAN, HAMISH DUNCAN',
#   '2011229',
#   '21/10/2024',
#   'Gasfitter',
#   'Advanced',
#   '',
#   ''],
#  ['BUCKLEY, ROBERT PATRICK',
#   '199715458',
#   '5/7/2024',
#   'Gasfitter',
#   'General',
#   ''],
#  ['BUCKMASTER, BENJAMIN',
#   '2017695',
#   '28/10/2023',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['BULL, ANDREW DUNCAN',
#   '200214172',
#   '23/12/2021',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   ''],
#  ['BULLOCK, BRENT',
#   '20201576',
#   '25/11/2021',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['BUNNEY, RYAN',
#   '20201668',
#   '15/12/2021',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['BUONOPANE, VINCE PETER',
#   '199214812',
#   '4/7/2022',
#   'Gasfitter',
#   'Advanced',
#   ''],
#  ['BURDORF, MICHAEL', '200874', '2/8/2022', 'Gasfitter', 'General', '', ''],
#  ['BURDORF, MICHAEL',
#   '200874',
#   '2/8/2022',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['BURKE, RAY ALLAN',
#   '200316158',
#   '24/10/2022',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['BURKE, RAY ALLAN',
#   '200316158',
#   '24/10/2022',
#   'Gasfitter',
#   'General',
#   '',
#   ''],
#  ['BURR, ANTHONY DAVID',
#   '199514030',
#   '29/7/2022',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['BURRELL, CRAIG LINDSAY',
#   '199314574',
#   '31/10/2023',
#   'Gasfitter',
#   'Advanced',
#   ''],
#  ['BURRELL, MICHAEL LINDSAY',
#   '2020126',
#   '4/2/2023',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['BURRELL, MICHAEL LINDSAY',
#   '2020126',
#   '4/2/2023',
#   'Gasfitter',
#   'General',
#   '',
#   ''],
#  ['BURROWS, ANGUS', '2018506', '18/6/2024', 'Gasfitter', 'General', ''],
#  ['BUSSTRA, DAVID JOHN', '199714484', '2/12/2021', 'Gasfitter', 'General', ''],
#  ['BUTLER, ANTHONY JAMES', '201335', '29/9/2024', 'Gasfitter', 'General', ''],
#  ['BUTLER, JORDAN PATRICK JAMES',
#   '201742',
#   '8/8/2024',
#   'Gasfitter',
#   'General',
#   ''],
#  ['BUTT, GORDON JOHN',
#   '20111000',
#   '3/9/2023',
#   'Gasfitter',
#   'Restricted Automotive LPG',
#   'Restricted to work as an employee only. Not able to contract.'],
#  ['BUTTERFIELD, PETER KENNETH',
#   '199314986',
#   '10/11/2023',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['BUYTEWEG, ANDREW MARK',
#   '199414527',
#   '23/3/2023',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['BYERS, JOSHUA MATTHEW',
#   '2021512',
#   '5/5/2024',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['CALEAR, GEORGE ALFRED',
#   '199315788',
#   '9/6/2022',
#   'Gasfitter',
#   'General',
#   'Includes LPG (Vapour Phase)'],
#  ['CALGARO, JOSHUA PAUL',
#   '2007112',
#   '2/3/2024',
#   'Gasfitter',
#   'General',
#   'Includes LPG Vapour Phase.'],
#  ['CALVERT, LESLIE ALAN',
#   '199515418',
#   '29/3/2024',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   ''],
#  ['CAMERON, MITCHELL',
#   '20181326',
#   '15/1/2023',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['CAMERON, MITCHELL',
#   '20181326',
#   '15/1/2023',
#   'Gasfitter',
#   'General',
#   '',
#   ''],
#  ['CAMERON, WILLIAM', '2006210', '13/8/2023', 'Gasfitter', 'General', ''],
#  ['CAMILLERI, JASON SEAN',
#   '20141065',
#   '7/12/2023',
#   'Gasfitter',
#   'Advanced',
#   ''],
#  ['CAMILLERI, JOSEPH BRADLEY JORDAN',
#   '20191110',
#   '13/11/2023',
#   'Gasfitter',
#   'General',
#   ''],
#  ['CAMPBELL, BLAKE',
#   '2021884',
#   '26/7/2022',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['CAMPBELL, JOEL',
#   '20201497',
#   '11/5/2022',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['CAMPBELL, STEVEN ALLAN',
#   '2015519',
#   '25/6/2024',
#   'Gasfitter',
#   'Advanced',
#   ''],
#  ['CANNIZZARO, MASSIMILIANO',
#   '2011367',
#   '6/4/2022',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['CANNON, GLEN DAVID', '2008300', '30/6/2024', 'Gasfitter', 'Advanced', ''],
#  ['CANNON, LEE MICHAEL', '199915894', '19/5/2023', 'Gasfitter', 'General', ''],
#  ['CANT, JOHN GORDON',
#   '200316168',
#   '18/12/2023',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['CAPEX GROUP PTY LTD', '20201209', '14/9/2023', 'Gasfitter', 'General', ''],
#  ['CAPITAL GAS WORKS PTY LTD',
#   '2013896',
#   '25/9/2022',
#   'Gasfitter',
#   'General',
#   ''],
#  ['CAPITAL MAINTENANCE SOLUTIONS',
#   '2019824',
#   '2/9/2022',
#   'Gasfitter',
#   'Advanced',
#   ''],
#  ['CAPPELLO, ANTHONY DAVID',
#   '100114349',
#   '2/9/2024',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['CAPPELLO, RYAN ANDREW', '200524', '20/6/2024', 'Gasfitter', 'Advanced', ''],
#  ['CARAZO, GERARD', '2019961', '20/5/2022', 'Gasfitter', 'Advanced', '', ''],
#  ['CARAZO, GERARD',
#   '2019961',
#   '20/5/2022',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['CAREY, SIMON THOMAS', '200920', '4/2/2022', 'Gasfitter', 'General', '', ''],
#  ['CAREY, SIMON THOMAS',
#   '200920',
#   '4/2/2022',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['CARLSON, SHANE', '2019277', '4/4/2022', 'Gasfitter', 'General', '', ''],
#  ['CARLSON, SHANE',
#   '2019277',
#   '4/4/2022',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['CARMODY, SHANE MARK', '200316136', '26/6/2022', 'Gasfitter', 'General', ''],
#  ['CARN, BEN',
#   '2019174',
#   '27/5/2022',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['CARNELL, THOMAS WILLIAM',
#   '201439',
#   '14/7/2022',
#   'Gasfitter',
#   'General',
#   '',
#   ''],
#  ['CARNELL, THOMAS WILLIAM',
#   '201439',
#   '14/7/2022',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['CARPENTER, JAMIE STEPHEN',
#   '2006444',
#   '23/3/2023',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['CARPENTER, JAMIE STEPHEN',
#   '2006444',
#   '23/3/2023',
#   'Gasfitter',
#   'General',
#   '',
#   ''],
#  ['CARPENTER, SIMON',
#   '20181238',
#   '19/11/2021',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['CARSON, DAMON JOHN', '200216107', '29/8/2022', 'Gasfitter', 'General', ''],
#  ['CARSON, PAUL GEOFFREY',
#   '20101017',
#   '4/8/2024',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['CARTER, WILLIAM',
#   '20191286',
#   '28/2/2022',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['CARTON, MATTHEW XAVIER',
#   '20091',
#   '8/3/2023',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['CARTON, MATTHEW XAVIER',
#   '20091',
#   '8/3/2023',
#   'Gasfitter',
#   'General',
#   '',
#   ''],
#  ['CARTWRIGHT, JACK GRAHAM',
#   '20111450',
#   '1/2/2022',
#   'Gasfitter',
#   'General',
#   '',
#   ''],
#  ['CARTWRIGHT, JACK GRAHAM',
#   '20111450',
#   '1/2/2022',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['CARUSO, JOSEPH', '2017842', '18/10/2023', 'Gasfitter', 'General', '', ''],
#  ['CARUSO, JOSEPH',
#   '2017842',
#   '18/10/2023',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['CASE, DARREN JOHN', '199314821', '20/11/2021', 'Gasfitter', 'Advanced', ''],
#  ['CASEY, ALLAN GRAHAM',
#   '2005466',
#   '12/10/2023',
#   'Gasfitter',
#   'Restricted Automotive NGV',
#   ''],
#  ['CASEY, MITCHELL BRIAN',
#   '2015193',
#   '1/7/2022',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['CASEY, MITCHELL BRIAN',
#   '2015193',
#   '1/7/2022',
#   'Gasfitter',
#   'General',
#   '',
#   ''],
#  ['CASSELDEN, GEOFFREY ROBERT',
#   '199715562',
#   '16/4/2022',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['CASSELDEN, GEOFFREY ROBERT',
#   '199715562',
#   '16/4/2022',
#   'Gasfitter',
#   'General',
#   '',
#   ''],
#  ['CATTELL, PETER GERARD', '2014855', '6/9/2024', 'Gasfitter', 'General', ''],
#  ['CCS FM PTY LTD', '2014720', '4/1/2024', 'Gasfitter', 'Advanced', ''],
#  ['CETINKAYA, IMRAN', '20111510', '20/4/2024', 'Gasfitter', 'General', ''],
#  ['CH PTY LIMITED', '20081087', '9/12/2023', 'Gasfitter', 'Advanced', ''],
#  ['CHALKER, STEPHEN JEFFERY',
#   '2018319',
#   '9/7/2022',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['CHALLEN, GARY RICHARD',
#   '199815855',
#   '11/6/2024',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['CHARLES, BENJAMIN JOHN',
#   '20101230',
#   '6/4/2023',
#   'Gasfitter',
#   'Advanced',
#   ''],
#  ['CHIEN KHUONG, MANH',
#   '2018336',
#   '19/4/2023',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['CHIEN KHUONG, MANH',
#   '2018336',
#   '20/4/2023',
#   'Gasfitter',
#   'General',
#   '',
#   ''],
#  ['CHIERA, JOHN FRANCIS',
#   '199615657',
#   '30/1/2023',
#   'Gasfitter',
#   'Advanced',
#   ''],
#  ['CHIVAS, IAN JOHN', '199613965', '26/3/2023', 'Gasfitter', 'Advanced', ''],
#  ['CHOPPING, DAVID BRIAN',
#   '199714752',
#   '4/4/2022',
#   'Gasfitter',
#   'Advanced',
#   ''],
#  ['CHRISTIAN, NATHAN',
#   '20201714',
#   '26/12/2021',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['CHRISTIAN, SHANE ANTHONY',
#   '2014519',
#   '30/5/2023',
#   'Gasfitter',
#   'Advanced',
#   'Restricted to work performed as an employee only. Not able to contract.'],
#  ['CICERAN, JOHN STEVEN',
#   '199815828',
#   '6/2/2023',
#   'Gasfitter',
#   'General',
#   '',
#   ''],
#  ['CICERAN, JOHN STEVEN',
#   '199815828',
#   '6/2/2023',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['CIESIOLKA, ERIC',
#   '202079',
#   '25/2/2023',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['CIVIL AND CIVIC GROUP PTY LTD',
#   '2021356',
#   '25/3/2024',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['CIVIL AND CIVIC GROUP PTY LTD',
#   '2021356',
#   '25/3/2024',
#   'Gasfitter',
#   'Advanced',
#   '',
#   ''],
#  ['CLACK, JAMES',
#   '2021642',
#   '20/5/2022',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['CLACK, JOHN',
#   '20201059',
#   '20/8/2024',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['CLARK, JOHN',
#   '2021308',
#   '1/6/2022',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['CLARK, NATHAN ASHLEY',
#   '20181353',
#   '13/12/2021',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['CLARK, ROSS KAI', '2005941', '30/3/2022', 'Gasfitter', 'General', ''],
#  ['CLARK, TYE', '201715', '31/1/2023', 'Gasfitter', 'Advanced', ''],
#  ['CLARKE, ADRIAN DAVID',
#   '199714510',
#   '5/7/2022',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['CLARKE, ADRIAN DAVID',
#   '199714510',
#   '5/7/2022',
#   'Gasfitter',
#   'General',
#   '',
#   ''],
#  ['CLEARY, WILLIAM EDMUND',
#   '199715745',
#   '7/4/2023',
#   'Gasfitter',
#   'General',
#   '',
#   ''],
#  ['CLEARY, WILLIAM EDMUND',
#   '199715745',
#   '7/4/2023',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['CLEMENO, JOSEPH',
#   '2009798',
#   '4/9/2022',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['CLEMENO, JOSEPH', '2009798', '4/9/2022', 'Gasfitter', 'General', '', ''],
#  ['CLIMATROL TRADING PTY LTD',
#   '20211118',
#   '6/8/2024',
#   'Gasfitter',
#   'General',
#   ''],
#  ['CLOTHIER, CHRISTOPHER ARTHUR',
#   '199714038',
#   '19/1/2024',
#   'Gasfitter',
#   'Restricted Automotive LPG',
#   ''],
#  ['CLUNE, KIERAN TIMOTHY',
#   '199714272',
#   '31/8/2022',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['CLUNE, KIERAN TIMOTHY',
#   '199714272',
#   '31/8/2022',
#   'Gasfitter',
#   'General',
#   '',
#   ''],
#  ['COBUCCIO, GUISEPPE',
#   '200427203',
#   '2/11/2022',
#   'Gasfitter',
#   'Restricted Automotive LPG',
#   ''],
#  ['COCKRAM, MATTHEW PAUL',
#   '199713945',
#   '12/6/2024',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['COGGAN, JASON',
#   '2013886',
#   '20/10/2021',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['COLEMAN, ALEXANDER JOSEPH',
#   '2015839',
#   '28/3/2022',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['COLEMAN, JOHN JAMES',
#   '2020313',
#   '23/4/2023',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['COLEMAN, JOHN JAMES',
#   '2020313',
#   '23/4/2023',
#   'Gasfitter',
#   'Advanced',
#   '',
#   ''],
#  ['COLEMAN, SEAN ANDREW',
#   '20111114',
#   '14/12/2023',
#   'Gasfitter',
#   'Advanced',
#   '',
#   ''],
#  ['COLEMAN, SEAN ANDREW',
#   '20111114',
#   '14/12/2023',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['COLLARD, SIMON WAYNE',
#   '200849',
#   '10/1/2022',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['COLLARD, SIMON WAYNE',
#   '200849',
#   '10/1/2022',
#   'Gasfitter',
#   'General',
#   '',
#   ''],
#  ['COLLINS, BRADLEY',
#   '20211375',
#   '22/9/2024',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['COLMAN, BRIAN JAMES',
#   '2014699',
#   '23/7/2023',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['COLMAN, BRIAN JAMES',
#   '2014699',
#   '23/7/2023',
#   'Gasfitter',
#   'General',
#   '',
#   ''],
#  ['COMPTON, GERAINT', '2019333', '22/5/2022', 'Gasfitter', 'Advanced', ''],
#  ['CONLON, BLAKE JOSHUA',
#   '200416236',
#   '30/8/2023',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['CONNELL, JOSHUA',
#   '2019848',
#   '3/12/2022',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['CONNELLY, MATTHEW',
#   '2015806',
#   '27/2/2022',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['CONNELLY, MATTHEW', '2015806', '27/2/2022', 'Gasfitter', 'General', '', ''],
#  ['CONNOR, ASHLEY JOHN',
#   '2014604',
#   '14/1/2022',
#   'Gasfitter',
#   'General',
#   '',
#   ''],
#  ['CONNOR, ASHLEY JOHN',
#   '2014604',
#   '14/1/2022',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['CONRON, JOEL THOMAS',
#   '200676',
#   '25/1/2022',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['COOK, ALAN RODNEY',
#   '199615434',
#   '15/6/2023',
#   'Gasfitter',
#   'General',
#   'Includes LPG (Vapour Phase)'],
#  ['COOK, COLIN NOEL', '2020157', '20/2/2024', 'Gasfitter', 'Advanced', ''],
#  ['COOMBE, WARWICK',
#   '20201500',
#   '9/11/2021',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['COOMBES, EMMETT WILLIAM',
#   '20081145',
#   '9/1/2024',
#   'Gasfitter',
#   'General',
#   'includes LPG vapour phase.'],
#  ['COOPER, DANIEL JAMES',
#   '200216087',
#   '18/9/2022',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['COOPER, DANIEL JAMES',
#   '200216087',
#   '29/9/2022',
#   'Gasfitter',
#   'General',
#   '',
#   ''],
#  ['COOPER, DAVID NORMAN',
#   '2013914',
#   '7/9/2023',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['COOPER, DAVID NORMAN',
#   '2013914',
#   '7/9/2023',
#   'Gasfitter',
#   'General',
#   '',
#   ''],
#  ['COOPER, MAXWELL ROBERT',
#   '2018313',
#   '19/4/2022',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['COOPERS PLUMBING & IRRIGATION PTY LTD',
#   '2020787',
#   '26/7/2023',
#   'Gasfitter',
#   'General',
#   '',
#   ''],
#  ['COOPERS PLUMBING & IRRIGATION PTY LTD',
#   '2020787',
#   '26/7/2023',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['CORDY, BRYCE',
#   '2019133',
#   '1/4/2022',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['CORKERY, MITCHELL',
#   '20181239',
#   '21/11/2021',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['CORKHILL, LINCOLN', '200216076', '1/4/2023', 'Gasfitter', 'General', ''],
#  ['CORRIGAN, MARK THOMAS',
#   '20061144',
#   '30/8/2022',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['COSTANZO, ANTONIO',
#   '199714008',
#   '6/8/2023',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['COSTANZO, ANTONIO',
#   '199714008',
#   '6/8/2023',
#   'Gasfitter',
#   'General',
#   '',
#   ''],
#  ['COSTANZO, SAVERIO', '2010928', '18/3/2024', 'Gasfitter', 'General', '', ''],
#  ['COSTANZO, SAVERIO',
#   '2010928',
#   '18/3/2024',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['COTTER, SHAUN PATRICK',
#   '199915931',
#   '19/4/2023',
#   'Gasfitter',
#   'General',
#   ''],
#  ['COTTERILL, BRADLEY DOUGLAS',
#   '200316134',
#   '26/7/2023',
#   'Gasfitter',
#   'General',
#   ''],
#  ['COTTERILL, CARL',
#   '2020127',
#   '4/2/2023',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['COULSON, MICHAEL ALAN', '2011484', '26/9/2024', 'Gasfitter', 'General', ''],
#  ['CRABB, AIDEN MARC', '2014328', '25/6/2022', 'Gasfitter', 'General', '', ''],
#  ['CRABB, AIDEN MARC',
#   '2014328',
#   '25/6/2022',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['CRAIGIE, CALLUM MACKENZIE',
#   '2015255',
#   '2/5/2022',
#   'Gasfitter',
#   'General',
#   ''],
#  ['CREGAN, ISAAC JAMES',
#   '2016281',
#   '14/5/2022',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['CRIVICI, ASHLEY JAMES',
#   '2014508',
#   '31/5/2023',
#   'Gasfitter',
#   'General',
#   '',
#   ''],
#  ['CRIVICI, ASHLEY JAMES',
#   '2014508',
#   '31/5/2023',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['CRNCEVIC, TONY ANDREW JOHN',
#   '199414837',
#   '16/5/2023',
#   'Gasfitter',
#   'General',
#   ''],
#  ['CRNJAC, IVAN DRAGO', '2016520', '11/1/2023', 'Gasfitter', 'General', ''],
#  ['CRNJAC, TONY', '199815818', '9/11/2023', 'Gasfitter', 'General', ''],
#  ['CROKER, RYAN JOHN', '2015934', '21/3/2024', 'Gasfitter', 'Advanced', ''],
#  ['CROMPTON, MARK',
#   '2021592',
#   '17/5/2022',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['CROMPTON, MARK', '2021592', '17/5/2022', 'Gasfitter', 'Advanced', '', ''],
#  ['CROSBIE, BRENDAN JOSEPH',
#   '199314614',
#   '7/1/2022',
#   'Gasfitter',
#   'General',
#   'Includes LPG (Vapour Phase)'],
#  ['CROSBIE, JOSEPH',
#   '202115',
#   '12/1/2022',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['CROW, JOSHUA JAMES', '201996', '14/2/2022', 'Gasfitter', 'Advanced', ''],
#  ['CRYER, TOM',
#   '2020725',
#   '29/3/2024',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['CRYER, TOM', '2020725', '29/3/2024', 'Gasfitter', 'Advanced', '', ''],
#  ['CULLEN, JONATHAN JOSEPH',
#   '20151211',
#   '19/2/2022',
#   'Gasfitter',
#   'General',
#   ''],
#  ['CUMMINS, BRETT RONALD',
#   '200416201',
#   '19/4/2024',
#   'Gasfitter',
#   'General',
#   ''],
#  ['CUMMINS, SCOTT',
#   '2020101',
#   '17/12/2021',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['CUNANAN, WILFREDO',
#   '200752',
#   '6/8/2022',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['CURRAN, PATRICK DANIEL ALEXANDER',
#   '2006495',
#   '15/7/2022',
#   'Gasfitter',
#   'General',
#   ''],
#  ['CUSHMAN & WAKEFIELD PTY LTD',
#   '20091198',
#   '20/12/2021',
#   'Gasfitter',
#   'Advanced',
#   'Includes LPG Vapour Phase.'],
#  ['CUSTOM PLUMBING SERVICES PTY LTD',
#   '2008530',
#   '10/6/2023',
#   'Gasfitter',
#   'Advanced',
#   ''],
#  ['CUTTS, JEREMY WAKEHAM',
#   '20101027',
#   '24/9/2022',
#   'Gasfitter',
#   'General',
#   ''],
#  ['D & K EGAN PLUMBING PTY LTD',
#   '20111377',
#   '13/11/2023',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['D & K EGAN PLUMBING PTY LTD',
#   '20111377',
#   '13/11/2023',
#   'Gasfitter',
#   'Advanced',
#   '',
#   ''],
#  ['D & N HRSTIC PTY LTD', '2020518', '5/5/2023', 'Gasfitter', 'General', ''],
#  ['D GROUP PTY LTD', '2005824', '26/10/2023', 'Gasfitter', 'General', '', ''],
#  ['D GROUP PTY LTD',
#   '2005824',
#   '26/10/2023',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['D L EARTHWORKS AND PLUMBING',
#   '20111033',
#   '3/9/2023',
#   'Gasfitter',
#   'General',
#   ''],
#  ['DA SILVA, MICHAEL DAVID',
#   '2013299',
#   '14/7/2023',
#   'Gasfitter',
#   'Advanced',
#   ''],
#  ['DAHL, JAMES ERNEST', '199915889', '26/3/2022', 'Gasfitter', 'General', ''],
#  ['DAL MASO, ADRIAN DEAN',
#   '200416224',
#   '5/12/2023',
#   'Gasfitter',
#   'Advanced',
#   'Includes LPG Vapour phase.'],
#  ['DALE, MARK', '201788', '24/2/2023', 'Gasfitter', 'Advanced', ''],
#  ['DALE, TROY ANDREW',
#   '2017237',
#   '8/10/2021',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['DALY, SCOTT JAMES',
#   '199714091',
#   '15/9/2022',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['DANIEL JAMES, KING',
#   '2017673',
#   '17/11/2023',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['DANIEL JAMES, KING',
#   '2017673',
#   '17/11/2023',
#   'Gasfitter',
#   'General',
#   '',
#   ''],
#  ['DANIEL, STEPHEN',
#   '199714741',
#   '12/5/2022',
#   'Gasfitter',
#   'General',
#   'Includes LPG (Vapour Phase)'],
#  ['DANILCZAK, KYLE JAMES',
#   '20201187',
#   '25/9/2022',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['DARVILLE, PAUL', '199715710', '8/6/2022', 'Gasfitter', 'General', '', ''],
#  ['DARVILLE, PAUL',
#   '199715710',
#   '8/6/2022',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['DAVIDSON, IAIN NEIL', '2016784', '10/9/2022', 'Gasfitter', 'Advanced', ''],
#  ['DAVIS, ROBERT JOHN', '199715140', '17/5/2024', 'Gasfitter', 'Advanced', ''],
#  ['DAVIS-NORMAN, SIMON', '2015491', '25/6/2024', 'Gasfitter', 'General', ''],
#  ['DAWSON, DEAN',
#   '200015948',
#   '30/8/2022',
#   'Gasfitter',
#   'General',
#   'Includes LPG (Vapour Phase)'],
#  ['DE FREITAS, MARCO',
#   '2018581',
#   '25/6/2024',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['DE HAAN, LACHLAN', '2008178', '7/3/2022', 'Gasfitter', 'General', '', ''],
#  ['DE HAAN, LACHLAN',
#   '2008178',
#   '7/3/2022',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['DE ROOY, JOSHUA',
#   '2015220',
#   '30/6/2022',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['DE SOUZA, LIONEL', '2014659', '28/11/2022', 'Gasfitter', 'Advanced', ''],
#  ['DEKKER, PAUL MARTIN', '2011755', '1/7/2022', 'Gasfitter', 'General', ''],
#  ['DELL, DAVID LOCHLAN', '2014684', '14/10/2023', 'Gasfitter', 'Advanced', ''],
#  ['DEMAMIEL, STEPHEN KEITH',
#   '199014657',
#   '12/9/2023',
#   'Gasfitter',
#   'General',
#   ''],
#  ['DEMETRIUS, AARON MARK',
#   '2016283',
#   '18/7/2022',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['DEMETRIUS, AARON MARK',
#   '2016283',
#   '18/7/2022',
#   'Gasfitter',
#   'General',
#   '',
#   ''],
#  ['DESCHAMPS, JAMES', '2017731', '16/8/2022', 'Gasfitter', 'General', '', ''],
#  ['DESCHAMPS, JAMES',
#   '2017731',
#   '16/8/2022',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['DEVANTIER, TERRY ALAN',
#   '2006920',
#   '11/12/2022',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['DEVANTIER, TERRY ALAN',
#   '2006920',
#   '11/12/2022',
#   'Gasfitter',
#   'General',
#   '',
#   ''],
#  ['DEVESON, ROY THOMAS', '20091020', '21/6/2024', 'Gasfitter', 'General', ''],
#  ['DICKIE, BRADLEY MITCHELL',
#   '200426285',
#   '29/7/2024',
#   'Gasfitter',
#   'General',
#   ''],
#  ['DICKIE, THOMAS', '20141231', '25/6/2023', 'Gasfitter', 'General', ''],
#  ['DICKSON, DANIEL',
#   '2009846',
#   '29/4/2023',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['DILLON, CRAIG JOHN',
#   '20131059',
#   '4/11/2023',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['DILLON, SAMUEL PETER',
#   '201141',
#   '23/1/2023',
#   'Gasfitter',
#   'General',
#   '',
#   ''],
#  ['DILLON, SAMUEL PETER',
#   '201141',
#   '23/1/2023',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['DISISTO, MICHAEL PETER',
#   '20091243',
#   '19/8/2022',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['DISISTO, MICHAEL PETER',
#   '20091243',
#   '19/8/2022',
#   'Gasfitter',
#   'General',
#   '',
#   ''],
#  ['DOAK, JOSHUA ERIC', '2014843', '22/10/2023', 'Gasfitter', 'Advanced', ''],
#  ['DOBIJA, JORDAN KRISTOPHER',
#   '199915895',
#   '17/2/2024',
#   'Gasfitter',
#   'General',
#   '',
#   ''],
#  ['DOBIJA, JORDAN KRISTOPHER',
#   '199915895',
#   '17/2/2024',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['DONALDSON, MARK ROBERT',
#   '2006685',
#   '2/9/2024',
#   'Gasfitter',
#   'Restricted Automotive LPG',
#   ''],
#  ['DONALDSON, ROBERT JAMES',
#   '199714606',
#   '3/10/2024',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['DONALDSON, ROBERT JAMES',
#   '199714606',
#   '3/10/2024',
#   'Gasfitter',
#   'General',
#   '',
#   ''],
#  ['DONNELLY, BRENDAN', '2009200', '9/10/2022', 'Gasfitter', 'General', ''],
#  ['DONNELLY, GARY',
#   '199414253',
#   '24/7/2024',
#   'Gasfitter',
#   'Restricted Automotive LPG',
#   ''],
#  ['DONNELLY, STEPHEN',
#   '20131110',
#   '20/11/2021',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['DORAHY, JAMES MATTHEW',
#   '2016794',
#   '19/2/2023',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['DOUCH, MITCHELL',
#   '2020755',
#   '29/6/2024',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['DOUGLAS, TIMOTHY JOEL', '2013805', '26/4/2024', 'Gasfitter', 'General', ''],
#  ['DOULGERIS, CONOR MICHAEL',
#   '2016795',
#   '11/6/2022',
#   'Gasfitter',
#   'General',
#   ''],
#  ['DOUST, JOHN WAYNE',
#   '20191165',
#   '20/11/2022',
#   'Gasfitter',
#   'Advanced',
#   '',
#   ''],
#  ['DOUST, JOHN WAYNE',
#   '20191165',
#   '20/11/2022',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['DRAGE, TIMOTHY MICHEAL',
#   '2007498',
#   '20/5/2023',
#   'Gasfitter',
#   'General',
#   ''],
#  ['DRIPS AND DRAINS PLUMBING (ACT) PTY LTD',
#   '2021888',
#   '12/7/2024',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['DRIPS AND DRAINS PLUMBING (ACT) PTY LTD',
#   '2021888',
#   '12/7/2024',
#   'Gasfitter',
#   'General',
#   '',
#   ''],
#  ['DRIPS AND DRAINS PLUMBING PTY LTD',
#   '2016330',
#   '23/4/2022',
#   'Gasfitter',
#   'General',
#   '',
#   ''],
#  ['DRIPS AND DRAINS PLUMBING PTY LTD',
#   '2016330',
#   '23/4/2022',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['DRUHAN, ELLIOT GRAY',
#   '2006924',
#   '22/11/2022',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['DUCKETT, LYELL ANDREW',
#   '2009972',
#   '29/12/2021',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['DUNCAN, ELLIOT JOSHUA',
#   '2018109',
#   '11/1/2024',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['DUNCAN, ELLIOT JOSHUA',
#   '2018109',
#   '11/1/2024',
#   'Gasfitter',
#   'General',
#   '',
#   ''],
#  ['DUNCAN, JASON DONALD',
#   '199714617',
#   '17/5/2022',
#   'Gasfitter',
#   'General',
#   ''],
#  ['DUNCAN, STANLEY ROSS',
#   '199715366',
#   '14/7/2022',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['DUNCAN, STANLEY ROSS',
#   '199715366',
#   '14/7/2022',
#   'Gasfitter',
#   'General',
#   '',
#   ''],
#  ['DUNN, CHRISTOPHER JOHN',
#   '20091092',
#   '25/4/2023',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['DUNN, CHRISTOPHER JOHN',
#   '20091092',
#   '25/4/2023',
#   'Gasfitter',
#   'General',
#   '',
#   ''],
#  ['DURRELL, MARK LEYS',
#   '199314529',
#   '26/4/2022',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['DUX MANUFACTURING LIMITED',
#   '20151230',
#   '3/4/2023',
#   'Gasfitter',
#   'Advanced',
#   ''],
#  ['DWYER, DAVID JOHN',
#   '2006832',
#   '27/7/2023',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['DWYER, IAN',
#   '20181120',
#   '22/6/2022',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['DWYER, IAN', '20181120', '22/6/2022', 'Gasfitter', 'General', '', ''],
#  ['DWYER, PATRICK WILLIAM',
#   '199714750',
#   '6/6/2023',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['DWYER, PATRICK WILLIAM',
#   '199714750',
#   '6/6/2023',
#   'Gasfitter',
#   'General',
#   '',
#   ''],
#  ['DWYER, RORY',
#   '202134',
#   '26/1/2022',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['DZIALOWY, ADRIAN MARK',
#   '20161183',
#   '22/12/2022',
#   'Gasfitter',
#   'General',
#   ''],
#  ['DZIALOWY, MARK', '2013260', '28/3/2022', 'Gasfitter', 'Advanced', ''],
#  ['EAGER, THOMAS',
#   '20191341',
#   '18/12/2021',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['EAGLES, STUART BRIAN',
#   '2008109',
#   '19/7/2023',
#   'Gasfitter',
#   'General',
#   '',
#   ''],
#  ['EAGLES, STUART BRIAN',
#   '2008109',
#   '19/7/2023',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['EASTON, BLAKE',
#   '202129',
#   '13/1/2022',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['EDLINGTON, JAMES ANDREW',
#   '199615254',
#   '30/11/2023',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   'May only provide gasfitting service as an employee'],
#  ['EDWARDS, DANIEL',
#   '2017204',
#   '5/4/2023',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['EDWARDS, DANIEL', '2017204', '5/4/2023', 'Gasfitter', 'General', '', ''],
#  ['EDWARDS, JERAMEY', '2019895', '1/10/2022', 'Gasfitter', 'General', '', ''],
#  ['EDWARDS, JERAMEY',
#   '2019895',
#   '1/10/2022',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['EDWARDS, ROBERT CHARLES',
#   '199714482',
#   '23/1/2024',
#   'Gasfitter',
#   'Advanced',
#   ''],
#  ['EGAN, DEAN DOUGLAS',
#   '20111173',
#   '31/10/2023',
#   'Gasfitter',
#   'Advanced',
#   '',
#   ''],
#  ['EGAN, DEAN DOUGLAS',
#   '20111173',
#   '31/10/2023',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['EGAN, NICHOLAS ADAM',
#   '20121659',
#   '27/4/2024',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['EGAN, RODNEY MICHAEL',
#   '2014697',
#   '7/7/2022',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['EGAN, RODNEY MICHAEL',
#   '2014697',
#   '7/7/2022',
#   'Gasfitter',
#   'LPG Gasfitter (Liquid Phase)',
#   '',
#   ''],
#  ['EL-DAYRI, AHMED',
#   '20201692',
#   '22/12/2021',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['ELDRIDGE, GREGORY JAMES',
#   '200015964',
#   '12/8/2022',
#   'Gasfitter',
#   'Advanced',
#   ''],
#  ['ELFERKH, JEFFERY KAMIL', '2007564', '7/6/2022', 'Gasfitter', 'General', ''],
#  ['ELLIOT, MICHAEL ANDREW',
#   '20111089',
#   '4/9/2023',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['ELLIOT, MICHAEL ANDREW',
#   '20111089',
#   '4/9/2023',
#   'Gasfitter',
#   'General',
#   '',
#   ''],
#  ['ELLIOTT, DAVID ROSS',
#   '199714688',
#   '4/3/2022',
#   'Gasfitter',
#   'Restricted Automotive LPG',
#   '',
#   'Fire Sprinkler work restricted to hydrants, hosereels and backflow'],
#  ['ELLIOTT, DAVID ROSS',
#   '199714688',
#   '4/3/2022',
#   'Gasfitter',
#   'Restricted Automotive NGV',
#   '',
#   'Fire Sprinkler work restricted to hydrants, hosereels and backflow'],
#  ['ELLIOTT, HARRISON WILLIAM',
#   '2021357',
#   '20/4/2022',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['ELMIR, ZAKARIYA', '200316182', '20/2/2022', 'Gasfitter', 'General', ''],
#  ['ELPHICK, ANDREW ROBERT',
#   '2008213',
#   '3/5/2022',
#   'Gasfitter',
#   'General',
#   '',
#   ''],
#  ['ELPHICK, ANDREW ROBERT',
#   '2008213',
#   '3/5/2022',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['ELPHICK, MARK', '20191228', '17/12/2022', 'Gasfitter', 'Advanced', '', ''],
#  ['ELPHICK, MARK',
#   '20191228',
#   '17/12/2022',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['ELWORTHY, MARK ROBERT',
#   '2009486',
#   '18/12/2021',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['EMMERT, BERND', '2017638', '2/8/2023', 'Gasfitter', 'Advanced', ''],
#  ['EMPIRE PLUMBING & DRAINS PTY LTD',
#   '201918',
#   '30/1/2022',
#   'Gasfitter',
#   'General',
#   ''],
#  ['ENGLAND, STEVEN JAMES LESLEY',
#   '2021448',
#   '21/4/2024',
#   'Gasfitter',
#   'Advanced',
#   '',
#   ''],
#  ['ENGLAND, STEVEN JAMES LESLEY',
#   '2021448',
#   '21/4/2024',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['ENHANCED PLUMBING & GAS LTD PTY',
#   '2020516',
#   '6/5/2023',
#   'Gasfitter',
#   'General',
#   ''],
#  ['EPPELSTUN, JOSHUA',
#   '20191200',
#   '18/12/2021',
#   'Gasfitter',
#   'General',
#   '',
#   ''],
#  ['EPPELSTUN, JOSHUA',
#   '20191200',
#   '18/12/2021',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['EQUIPPED PLUMBING PTY LTD',
#   '20211352',
#   '20/9/2024',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['EQUIPPED PLUMBING PTY LTD',
#   '20211352',
#   '20/9/2024',
#   'Gasfitter',
#   'General',
#   '',
#   ''],
#  ['ERMANLI, DYLAN ROBERT',
#   '201376',
#   '1/3/2023',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['ESPLIN, JOHN ANTHONY', '2008735', '3/1/2024', 'Gasfitter', 'Advanced', ''],
#  ['EVANS, BENJAMIN',
#   '2020757',
#   '24/7/2022',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['EVANS, BENJAMIN', '2020757', '24/7/2022', 'Gasfitter', 'Advanced', '', ''],
#  ['EVANS, BRENTON DAVID', '2018880', '25/1/2022', 'Gasfitter', 'Advanced', ''],
#  ['EVANS, DONALD ARTHUR',
#   '199615414',
#   '5/1/2024',
#   'Gasfitter',
#   'Advanced',
#   ''],
#  ['EVANS, PAUL JAMES',
#   '20101480',
#   '9/2/2023',
#   'Gasfitter',
#   'Advanced',
#   '',
#   ''],
#  ['EVANS, PAUL JAMES',
#   '20101480',
#   '9/2/2023',
#   'Gasfitter',
#   'LPG Gasfitter (Liquid Phase)',
#   '',
#   ''],
#  ['EVATT, JAMES STEPHEN',
#   '2006338',
# ...
#   '2015531',
#   '1/9/2023',
#   'Gasfitter',
#   'General',
#   '',
#   ''],
#  ['LANG, HARRISON', '2019585', '30/6/2022', 'Gasfitter', 'General', '', ''],
#  ['LANG, HARRISON',
#   '2019585',
#   '30/6/2022',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['LANG, MATTHEW DAVID', '2012552', '25/10/2022', 'Gasfitter', 'General', ''],
#  ['LANGTRY, BLAKE JOEL', '2017821', '16/10/2021', 'Gasfitter', 'Advanced', ''],
#  ['LAROBINA, RAFFAELE',
#   '199815819',
#   '26/1/2022',
#   'Gasfitter',
#   'General',
#   '',
#   ''],
#  ['LAROBINA, RAFFAELE',
#   '199815819',
#   '26/1/2022',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['LAURENT, BRADLEY JAMES',
#   '2014688',
#   '4/8/2023',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['LAVENDER, BIANCA',
#   '20211368',
#   '20/9/2024',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['LAWLESS, JACOB',
#   '2018381',
#   '20/3/2022',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['LAWRENCE, JOSHUA',
#   '20201106',
#   '30/8/2022',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['LAWSON, MICHAEL JOHN', '2015632', '3/9/2023', 'Gasfitter', 'General', ''],
#  ['LAYOUS, ANTHONY',
#   '2020831',
#   '11/7/2022',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['LAYOUS, ANTHONY', '2020831', '11/7/2022', 'Gasfitter', 'General', '', ''],
#  ['LAZAROU, NICKOLAS', '2010469', '4/6/2022', 'Gasfitter', 'Advanced', ''],
#  ['LAZAROU, WILLIAM', '20151007', '31/10/2021', 'Gasfitter', 'Advanced', ''],
#  ['LEA, HOWARD', '2008209', '20/6/2024', 'Gasfitter', 'General', ''],
#  ['LEAKE, BRUCE WILLIAM',
#   '198515178',
#   '14/5/2023',
#   'Gasfitter',
#   'General',
#   ''],
#  ['LEAKE, JAMES DAVID',
#   '2009262',
#   '28/7/2022',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['LEAKE, JEFFREY REX',
#   '199414491',
#   '15/3/2023',
#   'Gasfitter',
#   'General',
#   '',
#   ''],
#  ['LEAKE, JEFFREY REX',
#   '199414491',
#   '15/3/2023',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['LEAKE, MARC JAMES', '2007535', '17/12/2023', 'Gasfitter', 'Advanced', ''],
#  ['LEAKE, THOMAS JOHN', '2008542', '13/4/2023', 'Gasfitter', 'Advanced', ''],
#  ['LEDBROOK-MILLER, SAMUEL MARK',
#   '20201705',
#   '22/12/2023',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['LEE, NAM GI', '2010730', '23/12/2022', 'Gasfitter', 'Advanced', ''],
#  ['LEE, SUP',
#   '2019256',
#   '7/2/2022',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['LEEMHUIS, MICHAEL JACOB',
#   '199714720',
#   '14/5/2024',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['LEEMHUIS, MICHAEL JACOB',
#   '199714720',
#   '14/5/2024',
#   'Gasfitter',
#   'General',
#   '',
#   ''],
#  ['LEES, ROBERT LEIGHTON',
#   '199714926',
#   '30/11/2022',
#   'Gasfitter',
#   'General',
#   'Includes LPG (Vapour Phase)'],
#  ['LEET, WAYNE',
#   '20191105',
#   '23/11/2022',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['LEIFHEIT, STEVEN ANTHONY',
#   '2014593',
#   '6/6/2023',
#   'Gasfitter',
#   'General',
#   ''],
#  ['LEISHMAN, DARYL EDWARD',
#   '199714097',
#   '28/9/2023',
#   'Gasfitter',
#   'General',
#   'Includes LPG (Vapour Phase)'],
#  ['LEONARD, PAUL GRANT',
#   '199915905',
#   '24/10/2024',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['LEONARD, PAUL GRANT',
#   '199915905',
#   '24/10/2024',
#   'Gasfitter',
#   'General',
#   '',
#   ''],
#  ['LESIPUTTY, LESLIE THOMAS',
#   '199215447',
#   '28/3/2022',
#   'Gasfitter',
#   'Advanced',
#   ''],
#  ['LEWIS, EDWARD WILHELM',
#   '2016289',
#   '1/6/2023',
#   'Gasfitter',
#   'General',
#   '',
#   ''],
#  ['LEWIS, EDWARD WILHELM',
#   '2016289',
#   '1/6/2023',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['LEWIS, JOSHUA MICHAEL', '201244', '9/2/2024', 'Gasfitter', 'General', ''],
#  ['LEWIS, MICHAEL JOHN',
#   '199314286',
#   '26/12/2023',
#   'Gasfitter',
#   'Restricted Automotive LPG',
#   ''],
#  ['LEWKOWICZ, JOHN',
#   '199715312',
#   '30/4/2022',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['LIGACS, BENJAMIN ROBERT',
#   '200116009',
#   '20/7/2022',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['LIGACS, BENJAMIN ROBERT',
#   '200116009',
#   '20/7/2022',
#   'Gasfitter',
#   'General',
#   '',
#   ''],
#  ['LIND, PAUL MARTIN', '201873', '14/3/2024', 'Gasfitter', 'Advanced', ''],
#  ['LIU, DONG',
#   '2021671',
#   '21/6/2024',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['LLOYD, DANIEL JOHN',
#   '2015297',
#   '4/5/2022',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['LLOYD, DANIEL JOHN', '2015297', '4/5/2022', 'Gasfitter', 'General', '', ''],
#  ['LOBB, DAVID GORDON', '200216070', '30/4/2022', 'Gasfitter', 'Advanced', ''],
#  ['LOGAN, CHRISTOPHER',
#   '20201367',
#   '26/1/2022',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['LOGAN, SCOTT', '2020382', '16/4/2023', 'Gasfitter', 'General', '', ''],
#  ['LOGAN, SCOTT',
#   '2020382',
#   '16/4/2023',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['LONERGAN, DAVID BRENDAN',
#   '199414827',
#   '1/7/2022',
#   'Gasfitter',
#   'General',
#   '',
#   ''],
#  ['LONERGAN, DAVID BRENDAN',
#   '199414827',
#   '1/7/2022',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['LONERGAN, JOEL ANTHONY', '2014832', '4/5/2022', 'Gasfitter', 'General', ''],
#  ['LOPEZ, ALEXANDRO', '2012217', '6/7/2022', 'Gasfitter', 'General', '', ''],
#  ['LOPEZ, ALEXANDRO',
#   '2012217',
#   '6/7/2022',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['LOVELOCK, JORDAN RHYS', '201596', '8/7/2024', 'Gasfitter', 'General', ''],
#  ['LOVETT, MICHAEL THOMAS',
#   '2017736',
#   '1/12/2021',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['LOWTH, SIMON JOHN',
#   '199715749',
#   '14/4/2022',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   ''],
#  ['LUIC, THOMAS',
#   '2019119',
#   '27/3/2022',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['LUKASIK, STEFAN', '2005380', '16/3/2024', 'Gasfitter', 'Advanced', ''],
#  ["LUKE HURST'S PLUMBING SOLUTIONS PTY LTD",
#   '201672',
#   '16/11/2022',
#   'Gasfitter',
#   'Advanced',
#   ''],
#  ['LYONS, CHRIS ANDRES',
#   '2007121',
#   '31/8/2024',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['MACAFEE, JAMES ANDREW', '2014902', '5/9/2024', 'Gasfitter', 'General', ''],
#  ['MACCULLAGH, JONATHAN CHARLES',
#   '2011281',
#   '30/11/2021',
#   'Gasfitter',
#   'General',
#   '',
#   ''],
#  ['MACCULLAGH, JONATHAN CHARLES',
#   '2011281',
#   '30/11/2021',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['MACDERMID, RODNEY JOHN',
#   '2012844',
#   '12/8/2022',
#   'Gasfitter',
#   'Advanced',
#   ''],
#  ['MACDONALD, JONATHON', '2018296', '7/9/2023', 'Gasfitter', 'Advanced', ''],
#  ['MADDIGAN, PETER JOHN',
#   '199515527',
#   '9/10/2021',
#   'Gasfitter',
#   'Advanced',
#   ''],
#  ['MAGUIRE COMMERCIAL PLUMBING PTY LTD',
#   '2010351',
#   '23/4/2022',
#   'Gasfitter',
#   'Advanced',
#   '',
#   ''],
#  ['MAGUIRE COMMERCIAL PLUMBING PTY LTD',
#   '2010351',
#   '23/4/2022',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['MAGUIRE, BRIAN EDMUND',
#   '200115993',
#   '8/4/2023',
#   'Gasfitter',
#   'Advanced',
#   'includes LPG Vapour phase'],
#  ['MAGUIRE, MARK LESLIE',
#   '199315311',
#   '18/6/2022',
#   'Gasfitter',
#   'Advanced',
#   ''],
#  ['MAGYAR, TROY STEVEN',
#   '200313338',
#   '14/2/2022',
#   'Gasfitter',
#   'General',
#   '',
#   ''],
#  ['MAGYAR, TROY STEVEN',
#   '200313338',
#   '14/2/2022',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['MAHON, RODNEY GERARD',
#   '199714083',
#   '14/1/2022',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['MAHON, RODNEY GERARD',
#   '199714083',
#   '14/1/2022',
#   'Gasfitter',
#   'General',
#   '',
#   ''],
#  ['MALCOLM, ANDREW JOHN',
#   '2013464',
#   '19/9/2022',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   ''],
#  ['MALONEY, SEAN',
#   '202145',
#   '20/1/2024',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['MANN, GERARD DAVID',
#   '2010446',
#   '17/5/2024',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['MANN, GERARD DAVID',
#   '2010446',
#   '17/5/2024',
#   'Gasfitter',
#   'General',
#   '',
#   ''],
#  ['MARA, SEAN ANDREW',
#   '201762',
#   '15/2/2024',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['MARA, SEAN ANDREW', '201762', '15/2/2024', 'Gasfitter', 'General', '', ''],
#  ['MARGULES, LUKE',
#   '20141115',
#   '15/5/2022',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['MARKAKIS, NICHOLAS',
#   '2018606',
#   '12/10/2021',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['MARKAKIS, NICHOLAS',
#   '2018606',
#   '12/10/2021',
#   'Gasfitter',
#   'General',
#   '',
#   ''],
#  ['MARKLAND, COLIN BRUCE',
#   '199714125',
#   '21/1/2023',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   'Please contact Access Canberra for condition details'],
#  ['MARQUEZ, JAMES FORTUNATO',
#   '20081084',
#   '3/5/2022',
#   'Gasfitter',
#   'General',
#   ''],
#  ['MARSHALL, DEAN GEORGE',
#   '2018457',
#   '14/8/2022',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['MARTIN, ANTHONY DUNCAN',
#   '2017681',
#   '10/8/2023',
#   'Gasfitter',
#   'Advanced',
#   ''],
#  ['MARTIN, DANIEL ALLAN', '2021423', '29/4/2022', 'Gasfitter', 'Advanced', ''],
#  ['MARTIN, MATTHEW PAUL',
#   '20111372',
#   '9/10/2023',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['MARTIN, THOMAS GEOFFREY HOIT',
#   '2007784',
#   '25/8/2022',
#   'Gasfitter',
#   'Advanced',
#   ''],
#  ['MARTINIELLO, DANIEL FRANCIS',
#   '20061143',
#   '25/12/2022',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['MARTINIELLO, DANIEL JAMES',
#   '201437',
#   '8/5/2024',
#   'Gasfitter',
#   'General',
#   ''],
#  ['MARZANO, VINCE',
#   '2006128',
#   '29/3/2023',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['MASSEY, JACK DOUGLAS', '2014963', '24/10/2022', 'Gasfitter', 'General', ''],
#  ['MASSEY, RODNEY ALEXANDER',
#   '199714266',
#   '21/11/2021',
#   'Gasfitter',
#   'General',
#   '',
#   ''],
#  ['MASSEY, RODNEY ALEXANDER',
#   '199714266',
#   '21/11/2021',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['MASTAFLOW PLUMBING SERVICE PTY LTD',
#   '2014689',
#   '13/7/2023',
#   'Gasfitter',
#   'Advanced',
#   ''],
#  ['MATTHEW, KANE TRAVIS', '2017236', '13/12/2023', 'Gasfitter', 'General', ''],
#  ['MAY, RHYS', '2009765', '7/10/2023', 'Gasfitter', 'General', ''],
#  ['MCALLISTER, SIDNEY DAVID',
#   '201697',
#   '27/8/2022',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['MCAULEY, ROBERT LANNY',
#   '199714825',
#   '21/9/2022',
#   'Gasfitter',
#   'General',
#   '',
#   ''],
#  ['MCAULEY, ROBERT LANNY',
#   '199714825',
#   '21/9/2022',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['MCBRIDE, BENJAMIN LINDH',
#   '2013273',
#   '11/11/2021',
#   'Gasfitter',
#   'General',
#   ''],
#  ['MCCANN, MICHAEL',
#   '201989',
#   '29/1/2022',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['MCCARTHY, ROBERT',
#   '2017233',
#   '23/4/2023',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['MCCARTNEY, PATRICK', '2012140', '17/2/2024', 'Gasfitter', 'Advanced', ''],
#  ['MCCAULEY, KENNETH JOHN',
#   '199713951',
#   '4/5/2023',
#   'Gasfitter',
#   'Restricted Automotive LPG',
#   'Restricted to work performed as an employee only. Not able to contract.'],
#  ['MCCOY, ADAM NEVILLE', '2014725', '26/2/2024', 'Gasfitter', 'General', ''],
#  ['MCCOY, TERRY',
#   '199715256',
#   '1/7/2022',
#   'Gasfitter',
#   'General',
#   'Includes LPG (Vapour Phase)'],
#  ['MCDONALD, ANDREW BRYANT',
#   '2016295',
#   '20/9/2022',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['MCDONALD, PERI KNOX',
#   '2013728',
#   '23/9/2024',
#   'Gasfitter',
#   'General',
#   '',
#   ''],
#  ['MCDONALD, PERI KNOX',
#   '2013728',
#   '23/9/2024',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['MCDOUGALL, STEPHEN ROBERT',
#   '199414618',
#   '1/7/2022',
#   'Gasfitter',
#   'General',
#   ''],
#  ['MCENEARNEY, BRENDAN JOSEPH',
#   '2011470',
#   '30/9/2023',
#   'Gasfitter',
#   'Advanced',
#   ''],
#  ['MCEVOY, PETER LAURENCE',
#   '2015528',
#   '21/7/2024',
#   'Gasfitter',
#   'Advanced',
#   ''],
#  ['MCEWEN, TERRENCE JOHN',
#   '2012840',
#   '18/3/2022',
#   'Gasfitter',
#   'Advanced',
#   ''],
#  ['MCGEE, SHANE MATTHEW',
#   '201355',
#   '20/1/2024',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   'Journeyperson can only provide this construction service as an employee under supervision.'],
#  ['MCGIRR, MURRAY LYNDON',
#   '2021883',
#   '12/7/2022',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['MCGRATH, THOMAS CHARLES',
#   '20171057',
#   '12/5/2022',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['MCGRATH, TRAVIS',
#   '2021307',
#   '21/3/2022',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['MCGREGOR, CRAIG ANTHONY',
#   '199714161',
#   '2/3/2023',
#   'Gasfitter',
#   'Advanced',
#   ''],
#  ['MCINERNY, MATTHEW THOMAS',
#   '2014820',
#   '21/6/2024',
#   'Gasfitter',
#   'General',
#   ''],
#  ['MCINTOSH, KYEL', '2019870', '13/7/2023', 'Gasfitter', 'Advanced', ''],
#  ['MCINTYRE, LOUIS',
#   '2019107',
#   '12/2/2022',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['MCINTYRE, LOUIS', '2019107', '12/2/2022', 'Gasfitter', 'General', '', ''],
#  ['MCKEOUGH, ALLAN JOSEPH',
#   '2011435',
#   '24/5/2022',
#   'Gasfitter',
#   'Restricted Automotive LPG',
#   ''],
#  ['MCLARTY, RHYS', '2006298', '2/5/2024', 'Gasfitter', 'Advanced', ''],
#  ['MCLEAN, ANDREW', '2008684', '4/7/2022', 'Gasfitter', 'General', ''],
#  ['MCLEAN, STEVEN ANTHONY',
#   '2013189',
#   '14/5/2022',
#   'Gasfitter',
#   'General',
#   '',
#   ''],
#  ['MCLEAN, STEVEN ANTHONY',
#   '2013189',
#   '14/5/2022',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['MCMAHON, PETER FRANCIS',
#   '199114609',
#   '1/6/2023',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['MCMULLEN, MARK ANTHONY',
#   '199414992',
#   '2/6/2024',
#   'Gasfitter',
#   'General',
#   '',
#   ''],
#  ['MCMULLEN, MARK ANTHONY',
#   '199414992',
#   '2/6/2024',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['MCNEILL, PAUL RICHARD', '2014605', '8/12/2022', 'Gasfitter', 'General', ''],
#  ['MCPHAIL, JESSE', '2014715', '29/3/2024', 'Gasfitter', 'General', ''],
#  ['MCPHERSON, JAMES LACHLAN',
#   '20151067',
#   '18/11/2022',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['MCQUADE, PAUL', '20191147', '21/11/2022', 'Gasfitter', 'Advanced', ''],
#  ['MCREYNOLDS, ANDREW', '20121001', '9/3/2024', 'Gasfitter', 'General', ''],
#  ['MCREYNOLDS, DAVID GERARD',
#   '199715161',
#   '16/12/2022',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['MCREYNOLDS, DAVID GERARD',
#   '199715161',
#   '16/12/2022',
#   'Gasfitter',
#   'General',
#   '',
#   ''],
#  ['MCSPEERIN, ROBERT JOHN',
#   '199414164',
#   '30/5/2024',
#   'Gasfitter',
#   'General',
#   '',
#   ''],
#  ['MCSPEERIN, ROBERT JOHN',
#   '199414164',
#   '30/5/2024',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['MEANY, PHILIP JOHN',
#   '2013283',
#   '27/3/2022',
#   'Gasfitter',
#   'General',
#   '',
#   ''],
#  ['MEANY, PHILIP JOHN',
#   '2013283',
#   '27/3/2022',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['MEIKLEJOHN, GAVIN EDWARD GEORGE',
#   '20141145',
#   '28/2/2022',
#   'Gasfitter',
#   'General',
#   ''],
#  ['MERCIECA, JOSEPH ANTHONY',
#   '199714621',
#   '16/7/2022',
#   'Gasfitter',
#   'General',
#   '',
#   ''],
#  ['MERCIECA, JOSEPH ANTHONY',
#   '199714621',
#   '16/7/2022',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['MERCURI, DOMENICO', '2009802', '4/9/2024', 'Gasfitter', 'Advanced', ''],
#  ['MERRIGAN, SEAN',
#   '2021946',
#   '23/7/2024',
#   'Gasfitter',
#   'Journeyperson Gasfitter',
#   ''],
#  ['MICHELUTTI, CRAIG ALICK',
#   '20081045',
#   '5/12/2023',
#   'Gasfitter',
#   'Advanced',
#   ''],
#  ['MIKIC, BOBBY', '199714862', '28/5/2022', 'Gasfitter', 'Advanced', ''],
#  ['MIKKELSEN, DAVID', '2021229', '17/3/2024', 'Gasfitter', 'General', '', ''],
#  ['MIKKELSEN, DAVID',
#   '2021229',
#   '17/3/2024',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['MILICEVIC, DANIEL', '2006255', '7/5/2022', 'Gasfitter', 'General', ''],
#  ['MILLER, ANDREW JAMES',
#   '200116034',
#   '23/7/2023',
#   'Gasfitter',
#   'Advanced',
#   'Includes LPG Vapour Phase under/below 21 KPA.'],
#  ['MILLER, LAWRENCE JEFFERY',
#   '2006339',
#   '15/5/2022',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['MILLER, LAWRENCE JEFFERY',
#   '2006339',
#   '15/5/2022',
#   'Gasfitter',
#   'General',
#   '',
#   ''],
#  ['MILLS, BRAYDEN GEOFFREY',
#   '2006143',
#   '2/5/2024',
#   'Gasfitter',
#   'LPG Gasfitter (Vapour Phase)',
#   '',
#   ''],
#  ['MILLS, BRAYDEN GEOFFREY',
#   '2006143',
#   '2/5/2024',
#   'Gasfitter',
#   'General',
#   '',
#   ''],
#  ...]

# %%
licensee_detail[0]
# Out:
# ['A & A HOTWATER & GAS SOLUTIONS PTY LTD',
#  '20191321',
#  '2/2/2024',
#  'LPG Gasfitter (Vapour Phase)',
#  'Gasfitter',
#  '',
#  '']

# %%
len(licensee_detail)
# Out:
# 1669

# %% [markdown]
# # Creating the final dataframe by zipping all the attribute's lists

# %%
df = pd.DataFrame(licensee_detail, columns = ['Name', 'License number','Expiry Date','Class description','Occupation','x1','x2'])
 
# print dataframe.
df
# Out:
#                                                Name License number  \
# 0            A & A HOTWATER & GAS SOLUTIONS PTY LTD       20191321
# 1            A & A HOTWATER & GAS SOLUTIONS PTY LTD       20191321
# 2                               A & K (ACT) PTY LTD        2016855
# 3                     A PLUS PLUMBING (ACT) PTY LTD        2016683
# 4                              ABBEY, DAMIEN LETTON      200216119
# 5                              ABBEY, DAMIEN LETTON      200216119
# 6                 ABDEL RAHMAN, MUDATHIR NOURIN ALI       20201405
# 7                                     ABSOLOM, ALEX        2021915
# 8                          ACKLAND, CHRISTOPHER LEE        2014830
# 9                                      ADAMS, JAMES        2021668
# 10    ADVANCED PLUMBING & DRAINS (CANBERRA) PTY LTD        2017904
# 11                                 AGGARWAL, SURESH          20151
# 12                           AGOSTINO, ALEX DOMINIC       20121662
# 13                                  AL-KULABI, SAIF        2020367
# 14                                  AL-KULABI, SAIF        2020367
# 15                                AL-ZAHROUT, BRAKH       20211300
# 16                 ALL GAS PLUMBING REPAIRS PTY LTD          20208
# 17                 ALL GAS PLUMBING REPAIRS PTY LTD          20208
# 18                             ALLEN, GAVAN CHARLES       20151235
# 19                             ALLEN, GERARD THOMAS       20101061
# 20                            ALLEN, MATHEW CHARLES      200428226
# 21                              AMEY, BRETT RICHARD      199915913
# 22                       AMEY, SAMUEL LESLIE THOMAS      200216054
# 23                              ANDERSON, DEAN JOHN      199214659
# 24                            ANDREW, SCOTT MATTHEW        2010188
# 25                            ANDREW, SCOTT MATTHEW        2010188
# 26                             ANDREWS, JUSTIN PAUL      200416233
# 27                             ANDREWS, JUSTIN PAUL      200416233
# 28                                 ANTONAKOS, CHRIS      199714524
# 29                                     APAP, DANIEL        2021843
# ...                                             ...            ...
# 1639                    WOODBRIDGE, MATTHEW STEPHEN      199815827
# 1640                         WOODBURY, MALCOLM JOHN      199714937
# 1641                            WOODFORD, RYAN SEAN        2016267
# 1642                                WOODS, BENJAMIN       20071006
# 1643                                WOODS, BENJAMIN       20071006
# 1644                                  WOODS, ELLIOT       20201163
# 1645                        WOODWARD, ADAM KINGSLEY      199714141
# 1646                        WOODWARD, ADAM KINGSLEY      199714141
# 1647                          WOODWARD, MARK VICTOR      200316156
# 1648                                    WRIGHT, BEN        2021343
# 1649                          WRIGHT, JAMES BERNARD        2009649
# 1650                          WRIGHT, JAMES BERNARD        2009649
# 1651                                  WRIGHT, OSCAR        2020897
# 1652                         WRIGHT, WILLIAM JOSEPH        2014616
# 1653                         WRIGHT, WILLIAM JOSEPH        2014616
# 1654                        WROE, CARRINGTON ROBERT        2007277
# 1655                        WROE, CARRINGTON ROBERT        2007277
# 1656                                  WYBORN, ETHAN       20181262
# 1657                                  WYBORN, ETHAN       20181262
# 1658                                   WYBURN, SEAN        2017261
# 1659                            XL PLUMBING PTY LTD        2008404
# 1660                            XL PLUMBING PTY LTD        2008404
# 1661              YOUR LOCAL PLUMBING GROUP PTY LTD        2016603
# 1662                                 ZAMMIT, EDWARD      199613986
# 1663                                   ZHANG, CHENG        2021181
# 1664                            ZINGLEMANN, GREGORY       20211069
# 1665                            ZINGLEMANN, GREGORY       20211069
# 1666                             ZORZI, LUKE SAMUEL        2016890
# 1667                           ZOUCH, GEORGE ANDREW         201583
# 1668                           ZOUCH, GEORGE ANDREW         201583
#
#      Expiry Date             Class description                    Occupation  \
# 0       2/2/2024  LPG Gasfitter (Vapour Phase)                     Gasfitter
# 1       2/2/2024                       General                     Gasfitter
# 2      13/9/2022                       General                     Gasfitter
# 3      17/8/2022                      Advanced                     Gasfitter
# 4      17/2/2024                       General                     Gasfitter
# 5      17/2/2024  LPG Gasfitter (Vapour Phase)                     Gasfitter
# 6     31/10/2023       Journeyperson Gasfitter                     Gasfitter
# 7      27/7/2024       Journeyperson Gasfitter                     Gasfitter
# 8       5/4/2023                       General                     Gasfitter
# 9       8/8/2024       Journeyperson Gasfitter                     Gasfitter
# 10     6/11/2023                     Gasfitter                      Advanced
# 11     20/7/2023                     Gasfitter                       General
# 12     16/1/2022                     Gasfitter       Journeyperson Gasfitter
# 13     16/4/2022                     Gasfitter                       General
# 14     16/4/2022                     Gasfitter  LPG Gasfitter (Vapour Phase)
# 15     13/9/2024                     Gasfitter       Journeyperson Gasfitter
# 16      6/2/2023                     Gasfitter                       General
# 17      6/2/2023                     Gasfitter  LPG Gasfitter (Vapour Phase)
# 18     16/5/2023                     Gasfitter       Journeyperson Gasfitter
# 19    11/10/2021                     Gasfitter                       General
# 20      9/5/2022                     Gasfitter       Journeyperson Gasfitter
# 21     1/10/2023                     Gasfitter       Journeyperson Gasfitter
# 22      3/2/2023                     Gasfitter                       General
# 23     19/8/2024                     Gasfitter                      Advanced
# 24    12/10/2021                     Gasfitter                       General
# 25    12/10/2021                     Gasfitter  LPG Gasfitter (Vapour Phase)
# 26     28/5/2023                     Gasfitter                       General
# 27     28/5/2023                     Gasfitter  LPG Gasfitter (Vapour Phase)
# 28      1/5/2022                     Gasfitter                       General
# 29     23/7/2024                     Gasfitter                      Advanced
# ...          ...                           ...                           ...
# 1639    2/5/2024                     Gasfitter  LPG Gasfitter (Vapour Phase)
# 1640   10/2/2022                     Gasfitter  LPG Gasfitter (Vapour Phase)
# 1641    1/6/2024                     Gasfitter                       General
# 1642    3/4/2022                     Gasfitter  LPG Gasfitter (Vapour Phase)
# 1643    3/4/2022                     Gasfitter                       General
# 1644    9/9/2023                     Gasfitter                      Advanced
# 1645   31/8/2023                     Gasfitter                       General
# 1646   31/8/2023                     Gasfitter  LPG Gasfitter (Vapour Phase)
# 1647   28/7/2024                     Gasfitter                       General
# 1648   22/3/2024                     Gasfitter                      Advanced
# 1649   25/9/2023                     Gasfitter                       General
# 1650   25/9/2023                     Gasfitter  LPG Gasfitter (Vapour Phase)
# 1651   18/6/2024                     Gasfitter       Journeyperson Gasfitter
# 1652   11/7/2023                     Gasfitter                      Advanced
# 1653   11/7/2023                     Gasfitter  LPG Gasfitter (Vapour Phase)
# 1654  30/10/2021                     Gasfitter  LPG Gasfitter (Vapour Phase)
# 1655  30/10/2021                     Gasfitter                       General
# 1656   29/3/2023                     Gasfitter  LPG Gasfitter (Vapour Phase)
# 1657   29/3/2023                     Gasfitter                       General
# 1658    7/9/2022                     Gasfitter                       General
# 1659   10/6/2022                     Gasfitter                       General
# 1660   10/6/2022                     Gasfitter  LPG Gasfitter (Vapour Phase)
# 1661   22/7/2022                     Gasfitter                      Advanced
# 1662  15/10/2022                     Gasfitter                      Advanced
# 1663    9/2/2024                     Gasfitter       Journeyperson Gasfitter
# 1664   27/8/2024                     Gasfitter  LPG Gasfitter (Vapour Phase)
# 1665   27/8/2024                     Gasfitter                       General
# 1666  16/12/2022                     Gasfitter                       General
# 1667    1/6/2024                     Gasfitter                       General
# 1668    1/6/2024                     Gasfitter  LPG Gasfitter (Vapour Phase)
#
#        x1    x2
# 0
# 1
# 2          None
# 3          None
# 4
# 5
# 6          None
# 7          None
# 8          None
# 9          None
# 10         None
# 11         None
# 12         None
# 13
# 14
# 15         None
# 16
# 17
# 18         None
# 19         None
# 20         None
# 21         None
# 22         None
# 23         None
# 24
# 25
# 26
# 27
# 28         None
# 29
# ...   ...   ...
# 1639
# 1640       None
# 1641       None
# 1642
# 1643
# 1644       None
# 1645
# 1646
# 1647       None
# 1648       None
# 1649
# 1650
# 1651       None
# 1652
# 1653
# 1654
# 1655
# 1656
# 1657
# 1658       None
# 1659
# 1660
# 1661       None
# 1662       None
# 1663       None
# 1664  NIL   NIL
# 1665  NIL   NIL
# 1666       None
# 1667
# 1668
#
# [1669 rows x 7 columns]

# %%
df = df.drop(['x1','x2'], 1)
df
# Out:
#                                                Name License number  \
# 0            A & A HOTWATER & GAS SOLUTIONS PTY LTD       20191321
# 1            A & A HOTWATER & GAS SOLUTIONS PTY LTD       20191321
# 2                               A & K (ACT) PTY LTD        2016855
# 3                     A PLUS PLUMBING (ACT) PTY LTD        2016683
# 4                              ABBEY, DAMIEN LETTON      200216119
# 5                              ABBEY, DAMIEN LETTON      200216119
# 6                 ABDEL RAHMAN, MUDATHIR NOURIN ALI       20201405
# 7                                     ABSOLOM, ALEX        2021915
# 8                          ACKLAND, CHRISTOPHER LEE        2014830
# 9                                      ADAMS, JAMES        2021668
# 10    ADVANCED PLUMBING & DRAINS (CANBERRA) PTY LTD        2017904
# 11                                 AGGARWAL, SURESH          20151
# 12                           AGOSTINO, ALEX DOMINIC       20121662
# 13                                  AL-KULABI, SAIF        2020367
# 14                                  AL-KULABI, SAIF        2020367
# 15                                AL-ZAHROUT, BRAKH       20211300
# 16                 ALL GAS PLUMBING REPAIRS PTY LTD          20208
# 17                 ALL GAS PLUMBING REPAIRS PTY LTD          20208
# 18                             ALLEN, GAVAN CHARLES       20151235
# 19                             ALLEN, GERARD THOMAS       20101061
# 20                            ALLEN, MATHEW CHARLES      200428226
# 21                              AMEY, BRETT RICHARD      199915913
# 22                       AMEY, SAMUEL LESLIE THOMAS      200216054
# 23                              ANDERSON, DEAN JOHN      199214659
# 24                            ANDREW, SCOTT MATTHEW        2010188
# 25                            ANDREW, SCOTT MATTHEW        2010188
# 26                             ANDREWS, JUSTIN PAUL      200416233
# 27                             ANDREWS, JUSTIN PAUL      200416233
# 28                                 ANTONAKOS, CHRIS      199714524
# 29                                     APAP, DANIEL        2021843
# ...                                             ...            ...
# 1639                    WOODBRIDGE, MATTHEW STEPHEN      199815827
# 1640                         WOODBURY, MALCOLM JOHN      199714937
# 1641                            WOODFORD, RYAN SEAN        2016267
# 1642                                WOODS, BENJAMIN       20071006
# 1643                                WOODS, BENJAMIN       20071006
# 1644                                  WOODS, ELLIOT       20201163
# 1645                        WOODWARD, ADAM KINGSLEY      199714141
# 1646                        WOODWARD, ADAM KINGSLEY      199714141
# 1647                          WOODWARD, MARK VICTOR      200316156
# 1648                                    WRIGHT, BEN        2021343
# 1649                          WRIGHT, JAMES BERNARD        2009649
# 1650                          WRIGHT, JAMES BERNARD        2009649
# 1651                                  WRIGHT, OSCAR        2020897
# 1652                         WRIGHT, WILLIAM JOSEPH        2014616
# 1653                         WRIGHT, WILLIAM JOSEPH        2014616
# 1654                        WROE, CARRINGTON ROBERT        2007277
# 1655                        WROE, CARRINGTON ROBERT        2007277
# 1656                                  WYBORN, ETHAN       20181262
# 1657                                  WYBORN, ETHAN       20181262
# 1658                                   WYBURN, SEAN        2017261
# 1659                            XL PLUMBING PTY LTD        2008404
# 1660                            XL PLUMBING PTY LTD        2008404
# 1661              YOUR LOCAL PLUMBING GROUP PTY LTD        2016603
# 1662                                 ZAMMIT, EDWARD      199613986
# 1663                                   ZHANG, CHENG        2021181
# 1664                            ZINGLEMANN, GREGORY       20211069
# 1665                            ZINGLEMANN, GREGORY       20211069
# 1666                             ZORZI, LUKE SAMUEL        2016890
# 1667                           ZOUCH, GEORGE ANDREW         201583
# 1668                           ZOUCH, GEORGE ANDREW         201583
#
#      Expiry Date             Class description                    Occupation
# 0       2/2/2024  LPG Gasfitter (Vapour Phase)                     Gasfitter
# 1       2/2/2024                       General                     Gasfitter
# 2      13/9/2022                       General                     Gasfitter
# 3      17/8/2022                      Advanced                     Gasfitter
# 4      17/2/2024                       General                     Gasfitter
# 5      17/2/2024  LPG Gasfitter (Vapour Phase)                     Gasfitter
# 6     31/10/2023       Journeyperson Gasfitter                     Gasfitter
# 7      27/7/2024       Journeyperson Gasfitter                     Gasfitter
# 8       5/4/2023                       General                     Gasfitter
# 9       8/8/2024       Journeyperson Gasfitter                     Gasfitter
# 10     6/11/2023                     Gasfitter                      Advanced
# 11     20/7/2023                     Gasfitter                       General
# 12     16/1/2022                     Gasfitter       Journeyperson Gasfitter
# 13     16/4/2022                     Gasfitter                       General
# 14     16/4/2022                     Gasfitter  LPG Gasfitter (Vapour Phase)
# 15     13/9/2024                     Gasfitter       Journeyperson Gasfitter
# 16      6/2/2023                     Gasfitter                       General
# 17      6/2/2023                     Gasfitter  LPG Gasfitter (Vapour Phase)
# 18     16/5/2023                     Gasfitter       Journeyperson Gasfitter
# 19    11/10/2021                     Gasfitter                       General
# 20      9/5/2022                     Gasfitter       Journeyperson Gasfitter
# 21     1/10/2023                     Gasfitter       Journeyperson Gasfitter
# 22      3/2/2023                     Gasfitter                       General
# 23     19/8/2024                     Gasfitter                      Advanced
# 24    12/10/2021                     Gasfitter                       General
# 25    12/10/2021                     Gasfitter  LPG Gasfitter (Vapour Phase)
# 26     28/5/2023                     Gasfitter                       General
# 27     28/5/2023                     Gasfitter  LPG Gasfitter (Vapour Phase)
# 28      1/5/2022                     Gasfitter                       General
# 29     23/7/2024                     Gasfitter                      Advanced
# ...          ...                           ...                           ...
# 1639    2/5/2024                     Gasfitter  LPG Gasfitter (Vapour Phase)
# 1640   10/2/2022                     Gasfitter  LPG Gasfitter (Vapour Phase)
# 1641    1/6/2024                     Gasfitter                       General
# 1642    3/4/2022                     Gasfitter  LPG Gasfitter (Vapour Phase)
# 1643    3/4/2022                     Gasfitter                       General
# 1644    9/9/2023                     Gasfitter                      Advanced
# 1645   31/8/2023                     Gasfitter                       General
# 1646   31/8/2023                     Gasfitter  LPG Gasfitter (Vapour Phase)
# 1647   28/7/2024                     Gasfitter                       General
# 1648   22/3/2024                     Gasfitter                      Advanced
# 1649   25/9/2023                     Gasfitter                       General
# 1650   25/9/2023                     Gasfitter  LPG Gasfitter (Vapour Phase)
# 1651   18/6/2024                     Gasfitter       Journeyperson Gasfitter
# 1652   11/7/2023                     Gasfitter                      Advanced
# 1653   11/7/2023                     Gasfitter  LPG Gasfitter (Vapour Phase)
# 1654  30/10/2021                     Gasfitter  LPG Gasfitter (Vapour Phase)
# 1655  30/10/2021                     Gasfitter                       General
# 1656   29/3/2023                     Gasfitter  LPG Gasfitter (Vapour Phase)
# 1657   29/3/2023                     Gasfitter                       General
# 1658    7/9/2022                     Gasfitter                       General
# 1659   10/6/2022                     Gasfitter                       General
# 1660   10/6/2022                     Gasfitter  LPG Gasfitter (Vapour Phase)
# 1661   22/7/2022                     Gasfitter                      Advanced
# 1662  15/10/2022                     Gasfitter                      Advanced
# 1663    9/2/2024                     Gasfitter       Journeyperson Gasfitter
# 1664   27/8/2024                     Gasfitter  LPG Gasfitter (Vapour Phase)
# 1665   27/8/2024                     Gasfitter                       General
# 1666  16/12/2022                     Gasfitter                       General
# 1667    1/6/2024                     Gasfitter                       General
# 1668    1/6/2024                     Gasfitter  LPG Gasfitter (Vapour Phase)
#
# [1669 rows x 5 columns]

# %% [markdown]
# ## Checking the shape (rows & columns) of the final dataframe

# %%
df.shape
# Out:
# (1669, 5)

# %% [markdown]
# ## Converting the dataframe into a `.csv` file

# %%
df.to_csv('ACT_Gasfitter.csv')
