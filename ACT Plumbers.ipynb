# %% [markdown]
# # Importing essential libraries

# %%
import selenium
import time
from selenium import webdriver

from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# # Loading the `Webdriver`

# %%
driver = webdriver.Chrome()

# %% [markdown]
# # Getting the access of `ACT Plumber's` official website

# %%
driver.get('https://www.accesscanberra.act.gov.au/s/public-registers/construction-licences?registerid=m0I4a00000000CMEAY')
time.sleep(2)

# %% [markdown]
# # Finding number of pages of the data

# %%
pages=driver.find_element_by_xpath('/html/body/div[4]/div[3]/div/div/div/div/div/div/div[3]/div/div/div[2]/c-cxs-public-registers-construction/div/div[6]/p').text
pages
# Out:
# 'Page: 1 / 215'

# %%
numbers = []
for word in pages.split():
    if word.isdigit():
        numbers.append(int(word))
print(numbers[1])
# Out:
# 215

# %% [markdown]
# # Main program to get `Headers` & `all the data rows` of just the `first page`

# %%
page_source = driver.page_source
soup =  BeautifulSoup(page_source, 'lxml')
            
data = [j.text for j in soup.findAll('td')]
data
all_names= []
all_names= data[::5]
all_names
# Out:
# ['360 DEGREE FIRE PTY LTD',
#  'A & A HOTWATER & GAS SOLUTIONS PTY LTD',
#  'A & K (ACT) PTY LTD',
#  'A & K (ACT) PTY LTD',
#  'A PLUS PLUMBING (ACT) PTY LTD',
#  'A PLUS PLUMBING (ACT) PTY LTD',
#  'AAA ABOVE BOARD PLUMBING PTY LTD',
#  'AAA ABOVE BOARD PLUMBING PTY LTD',
#  'ABBEY, DAMIEN LETTON',
#  'ABDEL RAHMAN, MUDATHIR NOURIN ALI']

# %%
data= data[3:]
#data
all_class_desc= []
all_class_desc= data[::5]
all_class_desc
# Out:
# ['Water Supply Plumber',
#  'Water Supply Plumber',
#  'Sanitary Plumber',
#  'Water Supply Plumber',
#  'Water Supply Plumber',
#  'Sanitary Plumber',
#  'Water Supply Plumber',
#  'Sanitary Plumber',
#  'Sanitary Plumber',
#  'Journeyperson Plumber']

# %% [markdown]
# # Generating xpaths for all the records in any page

# %%
xpaths=[]
for j in range(1,11): #creating xpaths: just change span[i] to click different links
    xpaths.append('/html/body/div[4]/div[3]/div/div/div/div/div/div/div[3]/div/div/div[2]/c-cxs-public-registers-construction/div/div[5]/div/div/table/tbody/tr['+str(j) + ']/td[5]/lightning-button/button')
print(xpaths)
# Out:
# ['/html/body/div[4]/div[3]/div/div/div/div/div/div/div[3]/div/div/div[2]/c-cxs-public-registers-construction/div/div[5]/div/div/table/tbody/tr[1]/td[5]/lightning-button/button', '/html/body/div[4]/div[3]/div/div/div/div/div/div/div[3]/div/div/div[2]/c-cxs-public-registers-construction/div/div[5]/div/div/table/tbody/tr[2]/td[5]/lightning-button/button', '/html/body/div[4]/div[3]/div/div/div/div/div/div/div[3]/div/div/div[2]/c-cxs-public-registers-construction/div/div[5]/div/div/table/tbody/tr[3]/td[5]/lightning-button/button', '/html/body/div[4]/div[3]/div/div/div/div/div/div/div[3]/div/div/div[2]/c-cxs-public-registers-construction/div/div[5]/div/div/table/tbody/tr[4]/td[5]/lightning-button/button', '/html/body/div[4]/div[3]/div/div/div/div/div/div/div[3]/div/div/div[2]/c-cxs-public-registers-construction/div/div[5]/div/div/table/tbody/tr[5]/td[5]/lightning-button/button', '/html/body/div[4]/div[3]/div/div/div/div/div/div/div[3]/div/div/div[2]/c-cxs-public-registers-construction/div/div[5]/div/div/table/tbody/tr[6]/td[5]/lightning-button/button', '/html/body/div[4]/div[3]/div/div/div/div/div/div/div[3]/div/div/div[2]/c-cxs-public-registers-construction/div/div[5]/div/div/table/tbody/tr[7]/td[5]/lightning-button/button', '/html/body/div[4]/div[3]/div/div/div/div/div/div/div[3]/div/div/div[2]/c-cxs-public-registers-construction/div/div[5]/div/div/table/tbody/tr[8]/td[5]/lightning-button/button', '/html/body/div[4]/div[3]/div/div/div/div/div/div/div[3]/div/div/div[2]/c-cxs-public-registers-construction/div/div[5]/div/div/table/tbody/tr[9]/td[5]/lightning-button/button', '/html/body/div[4]/div[3]/div/div/div/div/div/div/div[3]/div/div/div[2]/c-cxs-public-registers-construction/div/div[5]/div/div/table/tbody/tr[10]/td[5]/lightning-button/button']

# %%
licensee_detail=[]
for k in range(1,11): #getting the details of every license in a combination
    driver.find_element_by_xpath(xpaths[k-1]).click()
    #time.sleep(1)
    
    page_source = driver.page_source
    soup = BeautifulSoup(page_source, 'lxml')
            
    det= [j.text for j in soup.findAll('td')]
    det=det[1:]
    #det

    ab=[]
    ab=det[::2]

    ab.insert(0,all_names[k-1])
    ab.insert(3,all_class_desc[k-1])
    ab

    licensee_detail.append(ab)
    
    
    
    
    
    driver.find_element_by_xpath('/html/body/div[4]/div[3]/div/div/div/div/div/div/div[3]/div/div/div[2]/c-cxs-public-registers-construction/div/div/lightning-button/button').click()

# %%
licensee_detail
# Out:
# [['360 DEGREE FIRE PTY LTD',
#   '2017990',
#   'Plumber',
#   'Water Supply Plumber',
#   '22 January 2023',
#   ''],
#  ['A & A HOTWATER & GAS SOLUTIONS PTY LTD',
#   '20191321',
#   'Plumber',
#   'Water Supply Plumber',
#   '2 February 2024',
#   ''],
#  ['A & K (ACT) PTY LTD',
#   '2016855',
#   'Plumber',
#   'Sanitary Plumber',
#   '13 September 2022',
#   '',
#   ''],
#  ['A & K (ACT) PTY LTD',
#   '2016855',
#   'Plumber',
#   'Water Supply Plumber',
#   '13 September 2022',
#   '',
#   ''],
#  ['A PLUS PLUMBING (ACT) PTY LTD',
#   '2016683',
#   'Plumber',
#   'Water Supply Plumber',
#   '17 August 2022',
#   '',
#   ''],
#  ['A PLUS PLUMBING (ACT) PTY LTD',
#   '2016683',
#   'Plumber',
#   'Sanitary Plumber',
#   '17 August 2022',
#   '',
#   ''],
#  ['AAA ABOVE BOARD PLUMBING PTY LTD',
#   '2018299',
#   'Plumber',
#   'Water Supply Plumber',
#   '31 May 2022',
#   '',
#   ''],
#  ['AAA ABOVE BOARD PLUMBING PTY LTD',
#   '2018299',
#   'Plumber',
#   'Sanitary Plumber',
#   '31 May 2022',
#   '',
#   ''],
#  ['ABBEY, DAMIEN LETTON',
#   '200216119',
#   'Plumber',
#   'Sanitary Plumber',
#   '17 February 2024',
#   'Certified to test Backflow Prevention Devices.'],
#  ['ABDEL RAHMAN, MUDATHIR NOURIN ALI',
#   '20201405',
#   'Plumber',
#   'Journeyperson Plumber',
#   '31 October 2023',
#   '']]

# %%
licensee_detail[1]
# Out:
# ['A & A HOTWATER & GAS SOLUTIONS PTY LTD',
#  '20191321',
#  'Plumber',
#  'Water Supply Plumber',
#  '2 February 2024',
#  '']

# %%
len(licensee_detail)
# Out:
# 10

# %% [markdown]
# # Main program to get `Headers` & `all the data rows` of all the pages till 215

# %%
for i in range(1, numbers[1]):
    
    driver.find_element_by_xpath('/html/body/div[4]/div[3]/div/div/div/div/div/div/div[3]/div/div/div[2]/c-cxs-public-registers-construction/div/div[6]/div[4]/button').click()
    time.sleep(1)
    
    page_source = driver.page_source
    soup =  BeautifulSoup(page_source, 'lxml')       
    data = [j.text for j in soup.findAll('td')]
    #data
    all_names= []
    all_names= data[::5]
    #all_names
    data= data[3:]
    #data
    all_class_desc= []
    all_class_desc= data[::5]
    #all_class_desc
    
    
    for k in range(1,11): 
        
        driver.find_element_by_xpath(xpaths[k-1]).click()
        #time.sleep(1)
    
        page_source = driver.page_source
        soup = BeautifulSoup(page_source, 'lxml')
            
        det= [l.text for l in soup.findAll('td')]
        det=det[1:]
        #det

        ab=[]
        ab=det[::2]

        ab.insert(0,all_class_desc[k-1])
        ab.insert(0,all_names[k-1])
        #ab

        licensee_detail.append(ab)
    
        driver.find_element_by_xpath('/html/body/div[4]/div[3]/div/div/div/div/div/div/div[3]/div/div/div[2]/c-cxs-public-registers-construction/div/div/lightning-button/button').click()
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-48-3b8625a92e02> in <module>
#      20     for k in range(1,11):
#      21
# ---> 22         driver.find_element_by_xpath(xpaths[k-1]).click()
#      23         #time.sleep(1)
#      24
#
# ~/anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in find_element_by_xpath(self, xpath)
#     392             element = driver.find_element_by_xpath('//div/td[1]')
#     393         """
# --> 394         return self.find_element(by=By.XPATH, value=xpath)
#     395
#     396     def find_elements_by_xpath(self, xpath):
#
# ~/anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in find_element(self, by, value)
#     976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
# --> 978             'value': value})['value']
#     979
#     980     def find_elements(self, by=By.ID, value=None):
#
# ~/anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~/anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/div[4]/div[3]/div/div/div/div/div/div/div[3]/div/div/div[2]/c-cxs-public-registers-construction/div/div[5]/div/div/table/tbody/tr[8]/td[5]/lightning-button/button"}
#   (Session info: chrome=93.0.4577.82)

# %%
det
# Out:
# ['201583',
#  'Occupation',
#  'Plumber',
#  'Expiry date',
#  '1 June 2024',
#  'Water Supply Plumber',
#  '',
#  'Sanitary Plumber',
#  '']

# %%
ab
# Out:
# ['ZOUCH, GEORGE ANDREW',
#  'Sanitary Plumber',
#  '201583',
#  'Plumber',
#  '1 June 2024',
#  '',
#  '']

# %%
licensee_detail
# Out:
# [['360 DEGREE FIRE PTY LTD',
#   '2017990',
#   'Plumber',
#   'Water Supply Plumber',
#   '22 January 2023',
#   ''],
#  ['A & A HOTWATER & GAS SOLUTIONS PTY LTD',
#   '20191321',
#   'Plumber',
#   'Water Supply Plumber',
#   '2 February 2024',
#   ''],
#  ['A & K (ACT) PTY LTD',
#   '2016855',
#   'Plumber',
#   'Sanitary Plumber',
#   '13 September 2022',
#   '',
#   ''],
#  ['A & K (ACT) PTY LTD',
#   '2016855',
#   'Plumber',
#   'Water Supply Plumber',
#   '13 September 2022',
#   '',
#   ''],
#  ['A PLUS PLUMBING (ACT) PTY LTD',
#   '2016683',
#   'Plumber',
#   'Water Supply Plumber',
#   '17 August 2022',
#   '',
#   ''],
#  ['A PLUS PLUMBING (ACT) PTY LTD',
#   '2016683',
#   'Plumber',
#   'Sanitary Plumber',
#   '17 August 2022',
#   '',
#   ''],
#  ['AAA ABOVE BOARD PLUMBING PTY LTD',
#   '2018299',
#   'Plumber',
#   'Water Supply Plumber',
#   '31 May 2022',
#   '',
#   ''],
#  ['AAA ABOVE BOARD PLUMBING PTY LTD',
#   '2018299',
#   'Plumber',
#   'Sanitary Plumber',
#   '31 May 2022',
#   '',
#   ''],
#  ['ABBEY, DAMIEN LETTON',
#   '200216119',
#   'Plumber',
#   'Sanitary Plumber',
#   '17 February 2024',
#   'Certified to test Backflow Prevention Devices.'],
#  ['ABDEL RAHMAN, MUDATHIR NOURIN ALI',
#   '20201405',
#   'Plumber',
#   'Journeyperson Plumber',
#   '31 October 2023',
#   ''],
#  ['ABSOLOM, ALEX',
#   'Journeyperson Plumber',
#   '2021915',
#   'Plumber',
#   '27 July 2024',
#   ''],
#  ['ACKLAND, CHRISTOPHER LEE',
#   'Water Supply Plumber',
#   '2014830',
#   'Plumber',
#   '5 April 2023',
#   'Certified to test Backflow Prevention Devices',
#   ''],
#  ['ACKLAND, CHRISTOPHER LEE',
#   'Sanitary Plumber',
#   '2014830',
#   'Plumber',
#   '5 April 2023',
#   'Certified to test Backflow Prevention Devices',
#   ''],
#  ['ADAMS, JAMES',
#   'Journeyperson Plumber',
#   '2021668',
#   'Plumber',
#   '8 August 2024',
#   ''],
#  ['ADENS-KANTS, MARK',
#   'Water Supply Plumber',
#   '2017882',
#   'Plumber',
#   '19 June 2023',
#   '',
#   ''],
#  ['ADENS-KANTS, MARK',
#   'Sanitary Plumber',
#   '2017882',
#   'Plumber',
#   '19 June 2023',
#   '',
#   ''],
#  ['ADVANCED PLUMBING & DRAINS (CANBERRA) PTY LTD',
#   'Sanitary Plumber',
#   '2017904',
#   'Plumber',
#   '6 November 2023',
#   'Certified to test Backflow Prevention Devices',
#   ''],
#  ['ADVANCED PLUMBING & DRAINS (CANBERRA) PTY LTD',
#   'Water Supply Plumber',
#   '2017904',
#   'Plumber',
#   '6 November 2023',
#   'Certified to test Backflow Prevention Devices',
#   ''],
#  ['AGGARWAL, SURESH',
#   'Sanitary Plumber',
#   '20151',
#   'Plumber',
#   '20 July 2023',
#   '',
#   ''],
#  ['AGGARWAL, SURESH',
#   'Water Supply Plumber',
#   '20151',
#   'Plumber',
#   '20 July 2023',
#   '',
#   ''],
#  ['AGIUS, MICHAEL',
#   'Sanitary Plumber',
#   '199815867',
#   'Plumber',
#   '26 September 2021',
#   'Certified to test Backflow Prevention Devices.',
#   ''],
#  ['AGIUS, MICHAEL',
#   'Water Supply Plumber',
#   '199815867',
#   'Plumber',
#   '26 September 2021',
#   'Certified to test Backflow Prevention Devices.',
#   ''],
#  ['AGOSTINO, ALEX DOMINIC',
#   'Journeyperson Fire Sprinkler Fitter',
#   '20121662',
#   'Plumber',
#   '16 January 2022',
#   'Journeyperson Fire Sprinkler Fitter - Restricted to fire sprikler work only as an employee under supervision',
#   ''],
#  ['AGOSTINO, ALEX DOMINIC',
#   'Journeyperson Plumber',
#   '20121662',
#   'Plumber',
#   '16 January 2022',
#   'Journeyperson Fire Sprinkler Fitter - Restricted to fire sprikler work only as an employee under supervision',
#   ''],
#  ['AL-KULABI, SAIF',
#   'Water Supply Plumber',
#   '2020367',
#   'Plumber',
#   '16 April 2022',
#   '',
#   ''],
#  ['AL-KULABI, SAIF',
#   'Sanitary Plumber',
#   '2020367',
#   'Plumber',
#   '16 April 2022',
#   '',
#   ''],
#  ['AL-ZAHROUT, BRAKH',
#   'Journeyperson Plumber',
#   '20211300',
#   'Plumber',
#   '13 September 2024',
#   ''],
#  ['ALL GAS PLUMBING REPAIRS PTY LTD',
#   'Sanitary Plumber',
#   '20208',
#   'Plumber',
#   '6 February 2023',
#   '',
#   ''],
#  ['ALL GAS PLUMBING REPAIRS PTY LTD',
#   'Water Supply Plumber',
#   '20208',
#   'Plumber',
#   '6 February 2023',
#   '',
#   ''],
#  ['ALLAN, JAMES GORDON',
#   'Sanitary Plumber',
#   '199715300',
#   'Plumber',
#   '7 March 2023',
#   '',
#   ''],
#  ['ALLAN, JAMES GORDON',
#   'Water Supply Plumber',
#   '199715300',
#   'Plumber',
#   '7 March 2023',
#   '',
#   ''],
#  ['ALLEN, GAVAN CHARLES',
#   'Journeyperson Plumber',
#   '20151235',
#   'Plumber',
#   '16 May 2023',
#   ''],
#  ['ALLEN, GERARD THOMAS',
#   'Sanitary Plumber',
#   '20101061',
#   'Plumber',
#   '11 October 2021',
#   'Certified to test Backflow Prevention Devices.'],
#  ['ALLEN, GORDON GEORGE',
#   'Water Supply Plumber',
#   '199315514',
#   'Plumber',
#   '13 November 2021',
#   '',
#   ''],
#  ['ALLEN, GORDON GEORGE',
#   'Sanitary Plumber',
#   '199315514',
#   'Plumber',
#   '13 November 2021',
#   '',
#   ''],
#  ['ALLEN, MATHEW CHARLES',
#   'Journeyperson Plumber',
#   '200428226',
#   'Plumber',
#   '9 May 2022',
#   ''],
#  ['AMEY, BRETT RICHARD',
#   'Sanitary Plumber',
#   '199915913',
#   'Plumber',
#   '1 October 2023',
#   '',
#   ''],
#  ['AMEY, BRETT RICHARD',
#   'Water Supply Plumber',
#   '199915913',
#   'Plumber',
#   '1 October 2023',
#   '',
#   ''],
#  ['AMEY, SAMUEL LESLIE THOMAS',
#   'Water Supply Plumber',
#   '200216054',
#   'Plumber',
#   '3 February 2023',
#   '',
#   ''],
#  ['AMEY, SAMUEL LESLIE THOMAS',
#   'Sanitary Plumber',
#   '200216054',
#   'Plumber',
#   '3 February 2023',
#   '',
#   ''],
#  ['ANDERSON, DEAN JOHN',
#   'Water Supply Plumber',
#   '199214659',
#   'Plumber',
#   '19 August 2024',
#   '',
#   'Certified to test Backflow Prevention Devices.'],
#  ['ANDERSON, DEAN JOHN',
#   'Sanitary Plumber',
#   '199214659',
#   'Plumber',
#   '19 August 2024',
#   '',
#   'Certified to test Backflow Prevention Devices.'],
#  ['ANDREW, SCOTT MATTHEW',
#   'Water Supply Plumber',
#   '2010188',
#   'Plumber',
#   '12 October 2021',
#   '',
#   ''],
#  ['ANDREW, SCOTT MATTHEW',
#   'Sanitary Plumber',
#   '2010188',
#   'Plumber',
#   '12 October 2021',
#   '',
#   ''],
#  ['ANDREWS, JUSTIN PAUL',
#   'Water Supply Plumber',
#   '200416233',
#   'Plumber',
#   '28 May 2023',
#   '',
#   ''],
#  ['ANDREWS, JUSTIN PAUL',
#   'Sanitary Plumber',
#   '200416233',
#   'Plumber',
#   '28 May 2023',
#   '',
#   ''],
#  ['ANGELOSKI, VASIL',
#   'Journeyperson Plumber',
#   '20121402',
#   'Plumber',
#   '31 July 2023',
#   'Certified to test Backflow Prevention Devices. Can only provide this construction service as an employee under supervision.'],
#  ['ANTONAKOS, CHRIS',
#   'Sanitary Plumber',
#   '199714524',
#   'Plumber',
#   '1 May 2022',
#   '',
#   ''],
#  ['ANTONAKOS, CHRIS',
#   'Water Supply Plumber',
#   '199714524',
#   'Plumber',
#   '1 May 2022',
#   '',
#   ''],
#  ['APAP, DANIEL',
#   'Water Supply Plumber',
#   '2021843',
#   'Plumber',
#   '23 July 2024',
#   '',
#   ''],
#  ['APAP, DANIEL',
#   'Sanitary Plumber',
#   '2021843',
#   'Plumber',
#   '23 July 2024',
#   '',
#   ''],
#  ['APATHY, JAMIE',
#   'Journeyperson Plumber',
#   '20201612',
#   'Plumber',
#   '1 December 2021',
#   ''],
#  ['AQUA BROTHERS PLUMBING PTY LTD',
#   'Water Supply Plumber',
#   '20171009',
#   'Plumber',
#   '27 June 2022',
#   '',
#   ''],
#  ['AQUA BROTHERS PLUMBING PTY LTD',
#   'Sanitary Plumber',
#   '20171009',
#   'Plumber',
#   '27 June 2022',
#   '',
#   ''],
#  ['AQUAFLO IRRIGATION PTY LTD',
#   'Irrigation Plumber',
#   '20181150',
#   'Plumber',
#   '1 November 2021',
#   ''],
#  ['ARCIDIACONO, MICHAEL',
#   'Sanitary Plumber',
#   '2008895',
#   'Plumber',
#   '20 May 2023',
#   'Please contact Access Canberra for condition details'],
#  ['ARGENTI, JOSHUA JOSEPH',
#   'Sanitary Plumber',
#   '2017895',
#   'Plumber',
#   '4 April 2023',
#   '',
#   ''],
#  ['ARGENTI, JOSHUA JOSEPH',
#   'Water Supply Plumber',
#   '2017895',
#   'Plumber',
#   '4 April 2023',
#   '',
#   ''],
#  ['ARGYLE, JAMES',
#   'Sanitary Plumber',
#   '20091222',
#   'Plumber',
#   '16 October 2021',
#   '',
#   ''],
#  ['ARGYLE, JAMES',
#   'Water Supply Plumber',
#   '20091222',
#   'Plumber',
#   '16 October 2021',
#   '',
#   ''],
#  ['ARNOTT, MATTHEW SHANE',
#   'Sanitary Plumber',
#   '20141072',
#   'Plumber',
#   '10 December 2021',
#   '',
#   ''],
#  ['ARNOTT, MATTHEW SHANE',
#   'Water Supply Plumber',
#   '20141072',
#   'Plumber',
#   '10 December 2021',
#   '',
#   ''],
#  ['AROUND THE BEND PLUMBING & GAS FITTING PTY LIMITED',
#   'Sanitary Plumber',
#   '2009837',
#   'Plumber',
#   '13 September 2024',
#   'Also valid for Back Flow Prevention.'],
#  ['ARRANZ, RAPHAEL ASTERIO',
#   'Water Supply Plumber',
#   '2011571',
#   'Plumber',
#   '31 May 2024',
#   'Restricted to Fire Protection Sprinkler Systems.'],
#  ['ASHBY, SAMUEL',
#   'Journeyperson Plumber',
#   '2021396',
#   'Plumber',
#   '25 March 2022',
#   ''],
#  ['ASHLIN, DYLAN',
#   'Water Supply Plumber',
#   '201942',
#   'Plumber',
#   '17 January 2022',
#   'Also valid to Certified Backflow Prevention Devices',
#   ''],
#  ['ASHLIN, DYLAN',
#   'Sanitary Plumber',
#   '201942',
#   'Plumber',
#   '17 January 2022',
#   'Also valid to Certified Backflow Prevention Devices',
#   ''],
#  ['ASKEW, SAMUEL',
#   'Journeyperson Plumber',
#   '20201115',
#   'Plumber',
#   '5 November 2021',
#   ''],
#  ['ATKIN, SHANE',
#   'Sanitary Plumber',
#   '2009215',
#   'Plumber',
#   '15 November 2022',
#   '',
#   ''],
#  ['ATKIN, SHANE',
#   'Water Supply Plumber',
#   '2009215',
#   'Plumber',
#   '15 November 2022',
#   '',
#   ''],
#  ['AUALIITIA, JUAN PAUL',
#   'Water Supply Plumber',
#   '2016433',
#   'Plumber',
#   '26 May 2022',
#   '',
#   ''],
#  ['AUALIITIA, JUAN PAUL',
#   'Sanitary Plumber',
#   '2016433',
#   'Plumber',
#   '26 May 2022',
#   '',
#   ''],
#  ['AURORA & CO PLUMBING PTY LTD',
#   'Sanitary Plumber',
#   '2019360',
#   'Plumber',
#   '23 April 2022',
#   'Certified to test Backflow Prevention Devices',
#   ''],
#  ['AURORA & CO PLUMBING PTY LTD',
#   'Water Supply Plumber',
#   '2019360',
#   'Plumber',
#   '23 April 2022',
#   'Certified to test Backflow Prevention Devices',
#   ''],
#  ['AUZMENDI, ADAM',
#   'Sanitary Plumber',
#   '2008711',
#   'Plumber',
#   '9 April 2022',
#   'Certified to test Backflow Prevention Devices.',
#   ''],
#  ['AUZMENDI, ADAM',
#   'Water Supply Plumber',
#   '2008711',
#   'Plumber',
#   '9 April 2022',
#   'Certified to test Backflow Prevention Devices.',
#   ''],
#  ['AVAGE, IAN DAVID',
#   'Water Supply Plumber',
#   '20111474',
#   'Plumber',
#   '11 August 2023',
#   '',
#   ''],
#  ['AVAGE, IAN DAVID',
#   'Sanitary Plumber',
#   '20111474',
#   'Plumber',
#   '11 August 2023',
#   '',
#   ''],
#  ['AWAD, TONY',
#   'Sanitary Plumber',
#   '2010953',
#   'Plumber',
#   '19 June 2022',
#   '',
#   ''],
#  ['AWAD, TONY',
#   'Water Supply Plumber',
#   '2010953',
#   'Plumber',
#   '19 June 2022',
#   '',
#   ''],
#  ['AXIS PLUMBING ACT PTY LTD',
#   'Sanitary Plumber',
#   '2005368',
#   'Plumber',
#   '23 May 2023',
#   '',
#   ''],
#  ['AXIS PLUMBING ACT PTY LTD',
#   'Water Supply Plumber',
#   '2005368',
#   'Plumber',
#   '23 May 2023',
#   '',
#   ''],
#  ['AZZILLA, AARON DEAN',
#   'Journeyperson Plumber',
#   '201523',
#   'Plumber',
#   '8 September 2023',
#   ''],
#  ['BACKHOUSE, BRETT MICHAEL',
#   'Sanitary Plumber',
#   '2008856',
#   'Plumber',
#   '20 August 2024',
#   '',
#   ''],
#  ['BACKHOUSE, BRETT MICHAEL',
#   'Water Supply Plumber',
#   '2008856',
#   'Plumber',
#   '20 August 2024',
#   '',
#   ''],
#  ['BACON, ALEXANDER',
#   'Water Supply Plumber',
#   '20151034',
#   'Plumber',
#   '21 February 2022',
#   ''],
#  ['BACON, LIAM',
#   'Journeyperson Plumber',
#   '201968',
#   'Plumber',
#   '27 January 2022',
#   ''],
#  ['BADDOCK, DANNY GREGORY',
#   'Sanitary Plumber',
#   '201754',
#   'Plumber',
#   '1 June 2022',
#   '',
#   ''],
#  ['BADDOCK, DANNY GREGORY',
#   'Water Supply Plumber',
#   '201754',
#   'Plumber',
#   '1 June 2022',
#   '',
#   ''],
#  ['BAILEY, IAN WILLIAM',
#   'Water Supply Plumber',
#   '199613974',
#   'Plumber',
#   '20 January 2023',
#   '',
#   ''],
#  ['BAILEY, IAN WILLIAM',
#   'Sanitary Plumber',
#   '199613974',
#   'Plumber',
#   '20 January 2023',
#   '',
#   ''],
#  ['BAKER, STEPHEN JOSEPH',
#   'Journeyperson Plumber',
#   '199314399',
#   'Plumber',
#   '30 March 2022',
#   'Please contact Access Canberra for condition details'],
#  ['BAKER, ZACHARY JOHN',
#   'Sanitary Plumber',
#   '2016741',
#   'Plumber',
#   '20 February 2022',
#   '',
#   ''],
#  ['BAKER, ZACHARY JOHN',
#   'Water Supply Plumber',
#   '2016741',
#   'Plumber',
#   '20 February 2022',
#   '',
#   ''],
#  ['BALMER, ROBERT',
#   'Sanitary Plumber',
#   '2021228',
#   'Plumber',
#   '1 April 2024',
#   'Certified to Test Backflow Prevention Devices.',
#   ''],
#  ['BALMER, ROBERT',
#   'Water Supply Plumber',
#   '2021228',
#   'Plumber',
#   '1 April 2024',
#   'Certified to Test Backflow Prevention Devices.',
#   ''],
#  ['BALTAJI, AYMAN',
#   'Journeyperson Plumber',
#   '20201616',
#   'Plumber',
#   '8 December 2021',
#   ''],
#  ['BANKS, THOMAS',
#   'Journeyperson Plumber',
#   '20201674',
#   'Plumber',
#   '22 December 2023',
#   ''],
#  ['BARAC, DENIS',
#   'Journeyperson Plumber',
#   '20131202',
#   'Plumber',
#   '9 August 2022',
#   ''],
#  ['BARKER, JOSHUA ARNOLD',
#   'Journeyperson Plumber',
#   '2021506',
#   'Plumber',
#   '3 May 2022',
#   ''],
#  ['BARLOW, MARK ANDREW',
#   'Sanitary Plumber',
#   '2006466',
#   'Plumber',
#   '18 May 2022',
#   'Restricted to work performed as an employee only. Not able to contract. Certified to test Backflow Prevention Devices.',
#   'Restricted to work performed as an employee only. Not able to contract.'],
#  ['BARLOW, MARK ANDREW',
#   'Water Supply Plumber',
#   '2006466',
#   'Plumber',
#   '18 May 2022',
#   'Restricted to work performed as an employee only. Not able to contract. Certified to test Backflow Prevention Devices.',
#   'Restricted to work performed as an employee only. Not able to contract.'],
#  ['BARNES, DALE WILLIAM',
#   'Sanitary Plumber',
#   '202154',
#   'Plumber',
#   '22 February 2022',
#   '',
#   ''],
#  ['BARNES, DALE WILLIAM',
#   'Water Supply Plumber',
#   '202154',
#   'Plumber',
#   '22 February 2022',
#   '',
#   ''],
#  ['BARNES, DAVID LINDSAY',
#   'Sanitary Plumber',
#   '199715467',
#   'Plumber',
#   '1 October 2021',
#   '',
#   ''],
#  ['BARNES, DAVID LINDSAY',
#   'Water Supply Plumber',
#   '199715467',
#   'Plumber',
#   '1 October 2021',
#   '',
#   ''],
#  ['BAROUDI, ADAM',
#   'Journeyperson Plumber',
#   '2021468',
#   'Plumber',
#   '16 April 2022',
#   ''],
#  ['BARRON, THOMAS RAYMOND',
#   'Sanitary Plumber',
#   '199714113',
#   'Plumber',
#   '21 June 2024',
#   '',
#   ''],
#  ['BARRON, THOMAS RAYMOND',
#   'Water Supply Plumber',
#   '199714113',
#   'Plumber',
#   '21 June 2024',
#   '',
#   ''],
#  ['BARTHOLOMEUSZ, MATTHEW THOMAS',
#   'Sanitary Plumber',
#   '2015300',
#   'Plumber',
#   '19 November 2023',
#   '',
#   ''],
#  ['BARTHOLOMEUSZ, MATTHEW THOMAS',
#   'Water Supply Plumber',
#   '2015300',
#   'Plumber',
#   '19 November 2023',
#   '',
#   ''],
#  ['BARTLEET, CHRISTOPHER MICHAEL',
#   'Water Supply Plumber',
#   '2016277',
#   'Plumber',
#   '2 May 2022',
#   ''],
#  ['BATEMAN, LUKE',
#   'Sanitary Plumber',
#   '2012632',
#   'Plumber',
#   '22 May 2022',
#   ''],
#  ['BAXTER, ROBERT JOHN',
#   'Sanitary Plumber',
#   '199714418',
#   'Plumber',
#   '24 March 2024',
#   '',
#   ''],
#  ['BAXTER, ROBERT JOHN',
#   'Water Supply Plumber',
#   '199714418',
#   'Plumber',
#   '24 March 2024',
#   '',
#   ''],
#  ['BAY & COAST PLUMBING PTY LTD',
#   'Sanitary Plumber',
#   '2015965',
#   'Plumber',
#   '22 October 2021',
#   '',
#   ''],
#  ['BAY & COAST PLUMBING PTY LTD',
#   'Water Supply Plumber',
#   '2015965',
#   'Plumber',
#   '22 October 2021',
#   '',
#   ''],
#  ['BAYLEY, LUKE MICHAEL',
#   'Journeyperson Plumber',
#   '2008271',
#   'Plumber',
#   '30 September 2023',
#   ''],
#  ['BAYLISS, ANDREW',
#   'Water Supply Plumber',
#   '2014885',
#   'Plumber',
#   '19 August 2024',
#   ''],
#  ['BAYOT, BEN WILLIAM',
#   'Water Supply Plumber',
#   '2017504',
#   'Plumber',
#   '28 June 2023',
#   '',
#   ''],
#  ['BAYOT, BEN WILLIAM',
#   'Sanitary Plumber',
#   '2017504',
#   'Plumber',
#   '28 June 2023',
#   '',
#   ''],
#  ['BEARD, PETER',
#   'Water Supply Plumber',
#   '2021707',
#   'Plumber',
#   '22 June 2024',
#   '',
#   ''],
#  ['BEARD, PETER',
#   'Sanitary Plumber',
#   '2021707',
#   'Plumber',
#   '22 June 2024',
#   '',
#   ''],
#  ['BEATH, ROBERT JOHN',
#   'Sanitary Plumber',
#   '2015667',
#   'Plumber',
#   '26 July 2023',
#   '',
#   'Certified to test Backflow Prevention Devices.'],
#  ['BEATH, ROBERT JOHN',
#   'Water Supply Plumber',
#   '2015667',
#   'Plumber',
#   '26 July 2023',
#   '',
#   'Certified to test Backflow Prevention Devices.'],
#  ['BELL, JAMIE ALLEN',
#   'Water Supply Plumber',
#   '20101127',
#   'Plumber',
#   '19 November 2023',
#   '',
#   ''],
#  ['BELL, JAMIE ALLEN',
#   'Sanitary Plumber',
#   '20101127',
#   'Plumber',
#   '19 November 2023',
#   '',
#   ''],
#  ['BELL, JOSHUA JOHN',
#   'Water Supply Plumber',
#   '20181092',
#   'Plumber',
#   '22 October 2022',
#   '',
#   ''],
#  ['BELL, JOSHUA JOHN',
#   'Sanitary Plumber',
#   '20181092',
#   'Plumber',
#   '22 October 2022',
#   '',
#   ''],
#  ['BENNETT, JASON BRADLEY THOMAS',
#   'Sanitary Plumber',
#   '2012212',
#   'Plumber',
#   '29 September 2023',
#   ''],
#  ['BENNETT, MARCUS KANE',
#   'Journeyperson Plumber',
#   '20101079',
#   'Plumber',
#   '17 September 2021',
#   ''],
#  ['BERENBAK, JUSTIN',
#   'Journeyperson Plumber',
#   '2011764',
#   'Plumber',
#   '24 June 2023',
#   ''],
#  ['BERESFORD, PAUL ANDREW',
#   'Sanitary Plumber',
#   '199713929',
#   'Plumber',
#   '24 December 2023',
#   '',
#   ''],
#  ['BERESFORD, PAUL ANDREW',
#   'Water Supply Plumber',
#   '199713929',
#   'Plumber',
#   '24 December 2023',
#   '',
#   ''],
#  ['BERRY, JUSTIN',
#   'Sanitary Plumber',
#   '2019590',
#   'Plumber',
#   '11 July 2023',
#   '',
#   ''],
#  ['BERRY, JUSTIN',
#   'Water Supply Plumber',
#   '2019590',
#   'Plumber',
#   '11 July 2023',
#   '',
#   ''],
#  ['BERRY, TIAGO',
#   'Sanitary Plumber',
#   '2018655',
#   'Plumber',
#   '14 October 2021',
#   ''],
#  ['BERTOSA, WILLIAM ANTON',
#   'Sanitary Plumber',
#   '199714679',
#   'Plumber',
#   '12 May 2023',
#   '',
#   ''],
#  ['BERTOSA, WILLIAM ANTON',
#   'Water Supply Plumber',
#   '199714679',
#   'Plumber',
#   '12 May 2023',
#   '',
#   ''],
#  ['BEVAN, DYLAN JAY',
#   'Journeyperson Plumber',
#   '2017464',
#   'Plumber',
#   '8 June 2023',
#   ''],
#  ['BIANCHINI, ROBERT JOHN',
#   'Water Supply Plumber',
#   '199614695',
#   'Plumber',
#   '28 April 2024',
#   '',
#   ''],
#  ['BIANCHINI, ROBERT JOHN',
#   'Sanitary Plumber',
#   '199614695',
#   'Plumber',
#   '28 April 2024',
#   '',
#   ''],
#  ['BINETTI, ANTHONY',
#   'Journeyperson Plumber',
#   '200416190',
#   'Plumber',
#   '26 April 2024',
#   'Please contact Access Canberra for condition details'],
#  ['BIONDA, KELVIN',
#   'Water Supply Plumber',
#   '2010627',
#   'Plumber',
#   '24 April 2023',
#   '',
#   ''],
#  ['BIONDA, KELVIN',
#   'Sanitary Plumber',
#   '2010627',
#   'Plumber',
#   '24 April 2023',
#   '',
#   ''],
#  ['BIRD, CODIE WALTER',
#   'Sanitary Plumber',
#   '2016160',
#   'Plumber',
#   '23 September 2022',
#   '',
#   ''],
#  ['BIRD, CODIE WALTER',
#   'Water Supply Plumber',
#   '2016160',
#   'Plumber',
#   '23 September 2022',
#   '',
#   ''],
#  ['BLACK, HARRY',
#   'Journeyperson Plumber',
#   '199415448',
#   'Plumber',
#   '25 June 2022',
#   ''],
#  ['BLACKER, MICHAEL DOUGLAS',
#   'Sanitary Plumber',
#   '2014660',
#   'Plumber',
#   '1 July 2023',
#   ''],
#  ['BLACKMORE, JASON',
#   'Journeyperson Plumber',
#   '20201422',
#   'Plumber',
#   '23 October 2023',
#   ''],
#  ['BLADEN, MICHAEL FRANCIS',
#   'Sanitary Plumber',
#   '199414703',
#   'Plumber',
#   '9 June 2022',
#   ''],
#  ['BLAIR, JAMES JOHN',
#   'Sanitary Plumber',
#   '2009986',
#   'Plumber',
#   '16 July 2024',
#   '',
#   'Certified to test backflow prevention devices'],
#  ['BLAIR, JAMES JOHN',
#   'Water Supply Plumber',
#   '2009986',
#   'Plumber',
#   '16 July 2024',
#   '',
#   'Certified to test backflow prevention devices'],
#  ['BLAKE, RYAN',
#   'Water Supply Plumber',
#   '2014353',
#   'Plumber',
#   '13 January 2024',
#   '',
#   ''],
#  ['BLAKE, RYAN',
#   'Sanitary Plumber',
#   '2014353',
#   'Plumber',
#   '13 January 2024',
#   '',
#   ''],
#  ['BLAKENEY, DANE THOMAS',
#   'Journeyperson Fire Sprinkler Fitter',
#   '2020683',
#   'Plumber',
#   '17 June 2023',
#   ''],
#  ['BLANCHARD, PATRICK JAMES',
#   'Sanitary Plumber',
#   '200216108',
#   'Plumber',
#   '4 February 2023',
#   '',
#   ''],
#  ['BLANCHARD, PATRICK JAMES',
#   'Water Supply Plumber',
#   '200216108',
#   'Plumber',
#   '4 February 2023',
#   '',
#   ''],
#  ['BLANKENSTEIN, JOHN',
#   'Water Supply Plumber',
#   '2009158',
#   'Plumber',
#   '2 November 2021',
#   '',
#   ''],
#  ['BLANKENSTEIN, JOHN',
#   'Sanitary Plumber',
#   '2009158',
#   'Plumber',
#   '2 November 2021',
#   '',
#   ''],
#  ['BLAYDEN, SAM ANDREW',
#   'Water Supply Plumber',
#   '2012793',
#   'Plumber',
#   '24 November 2022',
#   '',
#   'Certified to test Backflow Prevention Devices.'],
#  ['BLAYDEN, SAM ANDREW',
#   'Sanitary Plumber',
#   '2012793',
#   'Plumber',
#   '24 November 2022',
#   '',
#   'Certified to test Backflow Prevention Devices.'],
#  ['BLEWETT, JAMES',
#   'Journeyperson Plumber',
#   '2020171',
#   'Plumber',
#   '12 February 2023',
#   ''],
#  ['BLEWITT, GARRY',
#   'Sanitary Plumber',
#   '199715812',
#   'Plumber',
#   '8 March 2023',
#   '',
#   ''],
#  ['BLEWITT, GARRY',
#   'Water Supply Plumber',
#   '199715812',
#   'Plumber',
#   '8 March 2023',
#   '',
#   ''],
#  ['BLOODWORTH, BRIAN JAMES',
#   'Water Supply Plumber',
#   '199714802',
#   'Plumber',
#   '16 March 2023',
#   '',
#   ''],
#  ['BLOODWORTH, BRIAN JAMES',
#   'Sanitary Plumber',
#   '199714802',
#   'Plumber',
#   '16 March 2023',
#   '',
#   ''],
#  ['BLOODWORTH, JAMES MORGAN',
#   'Water Supply Plumber',
#   '2014348',
#   'Plumber',
#   '23 January 2022',
#   'Also valid for Backflow Prevention Testing.',
#   ''],
#  ['BLOODWORTH, JAMES MORGAN',
#   'Sanitary Plumber',
#   '2014348',
#   'Plumber',
#   '23 January 2022',
#   'Also valid for Backflow Prevention Testing.',
#   ''],
#  ['BLOODWORTH, NICHOLAS JOHN',
#   'Journeyperson Plumber',
#   '2016709',
#   'Plumber',
#   '27 January 2022',
#   ''],
#  ['BLOYE, STEVEN MARK',
#   'Water Supply Plumber',
#   '199414846',
#   'Plumber',
#   '13 December 2022',
#   '',
#   ''],
#  ['BLOYE, STEVEN MARK',
#   'Sanitary Plumber',
#   '199414846',
#   'Plumber',
#   '13 December 2022',
#   '',
#   ''],
#  ['BLUNDELL, KYLE JORDAN',
#   'Journeyperson Plumber',
#   '20121181',
#   'Plumber',
#   '6 May 2022',
#   ''],
#  ['BLUNDELL, WADE',
#   'Sanitary Plumber',
#   '20151076',
#   'Plumber',
#   '21 March 2022',
#   '',
#   ''],
#  ['BLUNDELL, WADE',
#   'Water Supply Plumber',
#   '20151076',
#   'Plumber',
#   '21 March 2022',
#   '',
#   ''],
#  ['BM PLUMBING & DRAINAGE PTY LIMITED',
#   'Sanitary Plumber',
#   '2019187',
#   'Plumber',
#   '1 April 2023',
#   ''],
#  ['BOLAND, TODD ASHLEY',
#   'Water Supply Plumber',
#   '2012857',
#   'Plumber',
#   '28 July 2023',
#   '',
#   ''],
#  ['BOLAND, TODD ASHLEY',
#   'Sanitary Plumber',
#   '2012857',
#   'Plumber',
#   '28 July 2023',
#   '',
#   ''],
#  ['BOLJKOVAC, BAILEY',
#   'Journeyperson Plumber',
#   '2021272',
#   'Plumber',
#   '4 March 2024',
#   ''],
#  ['BOOTH, TIMOTHY PAUL',
#   'Water Supply Plumber',
#   '2015385',
#   'Plumber',
#   '2 October 2021',
#   '',
#   ''],
#  ['BOOTH, TIMOTHY PAUL',
#   'Sanitary Plumber',
#   '2015385',
#   'Plumber',
#   '2 October 2021',
#   '',
#   ''],
#  ['BORRMAN, BARDO',
#   'Water Supply Plumber',
#   '20131306',
#   'Plumber',
#   '11 March 2024',
#   '',
#   ''],
#  ['BORRMAN, BARDO',
#   'Sanitary Plumber',
#   '20131306',
#   'Plumber',
#   '11 March 2024',
#   '',
#   ''],
#  ['BOSOTAS, TIMOTHY JOHN',
#   'Journeyperson Plumber',
#   '20181061',
#   'Plumber',
#   '26 February 2022',
#   ''],
#  ['BOSWELL, DANIEL JOHN',
#   'Journeyperson Plumber',
#   '2017486',
#   'Plumber',
#   '28 July 2023',
#   ''],
#  ['BOTHAMLEY, DANIEL WAYNE',
#   'Water Supply Plumber',
#   '2020161',
#   'Plumber',
#   '25 February 2023',
#   '',
#   ''],
#  ['BOTHAMLEY, DANIEL WAYNE',
#   'Sanitary Plumber',
#   '2020161',
#   'Plumber',
#   '25 February 2023',
#   '',
#   ''],
#  ['BOUNDY, NOAHTA',
#   'Journeyperson Plumber',
#   '20201423',
#   'Plumber',
#   '21 October 2021',
#   ''],
#  ['BOWDEN, ZACHERY',
#   'Water Supply Plumber',
#   '2016519',
#   'Plumber',
#   '9 August 2022',
#   '',
#   ''],
#  ['BOWDEN, ZACHERY',
#   'Sanitary Plumber',
#   '2016519',
#   'Plumber',
#   '11 August 2022',
#   '',
#   ''],
#  ['BOWIE, PETER IGNATIUS',
#   'Sanitary Plumber',
#   '198714858',
#   'Plumber',
#   '12 July 2024',
#   '',
#   ''],
#  ['BOWIE, PETER IGNATIUS',
#   'Water Supply Plumber',
#   '198714858',
#   'Plumber',
#   '12 July 2024',
#   '',
#   ''],
#  ['BOYTON, BENJAMIN JAMES',
#   'Sanitary Plumber',
#   '20111151',
#   'Plumber',
#   '16 February 2022',
#   ''],
#  ['BOYTON, CHARLIE JOSEPH',
#   'Water Supply Plumber',
#   '2016351',
#   'Plumber',
#   '3 March 2024',
#   ''],
#  ['BR PLUMBING & EXCAVATIONS PTY LTD',
#   'Water Supply Plumber',
#   '200987',
#   'Plumber',
#   '8 August 2024',
#   '',
#   ''],
#  ['BR PLUMBING & EXCAVATIONS PTY LTD',
#   'Sanitary Plumber',
#   '200987',
#   'Plumber',
#   '8 August 2024',
#   '',
#   ''],
#  ['BRAIDO, PHILLIP JOHN',
#   'Sanitary Plumber',
#   '199714667',
#   'Plumber',
#   '15 May 2023',
#   'Includes Water Supply work'],
#  ['BRAIN, MITCHELL ALEXANDER',
#   'Water Supply Plumber',
#   '20141361',
#   'Plumber',
#   '18 December 2023',
#   ''],
#  ['BRANDON, REECE',
#   'Sanitary Plumber',
#   '2014695',
#   'Plumber',
#   '27 May 2024',
#   '',
#   ''],
#  ['BRANDON, REECE',
#   'Water Supply Plumber',
#   '2014695',
#   'Plumber',
#   '27 May 2024',
#   '',
#   ''],
#  ['BREINER, PAUL',
#   'Journeyperson Plumber',
#   '200961',
#   'Plumber',
#   '21 April 2024',
#   ''],
#  ['BREITKOPF, JASON GRANT',
#   'Sanitary Plumber',
#   '199614149',
#   'Plumber',
#   '13 March 2024',
#   '',
#   ''],
#  ['BREITKOPF, JASON GRANT',
#   'Water Supply Plumber',
#   '199614149',
#   'Plumber',
#   '13 March 2024',
#   '',
#   ''],
#  ['BRERETON, CRAIG ANTHONY',
#   'Sanitary Plumber',
#   '2006849',
#   'Plumber',
#   '27 February 2024',
#   '',
#   ''],
#  ['BRERETON, CRAIG ANTHONY',
#   'Water Supply Plumber',
#   '2006849',
#   'Plumber',
#   '27 February 2024',
#   '',
#   ''],
#  ['BRETT, RICHARD JOHN',
#   'Sanitary Plumber',
#   '199714538',
#   'Plumber',
#   '22 July 2022',
#   '',
#   ''],
#  ['BRETT, RICHARD JOHN',
#   'Water Supply Plumber',
#   '199714538',
#   'Plumber',
#   '22 July 2022',
#   '',
#   ''],
#  ['BRICE-WILLIAMS, CALLUM',
#   'Sanitary Plumber',
#   '201955',
#   'Plumber',
#   '16 July 2022',
#   '',
#   ''],
#  ['BRICE-WILLIAMS, CALLUM',
#   'Water Supply Plumber',
#   '201955',
#   'Plumber',
#   '16 July 2022',
#   '',
#   ''],
#  ['BRIGGS, TIMOTHY DARRIN',
#   'Sanitary Plumber',
#   '20101149',
#   'Plumber',
#   '20 December 2023',
#   '',
#   ''],
#  ['BRIGGS, TIMOTHY DARRIN',
#   'Water Supply Plumber',
#   '20101149',
#   'Plumber',
#   '20 December 2023',
#   '',
#   ''],
#  ['BRIMAGE, CHRISTOPHER',
#   'Journeyperson Plumber',
#   '2021463',
#   'Plumber',
#   '25 April 2024',
#   ''],
#  ['BROMWICH, BRADLEY CHARLES',
#   'Water Supply Plumber',
#   '201360',
#   'Plumber',
#   '7 November 2023',
#   '',
#   ''],
#  ['BROMWICH, BRADLEY CHARLES',
#   'Sanitary Plumber',
#   '201360',
#   'Plumber',
#   '7 November 2023',
#   '',
#   ''],
#  ['BROOKHOUSE, FRANK CORNELUS',
#   'Sanitary Plumber',
#   '199714746',
#   'Plumber',
#   '21 July 2022',
#   'Certified to test Backflow Prevention Devices.',
#   ''],
#  ['BROOKHOUSE, FRANK CORNELUS',
#   'Water Supply Plumber',
#   '199714746',
#   'Plumber',
#   '21 July 2022',
#   'Certified to test Backflow Prevention Devices.',
#   ''],
#  ['BROWN, BRENDAN',
#   'Journeyperson Plumber',
#   '2021440',
#   'Plumber',
#   '12 April 2022',
#   ''],
#  ['BROWN, CAMERON',
#   'Water Supply Plumber',
#   '20171097',
#   'Plumber',
#   '8 June 2022',
#   '',
#   ''],
#  ['BROWN, CAMERON',
#   'Sanitary Plumber',
#   '20171097',
#   'Plumber',
#   '8 June 2022',
#   '',
#   ''],
#  ['BROWN, MICHAEL CHARLES',
#   'Water Supply Plumber',
#   '2011638',
#   'Plumber',
#   '19 November 2022',
#   ''],
#  ['BROWN, STEWART THOMAS',
#   'Journeyperson Plumber',
#   '199714448',
#   'Plumber',
#   '31 March 2022',
#   'Includes water supply work under supervision'],
#  ['BROWNBILL, GEORGE METCALF',
#   'Sanitary Plumber',
#   '20121129',
#   'Plumber',
#   '30 September 2022',
#   '',
#   ''],
#  ['BROWNBILL, GEORGE METCALF',
#   'Water Supply Plumber',
#   '20121129',
#   'Plumber',
#   '30 September 2022',
#   '',
#   ''],
#  ['BRUCE, CHRISTOPHER PATRICK',
#   'Water Supply Plumber',
#   '199713989',
#   'Plumber',
#   '21 September 2021',
#   '',
#   'Certified to test Backflow Prevention Devices'],
#  ['BRUCE, CHRISTOPHER PATRICK',
#   'Sanitary Plumber',
#   '199713989',
#   'Plumber',
#   '21 September 2021',
#   '',
#   'Certified to test Backflow Prevention Devices'],
#  ['BRUCIC, NICHOLAS',
#   'Sanitary Plumber',
#   '2014393',
#   'Plumber',
#   '5 November 2023',
#   ''],
#  ['BRYANT, COOPER SEC',
#   'Water Supply Plumber',
#   '200216113',
#   'Plumber',
#   '18 August 2024',
#   '',
#   ''],
#  ['BRYANT, COOPER SEC',
#   'Sanitary Plumber',
#   '200216113',
#   'Plumber',
#   '18 August 2024',
#   '',
#   ''],
#  ['BUCHANAN, HAMISH DUNCAN',
#   'Water Supply Plumber',
#   '2011229',
#   'Plumber',
#   '21 October 2024',
#   '',
#   'Certified to test Backflow Prevention Devices.'],
#  ['BUCHANAN, HAMISH DUNCAN',
#   'Sanitary Plumber',
#   '2011229',
#   'Plumber',
#   '21 October 2024',
#   '',
#   'Certified to test Backflow Prevention Devices.'],
#  ['BUCKLEY, ROBERT PATRICK',
#   'Water Supply Plumber',
#   '199715458',
#   'Plumber',
#   '5 July 2024',
#   '',
#   ''],
#  ['BUCKLEY, ROBERT PATRICK',
#   'Sanitary Plumber',
#   '199715458',
#   'Plumber',
#   '5 July 2024',
#   '',
#   ''],
#  ['BUCKMASTER, BENJAMIN',
#   'Journeyperson Plumber',
#   '2017695',
#   'Plumber',
#   '28 October 2023',
#   ''],
#  ['BUGEJA, JACKSON',
#   'Journeyperson Plumber',
#   '2016161',
#   'Plumber',
#   '19 May 2023',
#   ''],
#  ['BULL, ANDREW DUNCAN',
#   'Sanitary Plumber',
#   '200214172',
#   'Plumber',
#   '23 December 2021',
#   ''],
#  ['BULLOCK, BRENT',
#   'Journeyperson Plumber',
#   '20201576',
#   'Plumber',
#   '25 November 2021',
#   ''],
#  ['BUNNEY, RYAN',
#   'Journeyperson Plumber',
#   '20201668',
#   'Plumber',
#   '15 December 2021',
#   ''],
#  ['BUONOPANE, VINCE PETER',
#   'Sanitary Plumber',
#   '199214812',
#   'Plumber',
#   '4 July 2022',
#   'Certifed to test Backflow Prevention Devices',
#   ''],
#  ['BUONOPANE, VINCE PETER',
#   'Water Supply Plumber',
#   '199214812',
#   'Plumber',
#   '4 July 2022',
#   'Certifed to test Backflow Prevention Devices',
#   ''],
#  ['BURDORF, MICHAEL',
#   'Water Supply Plumber',
#   '200874',
#   'Plumber',
#   '2 August 2022',
#   '',
#   ''],
#  ['BURDORF, MICHAEL',
#   'Sanitary Plumber',
#   '200874',
#   'Plumber',
#   '2 August 2022',
#   '',
#   ''],
#  ['BURKE, RAY ALLAN',
#   'Sanitary Plumber',
#   '200316158',
#   'Plumber',
#   '24 October 2022',
#   '',
#   ''],
#  ['BURKE, RAY ALLAN',
#   'Water Supply Plumber',
#   '200316158',
#   'Plumber',
#   '24 October 2022',
#   '',
#   ''],
#  ['BURNETT, PHILIP JOHN',
#   'Sanitary Plumber',
#   '199615028',
#   'Plumber',
#   '16 December 2021',
#   '',
#   ''],
#  ['BURNETT, PHILIP JOHN',
#   'Water Supply Plumber',
#   '199615028',
#   'Plumber',
#   '16 December 2021',
#   '',
#   ''],
#  ['BURNS, JOHN EDWARD',
#   'Water Supply Plumber',
#   '202031',
#   'Plumber',
#   '26 February 2023',
#   'Restricted to the connection a fire sprinkler system to a water main.'],
#  ['BURR, ANTHONY DAVID',
#   'Water Supply Plumber',
#   '199514030',
#   'Plumber',
#   '29 July 2022',
#   '',
#   'Certified to Install and test backflow prevention devices.'],
#  ['BURR, ANTHONY DAVID',
#   'Sanitary Plumber',
#   '199514030',
#   'Plumber',
#   '29 July 2022',
#   '',
#   'Certified to Install and test backflow prevention devices.'],
#  ['BURRELL, CRAIG LINDSAY',
#   'Sanitary Plumber',
#   '199314574',
#   'Plumber',
#   '31 October 2023',
#   'Certified to test Backflow Prevention Devices.',
#   ''],
#  ['BURRELL, CRAIG LINDSAY',
#   'Water Supply Plumber',
#   '199314574',
#   'Plumber',
#   '31 October 2023',
#   'Certified to test Backflow Prevention Devices.',
#   ''],
#  ['BURRELL, MICHAEL LINDSAY',
#   'Journeyperson Plumber',
#   '2020126',
#   'Plumber',
#   '4 February 2023',
#   ''],
#  ['BURROWS, ANGUS',
#   'Water Supply Plumber',
#   '2018506',
#   'Plumber',
#   '18 June 2024',
#   ''],
#  ['BUSSTRA, DAVID JOHN',
#   'Sanitary Plumber',
#   '199714484',
#   'Plumber',
#   '2 December 2021',
#   ''],
#  ['BUTLER, ANTHONY JAMES',
#   'Sanitary Plumber',
#   '201335',
#   'Plumber',
#   '28 September 2021',
#   'Certified to test Backflow Prevention Devices.',
#   ''],
#  ['BUTLER, ANTHONY JAMES',
#   'Water Supply Plumber',
#   '201335',
#   'Plumber',
#   '29 September 2024',
#   'Certified to test Backflow Prevention Devices.',
#   ''],
#  ['BUTLER, JORDAN PATRICK JAMES',
#   'Water Supply Plumber',
#   '201742',
#   'Plumber',
#   '8 August 2024',
#   ''],
#  ['BUTTERFIELD, PATRICK',
#   'Fire Sprinkler Fitter',
#   '2021576',
#   'Plumber',
#   '24 May 2024',
#   ''],
#  ['BUTTERFIELD, PETER KENNETH',
#   'Water Supply Plumber',
#   '199314986',
#   'Plumber',
#   '10 November 2023',
#   '',
#   ''],
#  ['BUTTERFIELD, PETER KENNETH',
#   'Sanitary Plumber',
#   '199314986',
#   'Plumber',
#   '10 November 2023',
#   '',
#   ''],
#  ['BUYTEWEG, ANDREW MARK',
#   'Sanitary Plumber',
#   '199414527',
#   'Plumber',
#   '23 March 2023',
#   '',
#   ''],
#  ['BUYTEWEG, ANDREW MARK',
#   'Water Supply Plumber',
#   '199414527',
#   'Plumber',
#   '23 March 2023',
#   '',
#   ''],
#  ['BYERS, JOSHUA MATTHEW',
#   'Journeyperson Plumber',
#   '2021512',
#   'Plumber',
#   '5 May 2024',
#   ''],
#  ['CALEAR, GEORGE ALFRED',
#   'Sanitary Plumber',
#   '199315788',
#   'Plumber',
#   '9 June 2022',
#   'Includes Water Supply work'],
#  ['CALGARO, JOSHUA PAUL',
#   'Sanitary Plumber',
#   '2007112',
#   'Plumber',
#   '2 March 2024',
#   'Includes Water Supply Work.'],
#  ['CALVERT, LESLIE ALAN',
#   'Water Supply Plumber',
#   '199515418',
#   'Plumber',
#   '29 March 2024',
#   '',
#   ''],
#  ['CALVERT, LESLIE ALAN',
#   'Sanitary Plumber',
#   '199515418',
#   'Plumber',
#   '29 March 2024',
#   '',
#   ''],
#  ['CAMERON, MITCHELL',
#   'Water Supply Plumber',
#   '20181326',
#   'Plumber',
#   '15 January 2023',
#   '',
#   ''],
#  ['CAMERON, MITCHELL',
#   'Sanitary Plumber',
#   '20181326',
#   'Plumber',
#   '15 January 2023',
#   '',
#   ''],
#  ['CAMERON, WILLIAM',
#   'Sanitary Plumber',
#   '2006210',
#   'Plumber',
#   '13 August 2023',
#   ''],
#  ['CAMILLERI, JASON SEAN',
#   'Sanitary Plumber',
#   '20141065',
#   'Plumber',
#   '7 December 2023',
#   '',
#   ''],
#  ['CAMILLERI, JASON SEAN',
#   'Water Supply Plumber',
#   '20141065',
#   'Plumber',
#   '7 December 2023',
#   '',
#   ''],
#  ['CAMILLERI, JOSEPH BRADLEY JORDAN',
#   'Sanitary Plumber',
#   '20191110',
#   'Plumber',
#   '13 November 2023',
#   '',
#   ''],
#  ['CAMILLERI, JOSEPH BRADLEY JORDAN',
#   'Water Supply Plumber',
#   '20191110',
#   'Plumber',
#   '13 November 2023',
#   '',
#   ''],
#  ['CAMPBELL, BLAKE',
#   'Journeyperson Plumber',
#   '2021884',
#   'Plumber',
#   '26 July 2022',
#   ''],
#  ['CAMPBELL, JOEL',
#   'Journeyperson Plumber',
#   '20201497',
#   'Plumber',
#   '11 May 2022',
#   ''],
#  ['CAMPBELL, STEVEN ALLAN',
#   'Sanitary Plumber',
#   '2015519',
#   'Plumber',
#   '25 June 2024',
#   '',
#   ''],
#  ['CAMPBELL, STEVEN ALLAN',
#   'Water Supply Plumber',
#   '2015519',
#   'Plumber',
#   '25 June 2024',
#   '',
#   ''],
#  ['CANNIZZARO, MASSIMILIANO',
#   'Journeyperson Plumber',
#   '2011367',
#   'Plumber',
#   '6 April 2022',
#   'Certified to test Backflow Prevention Devices. Can only provide this construction service as an employee under supervision.'],
#  ['CANNON, GLEN DAVID',
#   'Water Supply Plumber',
#   '2008300',
#   'Plumber',
#   '30 June 2024',
#   '',
#   ''],
#  ['CANNON, GLEN DAVID',
#   'Sanitary Plumber',
#   '2008300',
#   'Plumber',
#   '30 June 2024',
#   '',
#   ''],
#  ['CANNON, LEE MICHAEL',
#   'Sanitary Plumber',
#   '199915894',
#   'Plumber',
#   '19 May 2023',
#   ''],
#  ['CANT, JOHN GORDON',
#   'Water Supply Plumber',
#   '200316168',
#   'Plumber',
#   '18 December 2023',
#   'Certified to test Backflow Prevention Devices.',
#   ''],
#  ['CANT, JOHN GORDON',
#   'Sanitary Plumber',
#   '200316168',
#   'Plumber',
#   '18 December 2023',
#   'Certified to test Backflow Prevention Devices.',
#   ''],
#  ['CANULLI, DOMENICO',
#   'Sanitary Plumber',
#   '199715559',
#   'Plumber',
#   '19 April 2022',
#   ''],
#  ['CAPEX GROUP PTY LTD',
#   'Sanitary Plumber',
#   '20201209',
#   'Plumber',
#   '14 September 2023',
#   ''],
#  ['CAPITAL FIRE PROTECTION PTY LTD',
#   'Water Supply Plumber',
#   '20211054',
#   'Plumber',
#   '11 August 2024',
#   'Restricted to Fire protection systems only'],
#  ['CAPITAL GAS WORKS PTY LTD',
#   'Sanitary Plumber',
#   '2013896',
#   'Plumber',
#   '26 September 2022',
#   '',
#   ''],
#  ['CAPITAL GAS WORKS PTY LTD',
#   'Water Supply Plumber',
#   '2013896',
#   'Plumber',
#   '25 September 2022',
#   '',
#   ''],
#  ['CAPITAL MAINTENANCE SOLUTIONS',
#   'Sanitary Plumber',
#   '2019824',
#   'Plumber',
#   '2 September 2022',
#   '',
#   'Certified to test Backflow Prevention Devices'],
#  ['CAPITAL MAINTENANCE SOLUTIONS',
#   'Water Supply Plumber',
#   '2019824',
#   'Plumber',
#   '2 September 2022',
#   '',
#   'Certified to test Backflow Prevention Devices'],
#  ['CAPPELLO, ANTHONY DAVID',
#   'Water Supply Plumber',
#   '100114349',
#   'Plumber',
#   '2 September 2024',
#   '',
#   ''],
#  ['CAPPELLO, ANTHONY DAVID',
#   'Sanitary Plumber',
#   '100114349',
#   'Plumber',
#   '2 September 2024',
#   '',
#   ''],
#  ['CAPPELLO, RYAN ANDREW',
#   'Sanitary Plumber',
#   '200524',
#   'Plumber',
#   '20 June 2024',
#   '',
#   ''],
#  ['CAPPELLO, RYAN ANDREW',
#   'Water Supply Plumber',
#   '200524',
#   'Plumber',
#   '20 June 2024',
#   '',
#   ''],
#  ['CAPUTO, DANIEL',
#   'Sanitary Plumber',
#   '2006817',
#   'Plumber',
#   '22 May 2022',
#   ''],
#  ['CARAZO, GERARD',
#   'Sanitary Plumber',
#   '2019961',
#   'Plumber',
#   '20 May 2022',
#   'Certified to Test Backflow Prevention Devices.',
#   ''],
#  ['CARAZO, GERARD',
#   'Water Supply Plumber',
#   '2019961',
#   'Plumber',
#   '20 May 2022',
#   'Certified to Test Backflow Prevention Devices.',
#   ''],
#  ['CAREY, SIMON THOMAS',
#   'Water Supply Plumber',
#   '200920',
#   'Plumber',
#   '4 February 2022',
#   '',
#   'Certified to test backflow prevention devices.'],
#  ['CAREY, SIMON THOMAS',
#   'Sanitary Plumber',
#   '200920',
#   'Plumber',
#   '4 February 2022',
#   '',
#   'Certified to test backflow prevention devices.'],
#  ['CARGILL, ANDREW JAMES',
#   'Sanitary Plumber',
#   '199714610',
#   'Plumber',
#   '3 February 2024',
#   '',
#   ''],
#  ['CARGILL, ANDREW JAMES',
#   'Water Supply Plumber',
#   '199714610',
#   'Plumber',
#   '3 February 2024',
#   '',
#   ''],
#  ['CARLSON, SHANE',
#   'Journeyperson Plumber',
#   '2019277',
#   'Plumber',
#   '4 April 2022',
#   ''],
#  ['CARMODY, SHANE MARK',
#   'Sanitary Plumber',
#   '200316136',
#   'Plumber',
#   '26 June 2022',
#   ''],
#  ['CARN, BEN',
#   'Journeyperson Plumber',
#   '2019174',
#   'Plumber',
#   '27 May 2022',
#   ''],
#  ['CARNELL, THOMAS WILLIAM',
#   'Water Supply Plumber',
#   '201439',
#   'Plumber',
#   '14 July 2022',
#   '',
#   ''],
#  ['CARNELL, THOMAS WILLIAM',
#   'Sanitary Plumber',
#   '201439',
#   'Plumber',
#   '14 July 2022',
#   '',
#   ''],
#  ['CARPENTER, JAMES BARRY',
#   'Fire Sprinkler Fitter',
#   '2015476',
#   'Plumber',
#   '24 June 2024',
#   ''],
#  ['CARPENTER, JAMIE STEPHEN',
#   'Sanitary Plumber',
#   '2006444',
#   'Plumber',
#   '23 March 2023',
#   ''],
#  ['CARPENTER, SIMON',
#   'Water Supply Plumber',
#   '20181238',
#   'Plumber',
#   '19 November 2021',
#   '',
#   ''],
#  ['CARPENTER, SIMON',
#   'Sanitary Plumber',
#   '20181238',
#   'Plumber',
#   '19 November 2021',
#   '',
#   ''],
#  ['CARSON, DAMON JOHN',
#   'Sanitary Plumber',
#   '200216107',
#   'Plumber',
#   '29 August 2022',
#   ''],
#  ['CARSON, PAUL GEOFFREY',
#   'Journeyperson Plumber',
#   '20101017',
#   'Plumber',
#   '4 August 2024',
#   ''],
#  ['CARTER, WILLIAM',
#   'Journeyperson Plumber',
#   '20191286',
#   'Plumber',
#   '28 February 2022',
#   ''],
#  ['CARTON, MATTHEW XAVIER',
#   'Sanitary Plumber',
#   '20091',
#   'Plumber',
#   '8 March 2023',
#   ''],
#  ['CARTWRIGHT, JACK GRAHAM',
#   'Sanitary Plumber',
#   '20111450',
#   'Plumber',
#   '1 February 2022',
#   'Certified to test Backflow Prevention Devices.',
#   ''],
#  ['CARTWRIGHT, JACK GRAHAM',
#   'Water Supply Plumber',
#   '20111450',
#   'Plumber',
#   '1 February 2022',
#   'Certified to test Backflow Prevention Devices.',
#   ''],
#  ['CARUSO, JOSEPH',
#   'Sanitary Plumber',
#   '2017842',
#   'Plumber',
#   '18 October 2023',
#   '',
#   ''],
#  ['CARUSO, JOSEPH',
#   'Water Supply Plumber',
#   '2017842',
#   'Plumber',
#   '18 October 2023',
#   '',
#   ''],
#  ['CASE, DARREN JOHN',
#   'Water Supply Plumber',
#   '199314821',
#   'Plumber',
#   '20 November 2021',
#   '',
#   ''],
#  ['CASE, DARREN JOHN',
#   'Sanitary Plumber',
#   '199314821',
#   'Plumber',
#   '20 November 2021',
#   '',
#   ''],
#  ['CASEY, MITCHELL BRIAN',
#   'Sanitary Plumber',
#   '2015193',
#   'Plumber',
#   '1 July 2022',
#   '',
#   ''],
#  ['CASEY, MITCHELL BRIAN',
#   'Water Supply Plumber',
#   '2015193',
#   'Plumber',
#   '1 July 2022',
#   '',
#   ''],
#  ['CASSELDEN, GEOFFREY ROBERT',
#   'Sanitary Plumber',
#   '199715562',
#   'Plumber',
#   '16 April 2022',
#   '',
#   ''],
#  ['CASSELDEN, GEOFFREY ROBERT',
#   'Water Supply Plumber',
#   '199715562',
#   'Plumber',
#   '16 April 2022',
#   '',
#   ''],
#  ['CATTELL, PETER GERARD',
#   'Sanitary Plumber',
#   '2014855',
#   'Plumber',
#   '6 September 2024',
#   'Certified to test Backflow Prevention Devices.'],
#  ['CCS FM PTY LTD',
#   'Sanitary Plumber',
#   '2014720',
#   'Plumber',
#   '4 January 2024',
#   'Certified to test backflow prevention devices',
#   ''],
#  ['CCS FM PTY LTD',
#   'Water Supply Plumber',
#   '2014720',
#   'Plumber',
#   '4 January 2024',
#   'Certified to test backflow prevention devices',
#   ''],
#  ['CETINKAYA, IMRAN',
#   'Sanitary Plumber',
#   '20111510',
#   'Plumber',
#   '20 April 2024',
#   ''],
#  ['CH PTY LIMITED',
#   'Sanitary Plumber',
#   '20081087',
#   'Plumber',
#   '9 December 2023',
#   '',
#   ''],
#  ['CH PTY LIMITED',
#   'Water Supply Plumber',
#   '20081087',
#   'Plumber',
#   '9 December 2023',
#   '',
#   ''],
#  ['CHALKER, STEPHEN JEFFERY',
#   'Journeyperson Plumber',
#   '2018319',
#   'Plumber',
#   '9 July 2022',
#   ''],
#  ['CHALLEN, GARY RICHARD',
#   'Water Supply Plumber',
#   '199815855',
#   'Plumber',
#   '11 June 2024',
#   '',
#   ''],
#  ['CHALLEN, GARY RICHARD',
#   'Sanitary Plumber',
#   '199815855',
#   'Plumber',
#   '11 June 2024',
#   '',
#   ''],
#  ['CHARLES, BENJAMIN JOHN',
#   'Water Supply Plumber',
#   '20101230',
#   'Plumber',
#   '6 April 2023',
#   '',
#   'Certified to test Backflow Prevention Devices.'],
#  ['CHARLES, BENJAMIN JOHN',
#   'Sanitary Plumber',
#   '20101230',
#   'Plumber',
#   '6 April 2023',
#   '',
#   'Certified to test Backflow Prevention Devices.'],
#  ['CHIEN KHUONG, MANH',
#   'Water Supply Plumber',
#   '2018336',
#   'Plumber',
#   '20 April 2023',
#   '',
#   ''],
#  ['CHIEN KHUONG, MANH',
#   'Sanitary Plumber',
#   '2018336',
#   'Plumber',
#   '20 April 2023',
#   '',
#   ''],
#  ['CHIERA, JOHN FRANCIS',
#   'Water Supply Plumber',
#   '199615657',
#   'Plumber',
#   '30 January 2023',
#   '',
#   'Certified for backflow.'],
#  ['CHIERA, JOHN FRANCIS',
#   'Sanitary Plumber',
#   '199615657',
#   'Plumber',
#   '30 January 2023',
#   '',
#   'Certified for backflow.'],
#  ['CHIVAS, IAN JOHN',
#   'Water Supply Plumber',
#   '199613965',
#   'Plumber',
#   '26 March 2023',
#   '',
#   'Certified to Backflow Prevention.'],
#  ['CHIVAS, IAN JOHN',
#   'Sanitary Plumber',
#   '199613965',
#   'Plumber',
#   '26 March 2023',
#   '',
#   'Certified to Backflow Prevention.'],
#  ['CHOPPING, DAVID BRIAN',
#   'Sanitary Plumber',
#   '199714752',
#   'Plumber',
#   '4 April 2022',
#   '',
#   ''],
#  ['CHOPPING, DAVID BRIAN',
#   'Water Supply Plumber',
#   '199714752',
#   'Plumber',
#   '4 April 2022',
#   '',
#   ''],
#  ['CHRISTIAN, NATHAN',
#   'Journeyperson Plumber',
#   '20201714',
#   'Plumber',
#   '26 December 2021',
#   ''],
#  ['CHRISTIAN, SHANE ANTHONY',
#   'Sanitary Plumber',
#   '2014519',
#   'Plumber',
#   '30 May 2023',
#   'Restricted to work performed as an employee only. Not able to contract.'],
#  ['CHUBB FIRE & SECURITY PTY LTD',
#   'Fire Sprinkler Fitter',
#   '2017117',
#   'Plumber',
#   '13 April 2023',
#   'NIL'],
#  ['CICERAN, JOHN STEVEN',
#   'Water Supply Plumber',
#   '199815828',
#   'Plumber',
#   '6 February 2023',
#   '',
#   'Certified to test Backflow Prevention Devices.'],
#  ['CICERAN, JOHN STEVEN',
#   'Sanitary Plumber',
#   '199815828',
#   'Plumber',
#   '6 February 2023',
#   '',
#   'Certified to test Backflow Prevention Devices.'],
#  ['CIESIOLKA, ERIC',
#   'Journeyperson Plumber',
#   '202079',
#   'Plumber',
#   '25 February 2023',
#   ''],
#  ['CIVIL AND CIVIC GROUP PTY LTD',
#   'Water Supply Plumber',
#   '2021356',
#   'Plumber',
#   '25 March 2024',
#   '',
#   ''],
#  ['CIVIL AND CIVIC GROUP PTY LTD',
#   'Sanitary Plumber',
#   '2021356',
#   'Plumber',
#   '25 March 2024',
#   '',
#   ''],
#  ['CLACK, JAMES',
#   'Journeyperson Plumber',
#   '2021642',
#   'Plumber',
#   '20 May 2022',
#   ''],
#  ['CLACK, JOHN',
#   'Journeyperson Plumber',
#   '20201059',
#   'Plumber',
#   '20 August 2024',
#   ''],
#  ['CLARK, JOHN',
#   'Journeyperson Plumber',
#   '2021308',
#   'Plumber',
#   '1 June 2022',
#   ''],
#  ['CLARK, NATHAN ASHLEY',
#   'Journeyperson Plumber',
#   '20181353',
#   'Plumber',
#   '13 December 2021',
#   'Certified to test Backflow Prevention Devices.'],
#  ['CLARK, ROSS KAI',
#   'Water Supply Plumber',
#   '2005941',
#   'Plumber',
#   '30 March 2022',
#   '',
#   ''],
#  ['CLARK, ROSS KAI',
#   'Sanitary Plumber',
#   '2005941',
#   'Plumber',
#   '30 March 2022',
#   '',
#   ''],
#  ['CLARK, TYE',
#   'Sanitary Plumber',
#   '201715',
#   'Plumber',
#   '31 January 2023',
#   '',
#   ''],
#  ['CLARK, TYE',
#   'Water Supply Plumber',
#   '201715',
#   'Plumber',
#   '31 January 2023',
#   '',
#   ''],
#  ['CLARKE, ADRIAN DAVID',
#   'Water Supply Plumber',
#   '199714510',
#   'Plumber',
#   '5 July 2022',
#   '',
#   'Certified to test backflow prevention devices.'],
#  ['CLARKE, ADRIAN DAVID',
#   'Sanitary Plumber',
#   '199714510',
#   'Plumber',
#   '5 July 2022',
#   '',
#   'Certified to test backflow prevention devices.'],
#  ['CLEARY, WILLIAM EDMUND',
#   'Water Supply Plumber',
#   '199715745',
#   'Plumber',
#   '7 April 2023',
#   '',
#   ''],
#  ['CLEARY, WILLIAM EDMUND',
#   'Sanitary Plumber',
#   '199715745',
#   'Plumber',
#   '7 April 2023',
#   '',
#   ''],
#  ['CLEMENO, JOSEPH',
#   'Journeyperson Plumber',
#   '2009798',
#   'Plumber',
#   '4 September 2022',
#   'Joureyperson plumber includes water supply work, as an employee under supervision'],
#  ['CLIMATROL TRADING PTY LTD',
#   'Sanitary Plumber',
#   '20211118',
#   'Plumber',
#   '6 August 2024',
#   '',
#   ''],
#  ['CLIMATROL TRADING PTY LTD',
#   'Water Supply Plumber',
#   '20211118',
#   'Plumber',
#   '6 August 2024',
#   '',
#   ''],
#  ['CLUNE, KIERAN TIMOTHY',
#   'Sanitary Plumber',
#   '199714272',
#   'Plumber',
#   '31 August 2022',
#   '',
#   ''],
#  ['CLUNE, KIERAN TIMOTHY',
#   'Water Supply Plumber',
#   '199714272',
#   'Plumber',
#   '31 August 2022',
#   '',
#   ''],
#  ['COCKRAM, MATTHEW PAUL',
#   'Sanitary Plumber',
#   '199713945',
#   'Plumber',
#   '12 June 2024',
#   ''],
#  ['COCKS, WILLIAM-JOHN',
#   'Sanitary Plumber',
#   '2013520',
#   'Plumber',
#   '8 October 2023',
#   'Certified to test Backflow Prevention Devices.',
#   ''],
#  ['COCKS, WILLIAM-JOHN',
#   'Water Supply Plumber',
#   '2013520',
#   'Plumber',
#   '8 October 2023',
#   'Certified to test Backflow Prevention Devices.',
#   ''],
#  ['COGGAN, JASON',
#   'Journeyperson Plumber',
#   '2013886',
#   'Plumber',
#   '20 October 2021',
#   ''],
#  ['COLEMAN, ALEXANDER JOSEPH',
#   'Journeyperson Plumber',
#   '2015839',
#   'Plumber',
#   '28 March 2022',
#   ''],
#  ['COLEMAN, JOHN JAMES',
#   'Water Supply Plumber',
#   '2020313',
#   'Plumber',
#   '23 April 2023',
#   '',
#   ''],
#  ['COLEMAN, JOHN JAMES',
#   'Sanitary Plumber',
#   '2020313',
#   'Plumber',
#   '23 April 2023',
#   '',
#   ''],
#  ['COLEMAN, SEAN ANDREW',
#   'Water Supply Plumber',
#   '20111114',
#   'Plumber',
#   '14 December 2023',
#   '',
#   ''],
#  ['COLEMAN, SEAN ANDREW',
#   'Sanitary Plumber',
#   '20111114',
#   'Plumber',
#   '14 December 2023',
#   '',
#   ''],
#  ['COLLARD, SIMON WAYNE',
#   'Sanitary Plumber',
#   '200849',
#   'Plumber',
#   '10 January 2022',
#   '',
#   ''],
#  ['COLLARD, SIMON WAYNE',
#   'Water Supply Plumber',
#   '200849',
#   'Plumber',
#   '10 January 2022',
#   '',
#   ''],
#  ['COLMAN, BRIAN JAMES',
#   'Water Supply Plumber',
#   '2014699',
#   'Plumber',
#   '23 July 2023',
#   '',
#   'Certified to test Backflow Prevention Devices.'],
#  ['COLMAN, BRIAN JAMES',
#   'Sanitary Plumber',
#   '2014699',
#   'Plumber',
#   '23 July 2023',
#   '',
#   'Certified to test Backflow Prevention Devices.'],
#  ['COMPTON, GERAINT',
#   'Water Supply Plumber',
#   '2019333',
#   'Plumber',
#   '22 May 2022',
#   '',
#   'Certified to Test Backflow Prevention Devices.'],
#  ['COMPTON, GERAINT',
#   'Sanitary Plumber',
#   '2019333',
#   'Plumber',
#   '22 May 2022',
#   '',
#   'Certified to Test Backflow Prevention Devices.'],
#  ['CONLON, BLAKE JOSHUA',
#   'Journeyperson Plumber',
#   '200416236',
#   'Plumber',
#   '30 August 2023',
#   'Includes water supply work under supervision'],
#  ['CONNELL, JOSHUA',
#   'Journeyperson Plumber',
#   '2019848',
#   'Plumber',
#   '3 December 2022',
#   ''],
#  ['CONNELLY, MATTHEW',
#   'Water Supply Plumber',
#   '2015806',
#   'Plumber',
#   '27 February 2022',
#   '',
#   ''],
#  ['CONNELLY, MATTHEW',
#   'Sanitary Plumber',
#   '2015806',
#   'Plumber',
#   '27 February 2022',
#   '',
#   ''],
#  ['CONNOR, ASHLEY JOHN',
#   'Sanitary Plumber',
#   '2014604',
#   'Plumber',
#   '14 January 2022',
#   '',
#   ''],
#  ['CONNOR, ASHLEY JOHN',
#   'Water Supply Plumber',
#   '2014604',
#   'Plumber',
#   '14 January 2022',
#   '',
#   ''],
#  ['CONRON, JOEL THOMAS',
#   'Water Supply Plumber',
#   '200676',
#   'Plumber',
#   '25 January 2022',
#   'Certified to test Backflow Prevention Devices',
#   ''],
#  ['CONRON, JOEL THOMAS',
#   'Sanitary Plumber',
#   '200676',
#   'Plumber',
#   '25 January 2022',
#   'Certified to test Backflow Prevention Devices',
#   ''],
#  ['COOK, ALAN RODNEY',
#   'Sanitary Plumber',
#   '199615434',
#   'Plumber',
#   '15 June 2023',
#   'Includes Water Supply work'],
#  ['COOK, COLIN NOEL',
#   'Water Supply Plumber',
#   '2020157',
#   'Plumber',
#   '20 February 2024',
#   '',
#   ''],
#  ['COOK, COLIN NOEL',
#   'Sanitary Plumber',
#   '2020157',
#   'Plumber',
#   '20 February 2024',
#   '',
#   ''],
#  ['COOMBE, WARWICK',
#   'Journeyperson Plumber',
#   '20201500',
#   'Plumber',
#   '9 November 2021',
#   ''],
#  ['COOMBES, EMMETT WILLIAM',
#   'Sanitary Plumber',
#   '20081145',
#   'Plumber',
#   '9 January 2024',
#   'Please contact Access Canberra for condition details'],
#  ['COOPER, DANIEL JAMES',
#   'Sanitary Plumber',
#   '200216087',
#   'Plumber',
#   '28 September 2021',
#   '',
#   ''],
#  ['COOPER, DANIEL JAMES',
#   'Water Supply Plumber',
#   '200216087',
#   'Plumber',
#   '28 September 2021',
#   '',
#   ''],
#  ['COOPER, DAVID NORMAN',
#   'Water Supply Plumber',
#   '2013914',
#   'Plumber',
#   '7 September 2023',
#   '',
#   ''],
#  ['COOPER, DAVID NORMAN',
#   'Sanitary Plumber',
#   '2013914',
#   'Plumber',
# ...
#   '',
#   ''],
#  ['HILL, AARON PATRICK',
#   'Sanitary Plumber',
#   '2006749',
#   'Plumber',
#   '2 September 2023',
#   '',
#   ''],
#  ['HILL, MATHEW JAMES',
#   'Water Supply Plumber',
#   '2020908',
#   'Plumber',
#   '21 August 2024',
#   '',
#   ''],
#  ['HILL, MATHEW JAMES',
#   'Sanitary Plumber',
#   '2020908',
#   'Plumber',
#   '21 August 2024',
#   '',
#   ''],
#  ['HILLARD, MICHAEL EDWARD',
#   'Sanitary Plumber',
#   '200116043',
#   'Plumber',
#   '16 October 2021',
#   '',
#   ''],
#  ['HILLARD, MICHAEL EDWARD',
#   'Water Supply Plumber',
#   '200116043',
#   'Plumber',
#   '16 October 2021',
#   '',
#   ''],
#  ['HILLEGE, CHRISTOPHER',
#   'Water Supply Plumber',
#   '2017458',
#   'Plumber',
#   '3 May 2024',
#   '',
#   ''],
#  ['HILLEGE, CHRISTOPHER',
#   'Sanitary Plumber',
#   '2017458',
#   'Plumber',
#   '3 May 2024',
#   '',
#   ''],
#  ['HILLMAN, CHARLES',
#   'Water Supply Plumber',
#   '2019439',
#   'Plumber',
#   '24 September 2022',
#   '',
#   ''],
#  ['HILLMAN, CHARLES',
#   'Sanitary Plumber',
#   '2019439',
#   'Plumber',
#   '24 September 2022',
#   '',
#   ''],
#  ['HINDMARSH PLUMBING SERVICES PTY LTD',
#   'Water Supply Plumber',
#   '20171047',
#   'Plumber',
#   '25 November 2023',
#   '',
#   ''],
#  ['HINDMARSH PLUMBING SERVICES PTY LTD',
#   'Sanitary Plumber',
#   '20171047',
#   'Plumber',
#   '25 November 2023',
#   '',
#   ''],
#  ['HIPPIT, GRAHAM REGINALD',
#   'Sanitary Plumber',
#   '200416211',
#   'Plumber',
#   '10 October 2023',
#   'Certified to Test Backflow Prevention Devices.',
#   ''],
#  ['HIPPIT, GRAHAM REGINALD',
#   'Water Supply Plumber',
#   '200416211',
#   'Plumber',
#   '10 October 2023',
#   'Certified to Test Backflow Prevention Devices.',
#   ''],
#  ['HITCHINS, ANDREW JAMES',
#   'Sanitary Plumber',
#   '199414693',
#   'Plumber',
#   '24 November 2021',
#   ''],
#  ['HITCHINS, KYLE ROBERT',
#   'Journeyperson Plumber',
#   '2013779',
#   'Plumber',
#   '6 September 2022',
#   ''],
#  ['HITCHINS, MARK CLIFFORD',
#   'Water Supply Plumber',
#   '199715804',
#   'Plumber',
#   '30 November 2022',
#   '',
#   ''],
#  ['HITCHINS, MARK CLIFFORD',
#   'Sanitary Plumber',
#   '199715804',
#   'Plumber',
#   '30 November 2022',
#   '',
#   ''],
#  ['HOCKEY, JEDIAH',
#   'Water Supply Plumber',
#   '2018227',
#   'Plumber',
#   '20 November 2021',
#   '',
#   'Also valid for Backflow Prevention Testing.'],
#  ['HOCKEY, JEDIAH',
#   'Sanitary Plumber',
#   '2018227',
#   'Plumber',
#   '20 November 2021',
#   '',
#   'Also valid for Backflow Prevention Testing.'],
#  ['HOCKING, IAN THOMAS',
#   'Sanitary Plumber',
#   '2006663',
#   'Plumber',
#   '4 September 2022',
#   '',
#   ''],
#  ['HOCKING, IAN THOMAS',
#   'Water Supply Plumber',
#   '2006663',
#   'Plumber',
#   '4 September 2022',
#   '',
#   ''],
#  ['HODSON, BENJAMIN JOHN',
#   'Water Supply Plumber',
#   '2011249',
#   'Plumber',
#   '27 August 2023',
#   '',
#   ''],
#  ['HODSON, BENJAMIN JOHN',
#   'Sanitary Plumber',
#   '2011249',
#   'Plumber',
#   '27 August 2023',
#   '',
#   ''],
#  ['HODSON, SAMUEL JAMES',
#   'Water Supply Plumber',
#   '2006516',
#   'Plumber',
#   '24 May 2022',
#   ''],
#  ['HOEY, JAMES',
#   'Journeyperson Plumber',
#   '2019460',
#   'Plumber',
#   '9 July 2022',
#   ''],
#  ['HOGAN, TIMOTHY DANIEL',
#   'Sanitary Plumber',
#   '200216065',
#   'Plumber',
#   '29 July 2022',
#   ''],
#  ['HOGAN, WAYNE ANTHONY',
#   'Journeyperson Plumber',
#   '199815865',
#   'Plumber',
#   '24 May 2022',
#   ''],
#  ['HOGNO, JASON RODNEY',
#   'Water Supply Plumber',
#   '2013866',
#   'Plumber',
#   '29 November 2022',
#   '',
#   ''],
#  ['HOGNO, JASON RODNEY',
#   'Sanitary Plumber',
#   '2013866',
#   'Plumber',
#   '29 November 2022',
#   '',
#   ''],
#  ['HOITINK, AARON',
#   'Journeyperson Plumber',
#   '2020846',
#   'Plumber',
#   '26 July 2022',
#   ''],
#  ['HOITINK, NATHAN LEO',
#   'Water Supply Plumber',
#   '20151217',
#   'Plumber',
#   '11 December 2023',
#   '',
#   ''],
#  ['HOITINK, NATHAN LEO',
#   'Sanitary Plumber',
#   '20151217',
#   'Plumber',
#   '11 December 2023',
#   '',
#   ''],
#  ['HOLDER, DAMIEN LESLIE',
#   'Sanitary Plumber',
#   '2016896',
#   'Plumber',
#   '8 August 2022',
#   '',
#   ''],
#  ['HOLDER, DAMIEN LESLIE',
#   'Water Supply Plumber',
#   '2016896',
#   'Plumber',
#   '8 August 2022',
#   '',
#   ''],
#  ['HOLDWAY, JACKSON',
#   'Journeyperson Plumber',
#   '20211052',
#   'Plumber',
#   '6 August 2022',
#   ''],
#  ['HOLLAND, JAKE REES',
#   'Water Supply Plumber',
#   '2015474',
#   'Plumber',
#   '20 March 2024',
#   '',
#   ''],
#  ['HOLLAND, JAKE REES',
#   'Sanitary Plumber',
#   '2015474',
#   'Plumber',
#   '20 March 2024',
#   '',
#   ''],
#  ['HOLLAND, THOMAS EDWARD',
#   'Sanitary Plumber',
#   '201470',
#   'Plumber',
#   '9 February 2024',
#   '',
#   ''],
#  ['HOLLAND, THOMAS EDWARD',
#   'Water Supply Plumber',
#   '201470',
#   'Plumber',
#   '9 February 2024',
#   '',
#   ''],
#  ['HONEY, PETER RAYMOND',
#   'Sanitary Plumber',
#   '2006706',
#   'Plumber',
#   '28 September 2022',
#   '',
#   ''],
#  ['HONEY, PETER RAYMOND',
#   'Water Supply Plumber',
#   '2006706',
#   'Plumber',
#   '28 September 2022',
#   '',
#   ''],
#  ['HOOKER, RYAN ALEXANDER',
#   'Water Supply Plumber',
#   '201615',
#   'Plumber',
#   '14 February 2023',
#   '',
#   ''],
#  ['HOOKER, RYAN ALEXANDER',
#   'Sanitary Plumber',
#   '201615',
#   'Plumber',
#   '14 February 2023',
#   '',
#   ''],
#  ['HOOKEY, SIMON JONATHON',
#   'Fire Sprinkler Fitter',
#   '2019985',
#   'Plumber',
#   '10 November 2022',
#   '',
#   '',
#   ''],
#  ['HOOKEY, SIMON JONATHON',
#   'Water Supply Plumber',
#   '2019985',
#   'Plumber',
#   '10 November 2022',
#   '',
#   '',
#   ''],
#  ['HOOKEY, SIMON JONATHON',
#   'Sanitary Plumber',
#   '2019985',
#   'Plumber',
#   '10 November 2022',
#   '',
#   '',
#   ''],
#  ['HOOPER, JASON',
#   'Sanitary Plumber',
#   '2009123',
#   'Plumber',
#   '29 April 2024',
#   '',
#   ''],
#  ['HOOPER, JASON',
#   'Water Supply Plumber',
#   '2009123',
#   'Plumber',
#   '29 April 2024',
#   '',
#   ''],
#  ['HOORWEG, DAVID JOHN',
#   'Water Supply Plumber',
#   '2008355',
#   'Plumber',
#   '18 October 2022',
#   '',
#   ''],
#  ['HOORWEG, DAVID JOHN',
#   'Sanitary Plumber',
#   '2008355',
#   'Plumber',
#   '18 October 2022',
#   '',
#   ''],
#  ['HOTWATER HOTLINE PTY LTD',
#   'Sanitary Plumber',
#   '200427084',
#   'Plumber',
#   '11 February 2023',
#   ''],
#  ['HOURIGAN, NICHOLAS',
#   'Sanitary Plumber',
#   '2006184',
#   'Plumber',
#   '29 May 2023',
#   '',
#   ''],
#  ['HOURIGAN, NICHOLAS',
#   'Water Supply Plumber',
#   '2006184',
#   'Plumber',
#   '29 May 2023',
#   '',
#   ''],
#  ['HOWARD, JACK',
#   'Journeyperson Plumber',
#   '2021622',
#   'Plumber',
#   '28 May 2022',
#   ''],
#  ['HOWARD, STUART EDWARD',
#   'Sanitary Plumber',
#   '199915925',
#   'Plumber',
#   '1 July 2022',
#   '',
#   ''],
#  ['HOWARD, STUART EDWARD',
#   'Water Supply Plumber',
#   '199915925',
#   'Plumber',
#   '1 July 2022',
#   '',
#   ''],
#  ['HOWROYD, KEIRAN RUSSELL',
#   'Journeyperson Plumber',
#   '20141257',
#   'Plumber',
#   '13 September 2022',
#   ''],
#  ['HROMOW, JAKE',
#   'Journeyperson Plumber',
#   '2020487',
#   'Plumber',
#   '1 May 2023',
#   ''],
#  ['HRSTIC, DALIBOR',
#   'Water Supply Plumber',
#   '199714243',
#   'Plumber',
#   '18 January 2024',
#   '',
#   ''],
#  ['HRSTIC, DALIBOR',
#   'Sanitary Plumber',
#   '199714243',
#   'Plumber',
#   '18 January 2024',
#   '',
#   ''],
#  ['HRSTIC, PETER FREDRICK',
#   'Water Supply Plumber',
#   '201256',
#   'Plumber',
#   '3 October 2023',
#   '',
#   'Certified to test Backflow Prevention Devices.'],
#  ['HRSTIC, PETER FREDRICK',
#   'Sanitary Plumber',
#   '201256',
#   'Plumber',
#   '3 October 2023',
#   '',
#   'Certified to test Backflow Prevention Devices.'],
#  ['HUANG, GUOHUA',
#   'Sanitary Plumber',
#   '20181221',
#   'Plumber',
#   '8 November 2021',
#   '',
#   ''],
#  ['HUANG, GUOHUA',
#   'Water Supply Plumber',
#   '20181221',
#   'Plumber',
#   '8 November 2021',
#   '',
#   ''],
#  ['HUGGAN, PAUL GARETH',
#   'Sanitary Plumber',
#   '199414165',
#   'Plumber',
#   '25 October 2022',
#   '',
#   ''],
#  ['HUGGAN, PAUL GARETH',
#   'Water Supply Plumber',
#   '199414165',
#   'Plumber',
#   '25 October 2022',
#   '',
#   ''],
#  ['HUGHES, JOHN',
#   'Journeyperson Plumber',
#   '2020607',
#   'Plumber',
#   '20 May 2023',
#   ''],
#  ['HULM, DANIEL JOHN',
#   'Sanitary Plumber',
#   '2006550',
#   'Plumber',
#   '19 September 2021',
#   ''],
#  ['HUNT, TIMOTHY',
#   'Journeyperson Plumber',
#   '2020185',
#   'Plumber',
#   '18 March 2023',
#   ''],
#  ['HUNTER, HILTON JARRAD',
#   'Journeyperson Plumber',
#   '2013894',
#   'Plumber',
#   '7 April 2024',
#   ''],
#  ['HUNTER, SAMUEL JAMES',
#   'Journeyperson Plumber',
#   '2018605',
#   'Plumber',
#   '6 April 2022',
#   ''],
#  ['HURLEY, BRENT NATHAN',
#   'Sanitary Plumber',
#   '2017930',
#   'Plumber',
#   '7 December 2023',
#   '',
#   ''],
#  ['HURLEY, BRENT NATHAN',
#   'Water Supply Plumber',
#   '2017930',
#   'Plumber',
#   '7 December 2023',
#   '',
#   ''],
#  ['HURST, LUKE WILLIAM',
#   'Water Supply Plumber',
#   '20131283',
#   'Plumber',
#   '28 November 2022',
#   '',
#   ''],
#  ['HURST, LUKE WILLIAM',
#   'Sanitary Plumber',
#   '20131283',
#   'Plumber',
#   '28 November 2022',
#   '',
#   ''],
#  ['HYDE, GREGORY',
#   'Journeyperson Plumber',
#   '20171019',
#   'Plumber',
#   '4 April 2024',
#   ''],
#  ['HYPDUP CONSTRUCTIONS PTY LTD',
#   'Water Supply Plumber',
#   '20121482',
#   'Plumber',
#   '14 February 2024',
#   '',
#   ''],
#  ['HYPDUP CONSTRUCTIONS PTY LTD',
#   'Sanitary Plumber',
#   '20121482',
#   'Plumber',
#   '14 February 2024',
#   '',
#   ''],
#  ['IFLAND, SEAN DAVID',
#   'Sanitary Plumber',
#   '20101216',
#   'Plumber',
#   '9 August 2022',
#   ''],
#  ['INCHER, JASON LEIGH',
#   'Sanitary Plumber',
#   '199514028',
#   'Plumber',
#   '11 August 2022',
#   ''],
#  ['INDEPENDENT PLUMBING AND GAS FITTING PTY LTD',
#   'Sanitary Plumber',
#   '20191263',
#   'Plumber',
#   '4 December 2021',
#   '',
#   ''],
#  ['INDEPENDENT PLUMBING AND GAS FITTING PTY LTD',
#   'Water Supply Plumber',
#   '20191263',
#   'Plumber',
#   '4 December 2021',
#   '',
#   ''],
#  ['INFINITY FIRE PROTECTION PTY LTD',
#   'Fire Sprinkler Fitter',
#   '2015381',
#   'Plumber',
#   '29 January 2023',
#   ''],
#  ['INGHAM, ROSS DAVID',
#   'Sanitary Plumber',
#   '20111530',
#   'Plumber',
#   '8 May 2022',
#   '',
#   ''],
#  ['INGHAM, ROSS DAVID',
#   'Water Supply Plumber',
#   '20111530',
#   'Plumber',
#   '8 May 2022',
#   '',
#   ''],
#  ['INGRAM, GREGORY JOHN',
#   'Sanitary Plumber',
#   '199715054',
#   'Plumber',
#   '27 April 2022',
#   '',
#   ''],
#  ['INGRAM, GREGORY JOHN',
#   'Water Supply Plumber',
#   '199715054',
#   'Plumber',
#   '27 April 2022',
#   '',
#   ''],
#  ['INGRAM, TYLER',
#   'Journeyperson Plumber',
#   '2020931',
#   'Plumber',
#   '28 August 2024',
#   ''],
#  ['INWOOD, MATT JAMES',
#   'Sanitary Plumber',
#   '2014445',
#   'Plumber',
#   '23 October 2021',
#   '',
#   ''],
#  ['INWOOD, MATT JAMES',
#   'Water Supply Plumber',
#   '2014445',
#   'Plumber',
#   '23 October 2021',
#   '',
#   ''],
#  ['IRVIN, JAYSON',
#   'Journeyperson Plumber',
#   '2021999',
#   'Plumber',
#   '20 August 2024',
#   ''],
#  ['IRVING, MITCHELL EDWARD',
#   'Sanitary Plumber',
#   '2007348',
#   'Plumber',
#   '24 September 2023',
#   ''],
#  ['ISHAK, PATRICK',
#   'Journeyperson Plumber',
#   '2018946',
#   'Plumber',
#   '9 November 2021',
#   ''],
#  ['ISON, LESLIE JAMES',
#   'Water Supply Plumber',
#   '2015512',
#   'Plumber',
#   '25 June 2022',
#   '',
#   ''],
#  ['ISON, LESLIE JAMES',
#   'Sanitary Plumber',
#   '2015512',
#   'Plumber',
#   '25 June 2022',
#   '',
#   ''],
#  ['IVES, ANDREW JACKSON',
#   'Sanitary Plumber',
#   '2009380',
#   'Plumber',
#   '1 July 2022',
#   '',
#   ''],
#  ['IVES, ANDREW JACKSON',
#   'Water Supply Plumber',
#   '2009380',
#   'Plumber',
#   '1 July 2022',
#   '',
#   ''],
#  ['J. EVERS PTY LTD',
#   'Water Supply Plumber',
#   '2014334',
#   'Plumber',
#   '18 April 2024',
#   '',
#   ''],
#  ['J. EVERS PTY LTD',
#   'Sanitary Plumber',
#   '2014334',
#   'Plumber',
#   '18 April 2024',
#   '',
#   ''],
#  ['JACKSON, CHARLES',
#   'Journeyperson Plumber',
#   '202139',
#   'Plumber',
#   '20 January 2024',
#   ''],
#  ['JACOB, PHILIP JOHN',
#   'Fire Sprinkler Fitter',
#   '20151178',
#   'Plumber',
#   '20 April 2022',
#   ''],
#  ['JACOBS, DONALD EDWARD',
#   'Sanitary Plumber',
#   '199515011',
#   'Plumber',
#   '1 July 2022',
#   'Please contact Access Canberra for condition details',
#   ''],
#  ['JACOBS, DONALD EDWARD',
#   'Water Supply Plumber',
#   '199515011',
#   'Plumber',
#   '1 July 2022',
#   'Please contact Access Canberra for condition details',
#   ''],
#  ['JACOBS, JACK',
#   'Journeyperson Plumber',
#   '20201650',
#   'Plumber',
#   '14 December 2023',
#   ''],
#  ['JAKOBASIC, BRENDON MICHAEL',
#   'Sanitary Plumber',
#   '2008757',
#   'Plumber',
#   '21 September 2023',
#   ''],
#  ['JAMES, NIGEL PAUL',
#   'Water Supply Plumber',
#   '199414168',
#   'Plumber',
#   '12 March 2024',
#   '',
#   ''],
#  ['JAMES, NIGEL PAUL',
#   'Sanitary Plumber',
#   '199414168',
#   'Plumber',
#   '12 March 2024',
#   '',
#   ''],
#  ['JAMES-WARD, RICCI',
#   'Journeyperson Plumber',
#   '2021811',
#   'Plumber',
#   '13 July 2024',
#   ''],
#  ['JAMIE, DAHER',
#   'Water Supply Plumber',
#   '2019544',
#   'Plumber',
#   '29 June 2022',
#   '',
#   ''],
#  ['JAMIE, DAHER',
#   'Sanitary Plumber',
#   '2019544',
#   'Plumber',
#   '29 June 2022',
#   '',
#   ''],
#  ['JANDI, ROBERT',
#   'Water Supply Plumber',
#   '200116006',
#   'Plumber',
#   '13 August 2023',
#   'Fire Sprinkler work restricted to hydrants, hosereels and backflow'],
#  ['JARAM, ADAM JOSEPH',
#   'Water Supply Plumber',
#   '201558',
#   'Plumber',
#   '23 February 2024',
#   '',
#   ''],
#  ['JARAM, ADAM JOSEPH',
#   'Sanitary Plumber',
#   '201558',
#   'Plumber',
#   '23 February 2024',
#   '',
#   ''],
#  ['JARAM, RICHARD MILAN',
#   'Water Supply Plumber',
#   '199815817',
#   'Plumber',
#   '1 February 2023',
#   '',
#   ''],
#  ['JARAM, RICHARD MILAN',
#   'Sanitary Plumber',
#   '199815817',
#   'Plumber',
#   '1 February 2023',
#   '',
#   ''],
#  ['JARVIE, EDWARD ALLAN',
#   'Water Supply Plumber',
#   '199715734',
#   'Plumber',
#   '11 June 2024',
#   '',
#   ''],
#  ['JARVIE, EDWARD ALLAN',
#   'Sanitary Plumber',
#   '199715734',
#   'Plumber',
#   '11 June 2024',
#   '',
#   ''],
#  ['JENBID PTY LTD',
#   'Sanitary Plumber',
#   '2019986',
#   'Plumber',
#   '23 October 2022',
#   '',
#   ''],
#  ['JENBID PTY LTD',
#   'Water Supply Plumber',
#   '2019986',
#   'Plumber',
#   '23 October 2022',
#   '',
#   ''],
#  ['JERDETSKI, ILYA',
#   'Sanitary Plumber',
#   '2019155',
#   'Plumber',
#   '19 May 2022',
#   '',
#   ''],
#  ['JERDETSKI, ILYA',
#   'Water Supply Plumber',
#   '2019155',
#   'Plumber',
#   '19 May 2022',
#   '',
#   ''],
#  ['JIRGENS WATERTEC PTY LTD',
#   'Water Supply Plumber',
#   '2020293',
#   'Plumber',
#   '26 March 2023',
#   'Certified to test backflow prevention devices.',
#   ''],
#  ['JIRGENS WATERTEC PTY LTD',
#   'Sanitary Plumber',
#   '2020293',
#   'Plumber',
#   '26 March 2023',
#   'Certified to test backflow prevention devices.',
#   ''],
#  ['JOHN. R. KEITH PTY LTD',
#   'Sanitary Plumber',
#   '2008491',
#   'Plumber',
#   '31 May 2023',
#   ''],
#  ['JOHNSON, RYAN MICHAEL',
#   'Fire Sprinkler Fitter',
#   '2021689',
#   'Plumber',
#   '24 June 2024',
#   ''],
#  ['JOHNSTON, BYRON ACHESON',
#   'Sanitary Plumber',
#   '199715442',
#   'Plumber',
#   '6 April 2024',
#   'Includes Water Supply work'],
#  ['JOMAX INVESTMENTS PTY LIMITED',
#   'Water Supply Plumber',
#   '2014771',
#   'Plumber',
#   '19 November 2023',
#   '',
#   ''],
#  ['JOMAX INVESTMENTS PTY LIMITED',
#   'Sanitary Plumber',
#   '2014771',
#   'Plumber',
#   '19 November 2023',
#   '',
#   ''],
#  ['JONES, ALBERT',
#   'Journeyperson Plumber',
#   '2011313',
#   'Plumber',
#   '8 April 2022',
#   ''],
#  ['JONES, ANDREW DANIEL',
#   'Water Supply Plumber',
#   '200416194',
#   'Plumber',
#   '21 June 2024',
#   ''],
#  ['JONES, MATTHEW SEAN',
#   'Journeyperson Plumber',
#   '2016712',
#   'Plumber',
#   '7 August 2022',
#   ''],
#  ['JONES, PAUL',
#   'Water Supply Plumber',
#   '2021553',
#   'Plumber',
#   '17 May 2022',
#   '',
#   ''],
#  ['JONES, PAUL',
#   'Sanitary Plumber',
#   '2021553',
#   'Plumber',
#   '17 May 2022',
#   '',
#   ''],
#  ['JONES, RYAN JEFFREY',
#   'Sanitary Plumber',
#   '20141276',
#   'Plumber',
#   '11 December 2022',
#   '',
#   ''],
#  ['JONES, RYAN JEFFREY',
#   'Water Supply Plumber',
#   '20141276',
#   'Plumber',
#   '11 December 2022',
#   '',
#   ''],
#  ['JORDAN, MITCHELL JAMES',
#   'Journeyperson Plumber',
#   '20131049',
#   'Plumber',
#   '31 March 2023',
#   ''],
#  ['JOSE, BENJAMIN WILLIAM',
#   'Sanitary Plumber',
#   '201962',
#   'Plumber',
#   '29 January 2022',
#   '',
#   ''],
#  ['JOSE, BENJAMIN WILLIAM',
#   'Water Supply Plumber',
#   '201962',
#   'Plumber',
#   '29 January 2022',
#   '',
#   ''],
#  ['JOZING, NICHOLAS JAMES',
#   'Journeyperson Plumber',
#   '20121627',
#   'Plumber',
#   '24 July 2022',
#   ''],
#  ['JOZWIAK, DANIEL JOHN',
#   'Sanitary Plumber',
#   '2015948',
#   'Plumber',
#   '9 June 2023',
#   '',
#   ''],
#  ['JOZWIAK, DANIEL JOHN',
#   'Water Supply Plumber',
#   '2015948',
#   'Plumber',
#   '9 June 2023',
#   '',
#   ''],
#  ['JUDE, DAVID ANDREW',
#   'Sanitary Plumber',
#   '199415611',
#   'Plumber',
#   '21 March 2024',
#   '',
#   ''],
#  ['JUDE, DAVID ANDREW',
#   'Water Supply Plumber',
#   '199415611',
#   'Plumber',
#   '21 March 2024',
#   '',
#   ''],
#  ...]

# %%
licensee_detail[0]
# Out:
# ['360 DEGREE FIRE PTY LTD',
#  '2017990',
#  'Plumber',
#  'Water Supply Plumber',
#  '22 January 2023',
#  '']

# %%
len(licensee_detail)
# Out:
# 2147

# %% [markdown]
# # Creating the final dataframe by zipping all the attribute's lists

# %%
df = pd.DataFrame(licensee_detail, columns = ['Name', 'License number','Occupation','Class description','Expiry Date','Class Condition / Endorsement','x1','x2'])
 
# print dataframe.
df
# Out:
#                                                Name  \
# 0                           360 DEGREE FIRE PTY LTD
# 1            A & A HOTWATER & GAS SOLUTIONS PTY LTD
# 2                               A & K (ACT) PTY LTD
# 3                               A & K (ACT) PTY LTD
# 4                     A PLUS PLUMBING (ACT) PTY LTD
# 5                     A PLUS PLUMBING (ACT) PTY LTD
# 6                  AAA ABOVE BOARD PLUMBING PTY LTD
# 7                  AAA ABOVE BOARD PLUMBING PTY LTD
# 8                              ABBEY, DAMIEN LETTON
# 9                 ABDEL RAHMAN, MUDATHIR NOURIN ALI
# 10                                    ABSOLOM, ALEX
# 11                         ACKLAND, CHRISTOPHER LEE
# 12                         ACKLAND, CHRISTOPHER LEE
# 13                                     ADAMS, JAMES
# 14                                ADENS-KANTS, MARK
# 15                                ADENS-KANTS, MARK
# 16    ADVANCED PLUMBING & DRAINS (CANBERRA) PTY LTD
# 17    ADVANCED PLUMBING & DRAINS (CANBERRA) PTY LTD
# 18                                 AGGARWAL, SURESH
# 19                                 AGGARWAL, SURESH
# 20                                   AGIUS, MICHAEL
# 21                                   AGIUS, MICHAEL
# 22                           AGOSTINO, ALEX DOMINIC
# 23                           AGOSTINO, ALEX DOMINIC
# 24                                  AL-KULABI, SAIF
# 25                                  AL-KULABI, SAIF
# 26                                AL-ZAHROUT, BRAKH
# 27                 ALL GAS PLUMBING REPAIRS PTY LTD
# 28                 ALL GAS PLUMBING REPAIRS PTY LTD
# 29                              ALLAN, JAMES GORDON
# ...                                             ...
# 2117                        WOODWARD, ADAM KINGSLEY
# 2118                        WOODWARD, ADAM KINGSLEY
# 2119                          WOODWARD, MARK VICTOR
# 2120                          WOODWARD, MARK VICTOR
# 2121                             WRIGHT, ALLAN JOHN
# 2122                             WRIGHT, ALLAN JOHN
# 2123                                    WRIGHT, BEN
# 2124                                    WRIGHT, BEN
# 2125                          WRIGHT, JAMES BERNARD
# 2126                                  WRIGHT, OSCAR
# 2127                         WRIGHT, WILLIAM JOSEPH
# 2128                         WRIGHT, WILLIAM JOSEPH
# 2129                        WROE, CARRINGTON ROBERT
# 2130                       WUBBELS, BRANDON MICHAEL
# 2131                                  WYBORN, ETHAN
# 2132                                  WYBORN, ETHAN
# 2133                                   WYBURN, SEAN
# 2134                                   WYBURN, SEAN
# 2135                            XL PLUMBING PTY LTD
# 2136                            XL PLUMBING PTY LTD
# 2137                                 YOUNG, MICHAEL
# 2138              YOUR LOCAL PLUMBING GROUP PTY LTD
# 2139                                 ZAMMIT, EDWARD
# 2140                                 ZAMMIT, EDWARD
# 2141                                   ZHANG, CHENG
# 2142                            ZINGLEMANN, GREGORY
# 2143                            ZINGLEMANN, GREGORY
# 2144                             ZORZI, LUKE SAMUEL
# 2145                           ZOUCH, GEORGE ANDREW
# 2146                           ZOUCH, GEORGE ANDREW
#
#                            License number Occupation      Class description  \
# 0                                 2017990    Plumber   Water Supply Plumber
# 1                                20191321    Plumber   Water Supply Plumber
# 2                                 2016855    Plumber       Sanitary Plumber
# 3                                 2016855    Plumber   Water Supply Plumber
# 4                                 2016683    Plumber   Water Supply Plumber
# 5                                 2016683    Plumber       Sanitary Plumber
# 6                                 2018299    Plumber   Water Supply Plumber
# 7                                 2018299    Plumber       Sanitary Plumber
# 8                               200216119    Plumber       Sanitary Plumber
# 9                                20201405    Plumber  Journeyperson Plumber
# 10                  Journeyperson Plumber    2021915                Plumber
# 11                   Water Supply Plumber    2014830                Plumber
# 12                       Sanitary Plumber    2014830                Plumber
# 13                  Journeyperson Plumber    2021668                Plumber
# 14                   Water Supply Plumber    2017882                Plumber
# 15                       Sanitary Plumber    2017882                Plumber
# 16                       Sanitary Plumber    2017904                Plumber
# 17                   Water Supply Plumber    2017904                Plumber
# 18                       Sanitary Plumber      20151                Plumber
# 19                   Water Supply Plumber      20151                Plumber
# 20                       Sanitary Plumber  199815867                Plumber
# 21                   Water Supply Plumber  199815867                Plumber
# 22    Journeyperson Fire Sprinkler Fitter   20121662                Plumber
# 23                  Journeyperson Plumber   20121662                Plumber
# 24                   Water Supply Plumber    2020367                Plumber
# 25                       Sanitary Plumber    2020367                Plumber
# 26                  Journeyperson Plumber   20211300                Plumber
# 27                       Sanitary Plumber      20208                Plumber
# 28                   Water Supply Plumber      20208                Plumber
# 29                       Sanitary Plumber  199715300                Plumber
# ...                                   ...        ...                    ...
# 2117                 Water Supply Plumber  199714141                Plumber
# 2118                     Sanitary Plumber  199714141                Plumber
# 2119                 Water Supply Plumber  200316156                Plumber
# 2120                     Sanitary Plumber  200316156                Plumber
# 2121                 Water Supply Plumber    2020181                Plumber
# 2122                     Sanitary Plumber    2020181                Plumber
# 2123                 Water Supply Plumber    2021343                Plumber
# 2124                     Sanitary Plumber    2021343                Plumber
# 2125                 Water Supply Plumber    2009649                Plumber
# 2126                Journeyperson Plumber    2020897                Plumber
# 2127                     Sanitary Plumber    2014616                Plumber
# 2128                 Water Supply Plumber    2014616                Plumber
# 2129                     Sanitary Plumber    2007277                Plumber
# 2130  Journeyperson Fire Sprinkler Fitter    2018777                Plumber
# 2131                 Water Supply Plumber   20181262                Plumber
# 2132                     Sanitary Plumber   20181262                Plumber
# 2133                     Sanitary Plumber    2017261                Plumber
# 2134                 Water Supply Plumber    2017261                Plumber
# 2135                     Sanitary Plumber    2008404                Plumber
# 2136                 Water Supply Plumber    2008404                Plumber
# 2137                Fire Sprinkler Fitter    2021390                Plumber
# 2138                     Sanitary Plumber    2016603                Plumber
# 2139                 Water Supply Plumber  199613986                Plumber
# 2140                     Sanitary Plumber  199613986                Plumber
# 2141                Journeyperson Plumber    2021181                Plumber
# 2142                 Water Supply Plumber   20211069                Plumber
# 2143                     Sanitary Plumber   20211069                Plumber
# 2144                 Water Supply Plumber    2016890                Plumber
# 2145                 Water Supply Plumber     201583                Plumber
# 2146                     Sanitary Plumber     201583                Plumber
#
#             Expiry Date                      Class Condition / Endorsement  \
# 0       22 January 2023
# 1       2 February 2024
# 2     13 September 2022
# 3     13 September 2022
# 4        17 August 2022
# 5        17 August 2022
# 6           31 May 2022
# 7           31 May 2022
# 8      17 February 2024     Certified to test Backflow Prevention Devices.
# 9       31 October 2023
# 10         27 July 2024
# 11         5 April 2023      Certified to test Backflow Prevention Devices
# 12         5 April 2023      Certified to test Backflow Prevention Devices
# 13        8 August 2024
# 14         19 June 2023
# 15         19 June 2023
# 16      6 November 2023      Certified to test Backflow Prevention Devices
# 17      6 November 2023      Certified to test Backflow Prevention Devices
# 18         20 July 2023
# 19         20 July 2023
# 20    26 September 2021     Certified to test Backflow Prevention Devices.
# 21    26 September 2021     Certified to test Backflow Prevention Devices.
# 22      16 January 2022  Journeyperson Fire Sprinkler Fitter - Restrict...
# 23      16 January 2022  Journeyperson Fire Sprinkler Fitter - Restrict...
# 24        16 April 2022
# 25        16 April 2022
# 26    13 September 2024
# 27      6 February 2023
# 28      6 February 2023
# 29         7 March 2023
# ...                 ...                                                ...
# 2117     31 August 2023
# 2118     31 August 2023
# 2119       28 July 2024
# 2120       28 July 2024
# 2121      23 March 2023
# 2122      23 March 2023
# 2123      22 March 2024
# 2124      22 March 2024
# 2125  25 September 2023
# 2126       18 June 2024
# 2127       11 July 2023      Certified to test Backflow Prevention Devices
# 2128       11 July 2023      Certified to test Backflow Prevention Devices
# 2129    30 October 2021
# 2130   12 November 2021
# 2131      29 March 2023
# 2132      29 March 2023
# 2133   7 September 2022      Certified to test Backflow Prevention Devices
# 2134   7 September 2022      Certified to test Backflow Prevention Devices
# 2135       10 June 2022
# 2136       10 June 2022
# 2137      22 April 2024  Valid for work performed as an employee/Nomine...
# 2138       22 July 2022     Certified to test Backflow Prevention Devices.
# 2139    15 October 2022
# 2140    15 October 2022
# 2141    9 February 2024
# 2142     27 August 2024  Valid for work performed as an employee/Nomine...
# 2143     27 August 2024  Valid for work performed as an employee/Nomine...
# 2144   16 December 2022      Certified to test backflow prevention devices
# 2145        1 June 2024
# 2146        1 June 2024
#
#                                                      x1    x2
# 0                                                  None  None
# 1                                                  None  None
# 2                                                        None
# 3                                                        None
# 4                                                        None
# 5                                                        None
# 6                                                        None
# 7                                                        None
# 8                                                  None  None
# 9                                                  None  None
# 10                                                 None  None
# 11                                                       None
# 12                                                       None
# 13                                                 None  None
# 14                                                       None
# 15                                                       None
# 16                                                       None
# 17                                                       None
# 18                                                       None
# 19                                                       None
# 20                                                       None
# 21                                                       None
# 22                                                       None
# 23                                                       None
# 24                                                       None
# 25                                                       None
# 26                                                 None  None
# 27                                                       None
# 28                                                       None
# 29                                                       None
# ...                                                 ...   ...
# 2117                                                     None
# 2118                                                     None
# 2119                                                     None
# 2120                                                     None
# 2121                 Excluding Fire Protection Systems.  None
# 2122                 Excluding Fire Protection Systems.  None
# 2123                                                     None
# 2124                                                     None
# 2125                                               None  None
# 2126                                               None  None
# 2127                                                     None
# 2128                                                     None
# 2129                                               None  None
# 2130                                               None  None
# 2131                                                     None
# 2132                                                     None
# 2133                                                     None
# 2134                                                     None
# 2135                                                     None
# 2136                                                     None
# 2137                                               None  None
# 2138                                               None  None
# 2139                                                     None
# 2140                                                     None
# 2141                                               None  None
# 2142  Valid for work performed as an employee/Nomine...  None
# 2143  Valid for work performed as an employee/Nomine...  None
# 2144                                               None  None
# 2145                                                     None
# 2146                                                     None
#
# [2147 rows x 8 columns]

# %%
df = df.drop(['x1','x2'], 1)

# %%
df
# Out:
#                                                Name  \
# 0                           360 DEGREE FIRE PTY LTD
# 1            A & A HOTWATER & GAS SOLUTIONS PTY LTD
# 2                               A & K (ACT) PTY LTD
# 3                               A & K (ACT) PTY LTD
# 4                     A PLUS PLUMBING (ACT) PTY LTD
# 5                     A PLUS PLUMBING (ACT) PTY LTD
# 6                  AAA ABOVE BOARD PLUMBING PTY LTD
# 7                  AAA ABOVE BOARD PLUMBING PTY LTD
# 8                              ABBEY, DAMIEN LETTON
# 9                 ABDEL RAHMAN, MUDATHIR NOURIN ALI
# 10                                    ABSOLOM, ALEX
# 11                         ACKLAND, CHRISTOPHER LEE
# 12                         ACKLAND, CHRISTOPHER LEE
# 13                                     ADAMS, JAMES
# 14                                ADENS-KANTS, MARK
# 15                                ADENS-KANTS, MARK
# 16    ADVANCED PLUMBING & DRAINS (CANBERRA) PTY LTD
# 17    ADVANCED PLUMBING & DRAINS (CANBERRA) PTY LTD
# 18                                 AGGARWAL, SURESH
# 19                                 AGGARWAL, SURESH
# 20                                   AGIUS, MICHAEL
# 21                                   AGIUS, MICHAEL
# 22                           AGOSTINO, ALEX DOMINIC
# 23                           AGOSTINO, ALEX DOMINIC
# 24                                  AL-KULABI, SAIF
# 25                                  AL-KULABI, SAIF
# 26                                AL-ZAHROUT, BRAKH
# 27                 ALL GAS PLUMBING REPAIRS PTY LTD
# 28                 ALL GAS PLUMBING REPAIRS PTY LTD
# 29                              ALLAN, JAMES GORDON
# ...                                             ...
# 2117                        WOODWARD, ADAM KINGSLEY
# 2118                        WOODWARD, ADAM KINGSLEY
# 2119                          WOODWARD, MARK VICTOR
# 2120                          WOODWARD, MARK VICTOR
# 2121                             WRIGHT, ALLAN JOHN
# 2122                             WRIGHT, ALLAN JOHN
# 2123                                    WRIGHT, BEN
# 2124                                    WRIGHT, BEN
# 2125                          WRIGHT, JAMES BERNARD
# 2126                                  WRIGHT, OSCAR
# 2127                         WRIGHT, WILLIAM JOSEPH
# 2128                         WRIGHT, WILLIAM JOSEPH
# 2129                        WROE, CARRINGTON ROBERT
# 2130                       WUBBELS, BRANDON MICHAEL
# 2131                                  WYBORN, ETHAN
# 2132                                  WYBORN, ETHAN
# 2133                                   WYBURN, SEAN
# 2134                                   WYBURN, SEAN
# 2135                            XL PLUMBING PTY LTD
# 2136                            XL PLUMBING PTY LTD
# 2137                                 YOUNG, MICHAEL
# 2138              YOUR LOCAL PLUMBING GROUP PTY LTD
# 2139                                 ZAMMIT, EDWARD
# 2140                                 ZAMMIT, EDWARD
# 2141                                   ZHANG, CHENG
# 2142                            ZINGLEMANN, GREGORY
# 2143                            ZINGLEMANN, GREGORY
# 2144                             ZORZI, LUKE SAMUEL
# 2145                           ZOUCH, GEORGE ANDREW
# 2146                           ZOUCH, GEORGE ANDREW
#
#                            License number Occupation      Class description  \
# 0                                 2017990    Plumber   Water Supply Plumber
# 1                                20191321    Plumber   Water Supply Plumber
# 2                                 2016855    Plumber       Sanitary Plumber
# 3                                 2016855    Plumber   Water Supply Plumber
# 4                                 2016683    Plumber   Water Supply Plumber
# 5                                 2016683    Plumber       Sanitary Plumber
# 6                                 2018299    Plumber   Water Supply Plumber
# 7                                 2018299    Plumber       Sanitary Plumber
# 8                               200216119    Plumber       Sanitary Plumber
# 9                                20201405    Plumber  Journeyperson Plumber
# 10                  Journeyperson Plumber    2021915                Plumber
# 11                   Water Supply Plumber    2014830                Plumber
# 12                       Sanitary Plumber    2014830                Plumber
# 13                  Journeyperson Plumber    2021668                Plumber
# 14                   Water Supply Plumber    2017882                Plumber
# 15                       Sanitary Plumber    2017882                Plumber
# 16                       Sanitary Plumber    2017904                Plumber
# 17                   Water Supply Plumber    2017904                Plumber
# 18                       Sanitary Plumber      20151                Plumber
# 19                   Water Supply Plumber      20151                Plumber
# 20                       Sanitary Plumber  199815867                Plumber
# 21                   Water Supply Plumber  199815867                Plumber
# 22    Journeyperson Fire Sprinkler Fitter   20121662                Plumber
# 23                  Journeyperson Plumber   20121662                Plumber
# 24                   Water Supply Plumber    2020367                Plumber
# 25                       Sanitary Plumber    2020367                Plumber
# 26                  Journeyperson Plumber   20211300                Plumber
# 27                       Sanitary Plumber      20208                Plumber
# 28                   Water Supply Plumber      20208                Plumber
# 29                       Sanitary Plumber  199715300                Plumber
# ...                                   ...        ...                    ...
# 2117                 Water Supply Plumber  199714141                Plumber
# 2118                     Sanitary Plumber  199714141                Plumber
# 2119                 Water Supply Plumber  200316156                Plumber
# 2120                     Sanitary Plumber  200316156                Plumber
# 2121                 Water Supply Plumber    2020181                Plumber
# 2122                     Sanitary Plumber    2020181                Plumber
# 2123                 Water Supply Plumber    2021343                Plumber
# 2124                     Sanitary Plumber    2021343                Plumber
# 2125                 Water Supply Plumber    2009649                Plumber
# 2126                Journeyperson Plumber    2020897                Plumber
# 2127                     Sanitary Plumber    2014616                Plumber
# 2128                 Water Supply Plumber    2014616                Plumber
# 2129                     Sanitary Plumber    2007277                Plumber
# 2130  Journeyperson Fire Sprinkler Fitter    2018777                Plumber
# 2131                 Water Supply Plumber   20181262                Plumber
# 2132                     Sanitary Plumber   20181262                Plumber
# 2133                     Sanitary Plumber    2017261                Plumber
# 2134                 Water Supply Plumber    2017261                Plumber
# 2135                     Sanitary Plumber    2008404                Plumber
# 2136                 Water Supply Plumber    2008404                Plumber
# 2137                Fire Sprinkler Fitter    2021390                Plumber
# 2138                     Sanitary Plumber    2016603                Plumber
# 2139                 Water Supply Plumber  199613986                Plumber
# 2140                     Sanitary Plumber  199613986                Plumber
# 2141                Journeyperson Plumber    2021181                Plumber
# 2142                 Water Supply Plumber   20211069                Plumber
# 2143                     Sanitary Plumber   20211069                Plumber
# 2144                 Water Supply Plumber    2016890                Plumber
# 2145                 Water Supply Plumber     201583                Plumber
# 2146                     Sanitary Plumber     201583                Plumber
#
#             Expiry Date                      Class Condition / Endorsement
# 0       22 January 2023
# 1       2 February 2024
# 2     13 September 2022
# 3     13 September 2022
# 4        17 August 2022
# 5        17 August 2022
# 6           31 May 2022
# 7           31 May 2022
# 8      17 February 2024     Certified to test Backflow Prevention Devices.
# 9       31 October 2023
# 10         27 July 2024
# 11         5 April 2023      Certified to test Backflow Prevention Devices
# 12         5 April 2023      Certified to test Backflow Prevention Devices
# 13        8 August 2024
# 14         19 June 2023
# 15         19 June 2023
# 16      6 November 2023      Certified to test Backflow Prevention Devices
# 17      6 November 2023      Certified to test Backflow Prevention Devices
# 18         20 July 2023
# 19         20 July 2023
# 20    26 September 2021     Certified to test Backflow Prevention Devices.
# 21    26 September 2021     Certified to test Backflow Prevention Devices.
# 22      16 January 2022  Journeyperson Fire Sprinkler Fitter - Restrict...
# 23      16 January 2022  Journeyperson Fire Sprinkler Fitter - Restrict...
# 24        16 April 2022
# 25        16 April 2022
# 26    13 September 2024
# 27      6 February 2023
# 28      6 February 2023
# 29         7 March 2023
# ...                 ...                                                ...
# 2117     31 August 2023
# 2118     31 August 2023
# 2119       28 July 2024
# 2120       28 July 2024
# 2121      23 March 2023
# 2122      23 March 2023
# 2123      22 March 2024
# 2124      22 March 2024
# 2125  25 September 2023
# 2126       18 June 2024
# 2127       11 July 2023      Certified to test Backflow Prevention Devices
# 2128       11 July 2023      Certified to test Backflow Prevention Devices
# 2129    30 October 2021
# 2130   12 November 2021
# 2131      29 March 2023
# 2132      29 March 2023
# 2133   7 September 2022      Certified to test Backflow Prevention Devices
# 2134   7 September 2022      Certified to test Backflow Prevention Devices
# 2135       10 June 2022
# 2136       10 June 2022
# 2137      22 April 2024  Valid for work performed as an employee/Nomine...
# 2138       22 July 2022     Certified to test Backflow Prevention Devices.
# 2139    15 October 2022
# 2140    15 October 2022
# 2141    9 February 2024
# 2142     27 August 2024  Valid for work performed as an employee/Nomine...
# 2143     27 August 2024  Valid for work performed as an employee/Nomine...
# 2144   16 December 2022      Certified to test backflow prevention devices
# 2145        1 June 2024
# 2146        1 June 2024
#
# [2147 rows x 6 columns]

# %% [markdown]
# ## Checking the shape (rows & columns) of the final dataframe

# %%
df.shape
# Out:
# (2147, 6)

# %% [markdown]
# ## Converting the dataframe into a `.csv` file

# %%
df.to_csv('ACT_Plumbers.csv')
